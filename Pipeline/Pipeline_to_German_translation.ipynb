# %% [markdown]
# # Pipeline - Translate to German
#
# This notebook takes the paraphrased sentences from the idiom paraphrase model(s) and feeds them through a regular T5 model (not fine-tuned) to translate them from English to German.

# %% [markdown]
# ## Load packages and data

# %%
# !pip install sentencepiece -q
# !pip install transformers -q
# !pip install torch -q
# Out:
#      |████████████████████████████████| 1.2 MB 5.4 MB/s
#      |████████████████████████████████| 4.2 MB 5.6 MB/s
#      |████████████████████████████████| 86 kB 3.4 MB/s
#      |████████████████████████████████| 6.6 MB 28.7 MB/s
#      |████████████████████████████████| 596 kB 34.2 MB/s

# %%
# Drive
from google.colab import drive

# Util
import os
import re
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)

# ML
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler

# Importing the T5 modules from huggingface/transformers
from transformers import T5Tokenizer, T5ForConditionalGeneration

# Setting up the device for GPU usage
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import inputs and predictions of the models


# Import split 1 no prefix (easiest for the inputs)
path = "file path here"
val_data = pd.read_csv(path+"data/data_nopref_val_split1.csv", sep="=")
en_id_data = val_data[['input']]

# test_data = pd.read_csv(path+"data/data_nopref_test_split1.csv", sep="=")
# en_id_data = test_data['input']

# %%
# Loading in prediction data
file_path = "file path here"
predictions_file = pd.read_csv(file_path+"predictions_IOBs.csv")

# Isolate the columns we need
en_lit_data = predictions_file[['Generated Text']].rename(columns={"Generated Text": "input"})
en_id_data = predictions_file[['Input']].rename(columns={"Input": "input"})
# references = predictions_file['Actual Text']
# sources = predictions_file['Input']

# %%
en_lit_data.iloc[0][0]
# Out:
# "Let's assume that she is right."

# %%
def cleanSources(sources, prefix, space_punct=False, suffix=None):
  '''Function to remove the prefix from the source sentence
  For example, if you had the prefix "paraphrase:" then you should add that as the prefix parameter.
  '''
  if space_punct:
    sources = sources.str.replace(",", " ,")
    sources = sources.str.replace(".", " .")
    sources = sources.str.replace("'", " '")
    sources = sources.str.replace("  ", " ")


  sources = sources.str.replace('"', '')
  # Removes any remainder of a prefix that might have stuck
  for p in prefix:
    sources = sources.str.replace(p, "")
  
  # Removes the idiom and everything following it
  if suffix is not None:
    for i in range(len(suffix)):
      sources[i] = sources[i].split(suffix, 1)[0]
  return sources

# %%
en_id_data['input'] = cleanSources(en_id_data['input'], prefix=["id_par sentence:"], suffix="idiom: ")

# %%
# Create input data

# Sentences with idioms
# en_id_input = pd.DataFrame()
# en_id_input['input'] = en_id_data.agg('translate English to German: {0[input]}'.format, axis=1)

# Sentences with idioms paraphrased
en_lit_input = pd.DataFrame()
en_lit_input['input'] = en_lit_data.agg('translate English to German: {0[input]}'.format, axis=1)

# %%
# Check max length
lengths_en_id = en_id_input["input"].str.split(" ")
lengths_en_lit = en_lit_input["input"].str.split(" ")

print("Max number of tokens input = ", max(lengths_en_id.str.len().max(),lengths_en_lit.str.len().max()))
# Out:
# Max number of tokens input =  107

# %%
# Check data
en_lit_input.head(n=10)
# Out:
#                                                input
# 0  translate English to German: Let's assume that...
# 1  translate English to German: The management wa...
# 2  translate English to German: I am really happy...
# 3  translate English to German: The boiling point...
# 4  translate English to German: The teacher makes...
# 5  translate English to German: I heard you had a...
# 6  translate English to German: I appreciate the ...
# 7  translate English to German: The client has be...
# 8  translate English to German: Losing that job t...
# 9  translate English to German: The teacher had a...

# %% [markdown]
# ##Setup functions & classes

# %% [markdown]
# ###CLASS: InputData

# %% [markdown]
# An InputData class for reading and loading the InputData into the dataloader, and then feed it into the neural network.

# %%
class InputData(Dataset):
    """
    Creating a dataset class for reading the dataset and
    loading it into the dataloader, to pass it to the
    neural network (only source, no target)

    """

    def __init__(
        self, dataframe, tokenizer, input_len, input_text
    ):
        """
        Initializes an InputData class

        Args:
            dataframe (pandas.DataFrame): Input dataframe
            tokenizer (transformers.tokenizer): Transformers tokenizer
            input_len (int): Max length of source text
            input_text (str): column name of source text
        """
        self.tokenizer = tokenizer
        self.data = dataframe
        self.input_len = input_len
        self.input_text = self.data[input_text]

    def __len__(self):
        """returns the length of dataframe"""

        return len(self.input_text)

    def __getitem__(self, index):
        """return the input ids and attention masks"""

        input_text = str(self.input_text[index])

        # cleaning data so as to ensure data is in string type
        input_text = " ".join(input_text.split())

        input = self.tokenizer.batch_encode_plus(
            [input_text],
            max_length=self.input_len,
            pad_to_max_length=True,
            truncation=True,
            padding="max_length",
            return_tensors="pt",
        )

        input_ids = input["input_ids"].squeeze()
        input_mask = input["attention_mask"].squeeze()

        return {
            "input_ids": input_ids.to(dtype=torch.long),
            "input_mask": input_mask.to(dtype=torch.long),
        }

# %% [markdown]
# ###FUNC: generate

# %% [markdown]
# Validate function is same as the Train function, but for the validation data

# %%
def generate(tokenizer, model, device, loader):

  """
  Function to generate predictions using the model

  """
  model.eval()
  predictions = []
  with torch.no_grad():
      for _, data in enumerate(loader, 0):
          ids = data['input_ids'].to(device, dtype = torch.long)
          mask = data['input_mask'].to(device, dtype = torch.long)

          # Generate outputs
          generated_ids = model.generate(
              input_ids = ids,
              attention_mask = mask, 
              max_length=150, 
              num_beams=2,
              repetition_penalty=2.5, 
              length_penalty=1.0, 
              early_stopping=True
              )
          preds = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True) for g in generated_ids]

          predictions.extend(preds)

  print("Outputs generated.")


  return predictions

# %% [markdown]
# ###FUNC: T5Generate
#
# T5Generate accepts the input data and utilizes the InputData class for data handling and the generate function to generate outputs from the T5 model.

# %%
def T5Generate(
    input_data, input_text, model_type="t5-small", output_dir="./outputs/"
):

    """
    T5Generate has 3 arguments:

      input_data: Input dataframe of input data
      input_text: Column name of the input text
      output_dir: Output directory to save results

    """

    # Set random seeds and deterministic pytorch for reproducibility
    torch.manual_seed(42)  # pytorch random seed
    np.random.seed(42)  # numpy random seed
    torch.backends.cudnn.deterministic = True

    # tokenizer for encoding the text
    tokenizer = T5Tokenizer.from_pretrained(model_type)

    # Defining the model. The model is then sent to device (GPU/TPU)
    model = T5ForConditionalGeneration.from_pretrained(model_type)
    model = model.to(device)

    # Importing the raw dataset
    input_data = input_data[[input_text]]

    # Creation of InputData and Dataloader
    print(f"INPUT data: {input_data.shape}")

    # Creating the Input dataset for further creation of Dataloader
    input_set = InputData(
        input_data,
        tokenizer,
        110,
        "input",
    )

    # Defining the parameters for creation of dataloaders
    input_params = {
        "batch_size": 4,
        "shuffle": False,
        "num_workers": 0,
    }

    # Creation of Dataloaders for data
    input_loader = DataLoader(input_set, **input_params)

    # Generating output
    translations = generate(tokenizer, model, device, input_loader)
    final_df = pd.DataFrame({"Input": input_data[input_text], "Generated Text": translations})
    final_df.to_csv(os.path.join(output_dir, "translations.csv"))

    print(
        f"""Generated data saved @ {os.path.join(output_dir,'translations.csv')}\n"""
    )

# %% [markdown]
# ## Translate sentences

# %% [markdown]
# #### Paraphrased sentences

# %%
# Generate translations to paraphrased sentences
T5Generate(input_data=en_lit_input, input_text="input", model_type="t5-small", output_dir=file_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:169: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-small automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,
# INPUT data: (412, 1)
# Outputs generated.
# Generated data saved @ /content/drive/MyDrive/Pipeline/Data/Idpar_Idiom_IOBs/outputs/test_data/translations.csv

# %%
# Load translations
translations_lit = pd.read_csv(file_path+"translations.csv")
# en_id_data = en_id_data[['input']].rename(columns={"input": "Source"})
translations = en_id_data.join(translations_lit["Input"])
translations["Input"] = cleanSources(translations['Input'], prefix=["translate English to German:"], suffix=None)
translations = translations.join(translations_lit["Generated Text"])
translations.head()

translations.to_csv(os.path.join(file_path, "translations_Source_German.csv"))

# for i in range(len(translations_lit)):
#   print(i)
#   print(translations_lit['Input'].iloc[i])
#   print(translations_lit['Generated Text'].iloc[i])
#   print()

# %%
# Still some cases where the output is basically blank.
print(en_id_input['input'].iloc[153])
print(translations_lit['Input'].iloc[153])
print(translations_lit['Generated Text'].iloc[153])
print()
print(en_id_input['input'].iloc[223])
print(translations_lit['Input'].iloc[223])
print(translations_lit['Generated Text'].iloc[223])
print()
print(en_id_input['input'].iloc[362])
print(translations_lit['Input'].iloc[362])
print(translations_lit['Generated Text'].iloc[362])
print()

# Also a case where the sentence is not translated to german but rewritten in english?
print()
print(en_id_input['input'].iloc[4])
print(translations_lit['Input'].iloc[4])
print(translations_lit['Generated Text'].iloc[4])
print()

# Also some cases where the english sentence was unnecessarily rewritten (though not really a problem)
print()
print(en_id_input['input'].iloc[2])
print(translations_lit['Input'].iloc[2])
print(translations_lit['Generated Text'].iloc[2])
print()

# Also many cases where idiom is not translated correctly, so the end result is weird as well
print()
print(en_id_input['input'].iloc[15])
print(translations_lit['Input'].iloc[15]) # Here missing punctuation also affects things
print(translations_lit['Generated Text'].iloc[15])
print()
# Out:
# 697
# translate English to German: Did you enjoy the ballet this weekend? Not at all.
# Das Ballett hat Sie an diesem Wochenende genossen, aber gar nicht.
#
# 698
# translate English to German: His piercing blue eyes are at opposites with the rest of his features and
# Seine blauen Augen sind gegensätzlich mit dem Rest seiner Merkmale und
#
# 699
# translate English to German: You seem to be crying fake tears at the thought of having to miss work tomorrow.
# Sie scheinen gefälschte Tränen zu schreien, wenn man denkt, morgen die Arbeit verpassen zu müssen.
#
# 700
# translate English to German: Working and studying at the same time has led to me having to use only my energy at the same time.
# Die Arbeit und das Studium hat dazu geführt, dass ich nur meine Energie gleichzeitig nutzen musste.
#
# 701
# translate English to German: Going into a business without carrying out proper studies is very risky.
# Es ist sehr riskant, in ein Unternehmen zu gehen, ohne ordentliche Studien durchzuführen.
#
# 702
# translate English to German: Your exam results this term were not up to what was expected.
# Ihre Prüfungsergebnisse dieser Zeit waren nicht dem entsprechen, was erwartet wurde.
#
# 703
# translate English to German: I usually can not get a strong argument with everybody but knowing that it can lead to some serious business opportunities, I can give it a shot.
# Ich kann normalerweise nicht ein starkes Argument mit allen bekommen, aber wissend, dass es zu ernsten Geschäftsmöglichkeiten führen kann, kann ich ihm einen Schub geben.
#
# 704
# translate English to German: My mom arrived for christmas this year unexpectedly, I thought she was spending it with my brothers family.
# Meine Mutter kam zu Weihnachten dieses Jahres unerwartet, dachte ich, sie verbrachte es mit meinen Brüdern Familie.
#
# 705
# translate English to German: Before being reported as a scam, he used to brag about this project and Now the minister has handled the project in front of the media.
# Bevor er als Betrügereien berichtet wurde, war er früher über dieses Projekt und jetzt hat der Minister das Projekt vor den Medien.
#
# 706
# translate English to German: I'm not going to send invitations to my wedding.
# Ich werde keine Einladungen zu meiner Hochzeit senden.
#
# 707
# translate English to German: You can cry all you want, we are still not going to that concert tomorrow night.
# Sie können alles weinen, was Sie wollen, wir gehen noch nicht zu diesem Konzert morgen Abend.
#
# 708
# translate English to German: our friends have been a real rock in the constant change of our lives the last few years.
# Unsere Freunde waren ein echter Rock in der ständigen Veränderung unseres Lebens in den letzten Jahren.
#
# 709
# translate English to German: What you know about the problems between your mother and I are only a small part of the problem.
# Was Sie über die Probleme zwischen Ihrer Mutter und mir wissen, ist nur ein kleiner Teil des Problems.
#
# 710
# translate English to German: entire store is in a state of ruin now due to the issue of sectarianism.
# ganzes Lager befindet sich jetzt in einem Zustand des Ruins aufgrund der Frage des Sektiererismus.
#
# 711
# translate English to German: Don't forget to take your umbrella to prevent the rain, Peter and It is horrible outside.
# Vergessen Sie nicht, Ihren Sonnenschirm zu nehmen, um den Regen zu verhindern, Peter und Es ist schrecklich draußen.
#
# 712
# translate English to German: You can stay with us for some time until you are back on your feet
# Sie können bei uns für eine Weile bleiben, bis Sie wieder auf Ihre Füße sind.
#
# 713
# translate English to German: His failed dream of being a singer has gone bankrupt.
# Sein gescheiterter Traum, Sänger zu sein, ist in Konkurs gegangen.
#
# 714
# translate English to German: Even though there are rumours that the company is in trouble, we plan to stick it out through rough patches.
# Obwohl Gerüchte lauten, dass das Unternehmen in Schwierigkeiten ist, planen wir, dies durch raue Flecken zu halten.
#
# 715
# translate English to German: I wish someone would reduce him to size.
# Ich wünschte, jemand würde ihn auf die Größe reduzieren.
#
# 716
# translate English to German: He lost control completely when his wife left him over his drinking habit.
# Er verlor die Kontrolle, als seine Frau ihn über seine Trinkgewohnheit ließ.
#
# 717
# translate English to German: He's working short hours today, he has to leave for a doctor's appointment after lunch.
# Er arbeitet heute kurz, er muss nach dem Mittagessen einen Arzt verlassen.
#
# 718
# translate English to German: I don't know why she bought that music system, which she only uses only once in a while.
# Ich weiß nicht, warum sie dieses Musiksystem gekauft hat, das sie nur einmal in einer Weile verwendet.
#
# 719
# translate English to German: His troubled past always kept her on the constant routine to avoid any mishap.
# Seine schmerzliche Vergangenheit hielt sie stets auf der ständigen Routine, um Missglücke zu vermeiden.
#
# 720
# translate English to German: I am taking a short notice from having the morning coffee with my husband today because I have to get to a business meeting by 8 am.
# Ich nehme den Morgenkaffee mit meinem Mann heute kurz vor, weil ich bis 8 Uhr zu einem Geschäftstreffen kommen muss.
#
# 721
# translate English to German: It was almost as if at that time that I met your father.
# Es war fast so, als ob ich zu dieser Zeit Ihren Vater traf.
#
# 722
# translate English to German: I waited in a nervous and excited manner to find out if my wife and child were safe outside the operation theatre for two hours.
# Ich wartete auf Nervosität und Aufregung, um herauszufinden, ob meine Frau und mein Kind zwei Stunden vor dem Operationstheater sicher waren.
#
# 723
# translate English to German: The advertisements shown are meant to show your interest to buy those products.
# Die angezeigten Werbeanzeigen sollen Ihr Interesse zum Kauf dieser Produkte zeigen.
#
# 724
# translate English to German: You saved me from having to talk to that tedious woman and You are my friend of mine.
# Sie haben mir gerettet, mit dieser mühsamen Frau zu sprechen, und Sie sind mein Freund.
#
# 725
# translate English to German: She is as eager to get her hands on the new toys that her mother promised her.
# Sie ist ebenso eifrig, um die neuen Spielzeuge zu bekommen, die ihre Mutter ihr versprochen hat.
#
# 726
# translate English to German: Another loss would exclude out all the happiness.
# Ein weiterer Verlust würde das Glück ausschließen.
#
# 727
# translate English to German: When I was a child, I used to fancy myself being a sportsperson when I grew up, but that can not be changed and Now I am stuck at this mundane job.
# Als ich ein Kind war, habe ich mich gefreut, als ich aufgewachsen bin Sportler zu sein, aber das kann nicht geändert werden und jetzt bin ich an diesem banalen Job festgehalten.
#
# 728
# translate English to German: My mom makes this cheesecake since long ago and I am yet to taste anything that is better.
# Meine Mutter macht diesen Käsekuchen seit langem und ich bin noch nicht zu schmecken, was besser ist.
#
# 729
# translate English to German: I am preparing dinner, but until then, you should try to get things ready for school tomorrow.
# Ich bereite das Abendessen vor, aber bis dahin sollten Sie versuchen, die Dinge morgen für die Schule vorzubereiten.
#
# 730
# translate English to German: I father was hoping for the best outcome, but was prepared to not get it at the time my mother was going through some serious ailments.
# Ich Vater hoffte auf das beste Ergebnis, war aber bereit, es nicht zu bekommen, als meine Mutter durch einige schwere Krankheiten.
#
# 731
# translate English to German: Don't worry, it is just a small in jury, you don't have to worry about it.
# Keine Sorge, es ist nur eine kleine Jury, Sie müssen sich nicht darüber Sorgen machen.
#
# 732
# translate English to German: I am not working right now but have a few offers in preparation.
# Ich arbeite jetzt nicht, habe aber einige Angebote in Vorbereitung.
#
# 733
# translate English to German: I hope Lily and Tim get married soon and They are really perfect for each other.
# Ich hoffe, Lily und Tim werden bald verheiratet und sie sind wirklich perfekt füreinander.
#
# 734
# translate English to German: She did not talk to me that day and I knew that something is wrong, but there was passion underneath her calm.
# Sie sprach an diesem Tag nicht mit mir und ich wusste, dass etwas falsch ist, aber es gab Leidenschaft unter ihrer Ruhe.
#
# 735
# translate English to German: I have a lot to do before I quit.
# Ich habe noch viel zu tun, bevor ich ausscheide.
#
# 736
# translate English to German: I'm new to this city, so I'm still struggling.
# Ich bin neu in dieser Stadt, also habe ich immer noch Probleme.
#
# 737
# translate English to German: the politician made a right fool of himself with all that madness on the stage and Do not think he is going to be voted for this time.
# Der Politiker hat sich mit all dem Wahnsinn auf der Bühne richtig veranlasst und glaube nicht, dass er dieses Mal gewählt werden wird.
#
# 738
# translate English to German: He has never worked in the HR department before but when the department head left unexpectedly, he took up the challenge
# Er hat nie zuvor in der Personalabteilung gearbeitet, aber als der Abteilungsleiter unerwartet verließ, nahm er die Herausforderung an.
#
# 739
# translate English to German: she acted so calm when her parents told her they were getting a divorce.
# Sie hat so ruhig gehandelt, als ihre Eltern ihr erzählten, dass sie eine Scheidung bekommen.
#
# 740
# translate English to German: I will see this project through to the end if I do so.
# Ich werde dieses Projekt bis zum Ende sehen, wenn ich das tue.
#
# 741
# translate English to German: I took the blame when the caterer did not deliver the food on time.
# Ich habe die Schuld genommen, als der Gastronom nicht rechtzeitig das Essen lieferte.
#
# 742
# translate English to German: Jennifer is the only person to interact - the rest of the group of is totally dull.
# Jennifer ist die einzige Person, die interagieren - der Rest der Gruppe von ist völlig langweilig.
#
# 743
# translate English to German: Sportsmen, as one would say, have become spiteful competitors
# Sportler sind, wie man sagen würde, zu ungeheueren Konkurrenten geworden
#
# 744
# translate English to German: When drug addicts experience a period of extreme suffering.
# Wenn Drogenabhängige eine Periode extremen Leids erleben.
#
# 745
# translate English to German: It is never advisable to run from place to place without purpose when looking for a good investment idea.
# Es ist nie ratsam, von Ort zu Stelle ohne Zweck zu laufen, wenn man nach einer guten Investitionsidee sucht.
#
# 746
# translate English to German: I don't know about all the popular words that you use.
# Ich weiß nicht über alle beliebten Wörter, die Sie verwenden.
#
# 747
# translate English to German: I completely understand that when something bad happens it will come in large quantities.
# Ich verstehe vollkommen, dass es in großen Mengen kommen wird, wenn etwas Schlechtes geschieht.
#
# 748
# translate English to German: My boss has strongly taken up for us regarding the head office's decision to stop giving bonuses.
# Mein Chef hat uns in Bezug auf die Entscheidung des Hauptsitzes, nicht mehr Bonuszahlungen zu gewähren, entschieden aufgegriffen.
#
# 749
# translate English to German: I friend had his first love affair when he was just twelve and It was just infatuation of his time, but at that time, he felt on top of the world.
# Ich war Freund seiner ersten Liebesangelegenheit, als er nur zwölf war und Es war nur Vergnügen seiner Zeit, aber zu dieser Zeit fühlte er sich auf der Spitze der Welt.
#
# 750
# translate English to German: I had asked him to calculate the possible consequences before he leapt when he was planning to buy those stocks and look what he has got himself into now!
# Ich hatte ihn gebeten, die möglichen Konsequenzen zu berechnen, bevor er vor dem Sprung gesprungen war, als er diese Aktien kaufen wollte und sich anschaute, worin er sich jetzt selbst eingestellt hat!
#
# 751
# translate English to German: Eventually the insect turned upside down and that was it.
# Das Insekt wandte sich schließlich auf den Kopf, und das war es.
#
# 752
# translate English to German: the young business tycoon and his newly married wife set up their lavish house in a luxurious villa off the beach.
# der junge Unternehmer und seine neu verheiratete Frau haben ihr luxuriöses Haus in einer luxuriösen Villa vor dem Strand eingerichtet.
#
# 753
# translate English to German: The win was marred in controversy, but the jubilant fans didn't care.
# Der Sieg war in Kontroversen gebremst, aber die jubilanten Fans haben sich nicht umhin.
#
# 754
# translate English to German: I moved on ahead with a fear of being so bad.
# Ich habe mit der Furcht, so schlecht zu sein, weiter vorangegangen.
#
# 755
# translate English to German: Start investing early and invest regularly in order to build a good foundation for the future.
# Beginnen Sie frühzeitig und investieren Sie regelmäßig, um eine gute Grundlage für die Zukunft zu schaffen.
#
# 756
# translate English to German: Throughout his career the actor has always seemed impressive.
# Während seiner Karriere schien der Schauspieler immer beeindruckend.
#
# 757
# translate English to German: He offered to pretend to be the original advocate and argue against our case so that we could find out any flaws in it.
# Er bot an, den ursprünglichen Anwalt zu behaupten und gegen unseren Fall zu streiten, damit wir eventuelle Mängel in diesem Fall herausfinden konnten.
#
# 758
# translate English to German: Though my uncle is always bungling and goofing things up, I have an emotional vulnerability for him ; he has a big heart and means well.
# Obwohl mein Onkel immer blüht und die Dinge in den Griff bekommt, habe ich eine emotionale Verwundbarkeit für ihn ; er hat ein großes Herz und bedeutet gut.
#
# 759
# translate English to German: His wife sits on his head, that is to say.
# Seine Frau sitzt auf seinem Kopf, das heißt.
#
# 760
# translate English to German: I think that he is just a person who feels like he is and does not have the strength to say what he actually feels in front of his wife.
# Ich denke, er ist nur ein Mensch, der sich wie er fühlt und nicht die Kraft hat, zu sagen, was er eigentlich vor seiner Frau fühlt.
#
# 761
# translate English to German: The teacher in this class lets no student be cruel and she has a schedule for the entire year made already and follows it very strictly.
# Die Lehrerin in dieser Klasse lässt keine Studenten grausam sein und sie hat einen Zeitplan für das ganze Jahr bereits gemacht und folgt es sehr streng.
#
# 762
# translate English to German: Sayda and Michelle sought shelter as soon as they heard the forecast of hurricane in their way.
# Sayda und Michelle suchten Unterkünfte, sobald sie die Prognose des Hurrikans in ihrem Weg hörten.
#
# 763
# translate English to German: A few days before his wedding date, James started feeling extremely nervous and finally decided to marry his girlfriend at the last minute.
# Ein paar Tage vor seinem Hochzeitsdatum fing James an, sich äußerst nervös zu fühlen und beschloss schließlich, seine Freundin in letzter Minute zu heiraten.
#
# 764
# translate English to German: A lot of meetings are held privately in order to prevent the public from knowing what is discussed.
# Viele Treffen werden privat durchgeführt, um die ffentlichkeit davon abzuhalten, was diskutiert wird.
#
# 765
# translate English to German: Amelia's ability to accurately read someone's expressions is a useful tool in her career as a psychiatrist.
# Amelias Fähigkeit, die Ausdrücke einer Person genau zu lesen, ist ein nützliches Werkzeug in ihrer Karriere als Psychiater.
#
# 766
# translate English to German: The teacher goes above and beyond for her students.
# Die Lehrerin geht über ihre Schüler hinaus.
#
# 767
# translate English to German: I always feel like I'm sick when I take that medication.
# Ich fühle mich immer krank, wenn ich diese Medikamente nehme.
#
# 768
# translate English to German: I was already getting late for work stuck in the traffic, and to make a bad situation worse, I was stopped by the police for speeding.
# Ich kam schon spät für die Arbeit im Verkehr, und um eine schlechte Situation zu verschlimmern, wurde ich von der Polizei gestoppt, um mich zu beschleunigen.
#
# 769
# translate English to German: I mother usually ends up searching every place in the house to find her keys and almost always finds it in her purse.
# Ich Mutter suche gewöhnlich jeden Ort im Haus, um ihre Schlüssel zu finden und findet sie fast immer in ihrem Geldbeutel.
#
# 770
# translate English to German: I asked my boss if I could go on a two month vacation, he said never!
# Ich fragte meinen Chef, ob ich in einen zweimonatigen Urlaub gehen könnte, sagte er nie!
#
# 771
# translate English to German: His career started off poorly when the company he joined had to shut down because of recession.
# Seine Karriere begann schlecht, als das Unternehmen, bei dem er sich beteiligte, wegen Rezession geschlossen werden musste.
#
# 772
# translate English to German: He will have one more accomplishment after he has finished this incredibly difficult assignment.
# Er wird noch eine Leistung haben, nachdem er diese unglaublich schwierige Aufgabe beendet hat.
#
# 773
# translate English to German: I friends are going for a camping trip during the weekend, but I have to help my brother with his shifting and blood relations are more important, you know.
# Ich liebe Freunde gehen für eine Camping-Tour während des Wochenendes, aber ich muss meinem Bruder bei seiner Verschiebung und Blutbeziehungen sind wichtiger, wissen Sie.
#
# 774
# translate English to German: Communities across the world have diverse traditions to celebrate the rebirth of their young ones.
# Gemeinschaften in der ganzen Welt haben verschiedene Traditionen, um die Wiedergeburt ihrer jungen Menschen zu feiern.
#
# 775
# translate English to German: Only those participating in the event have to come tomorrow and everyone needs not come.
# Nur diejenigen, die an der Veranstaltung teilnehmen, müssen morgen kommen und jeder muss nicht kommen.
#
# 776
# translate English to German: I am going to the coffee shop for a cup of coffee.
# Ich reise in den Kaffeeshop für eine Tasse Kaffee.
#
# 777
# translate English to German: That too old car is just about finished.
# Dieses zu alte Auto ist gerade fertig.
#
# 778
# translate English to German: I never said that in a negative manner, if she misunderstood then it was her job to get the statement clarified.
# Ich habe das niemals negativ gesagt, wenn sie falsch verstanden hat, dann war es ihre Aufgabe, die Erklärung zu klären.
#
# 779
# translate English to German: They need to rotate who is playing with an object.
# Sie müssen drehen, wer mit einem Objekt spielt.
#
# 780
# translate English to German: The test of the new theory would come when it is actually implemented and the results come out.
# Der Test der neuen Theorie würde kommen, wenn sie tatsächlich umgesetzt wird und die Ergebnisse herauskommen.
#
# 781
# translate English to German: I am not one to mock anybody for their appearance.
# Ich bin nicht einer, der jemanden für sein Erscheinungsbild verhöhnt.
#
# 782
# translate English to German: The biggest park in the city is just outside her door.
# Der größte Park der Stadt liegt direkt vor ihrer Tür.
#
# 783
# translate English to German: John and Susan needed to think carefully about their finances before deciding whether they could go on an overseas holiday for Christmas.
# John und Susan mussten sorgfältig über ihre Finanzen nachdenken, bevor sie entscheiden konnten, ob sie einen Auslandsurlaub für Weihnachten verbringen könnten.
#
# 784
# translate English to German: These days the houses cave in even before they are built and Such is the quality that is used today.
# Heute sind die Häuser noch vor ihrer Errichtung eingehöhlt und so ist die Qualität, die heute verwendet wird.
#
# 785
# translate English to German: I need to organize the children before they go and play in the snow.
# Ich muss die Kinder organisieren, bevor sie gehen und im Schnee spielen.
#
# 786
# translate English to German: I met my old school teacher yesterday and I was pleased to see that he was alive.
# Ich traf gestern meinen alten Schullehrer und ich war erfreut zu sehen, dass er am Leben war.
#
# 787
# translate English to German: It is difficult for the company to survive, unless the management scolds.
# Es ist schwierig für das Unternehmen zu überleben, wenn die Führung nicht schreckt.
#
# 788
# translate English to German: I have not seen you get in contact with any of these conversations so far, so what happened today?
# Ich habe bisher nicht gesehen, dass Sie mit einem dieser Gespräche in Kontakt gekommen sind, also was ist heute passiert?
#
# 789
# translate English to German: I have a new promotion at work it has been a struggle to survive.
# Ich habe eine neue Förderung am Arbeitsplatz es war ein Kampf ums Überleben.
#
# 790
# translate English to German: Martha is always in her sister's shadow, making second contact with her every time.
# Martha ist immer im Schatten ihrer Schwester und macht jedes Mal einen zweiten Kontakt mit ihr.
#
# 791
# translate English to German: I am counting on this job for my livelihood.
# Ich zähle auf diesen Arbeitsplatz für meine Existenz.
#
# 792
# translate English to German: water is coming in small bits irregularly from the pipe.
# Wasser kommt in kleinen Bits unregelmäßig aus dem Rohr.
#
# 793
# translate English to German: I am very careful about making payments for my share of food when we go out because there is nothing free.
# Ich bin sehr vorsichtig, wenn ich für meinen Anteil an Nahrungsmitteln bezahlt werde, weil es nichts Freies gibt.
#
# 794
# translate English to German: It took her a month after the accident before she was really in a high school.
# Es dauerte einen Monat nach dem Unfall, bevor sie wirklich in einer High School war.
#
# 795
# translate English to German: " Please refrain. "
# " Bitte verzichten Sie auf. "
#
# 796
# translate English to German: I father has promised to be at my hockey game tomorrow and it can only be determined at a later date whether he actually shows up.
# Ich Vater hat versprochen, morgen in meinem Hockeyspiel zu sein, und es kann erst später festgestellt werden, ob er tatsächlich auftritt.
#
# 797
# translate English to German: I have to get home immediately otherwise my parents will think I'm trying to skip curfew.
# Ich muss sofort nach Hause kommen, sonst werden meine Eltern denken, ich werde versuchen, die Fristen zu überspringen.
#
# 798
# translate English to German: John is the unguarded person in our family and He almost ended up in jail a few times when we were younger.
# John ist der unbewachte Mensch in unserer Familie, und Er kam fast ein paar Male im Gefängnis, als wir jünger waren.
#
# 799
# translate English to German: I still have not decided which phone I am going to buy and I guess it is going to be a very close call between the two new launches by the top two companies.
# Ich habe noch nicht entschieden, welches Telefon ich kaufen werde und ich vermute, dass es ein sehr enger Anruf zwischen den beiden neuen Starts der beiden Top-Unternehmen sein wird.
#
# 800
# translate English to German: They held him in high regard and were prepared to do everything they could to help him accomplish anything.
# Sie hielten ihn hoch und waren bereit, alles in ihrer Macht Stehende zu tun, um ihm dabei zu helfen, alles zu erreichen.
#
# 801
# translate English to German: The hotel we stayed in was very close to the beach.
# Das Hotel ist sehr zentral gelegen und die Mitarbeiter sind sehr freundlich.
#
# 802
# translate English to German: Drive slowly and take care not to slip on the icy roads.
# Fahren Sie langsam und achten Sie darauf, nicht auf den eisigen Straßen zu rutschen.
#
# 803
# translate English to German: I had to take such a difficult decision.
# Ich musste eine so schwierige Entscheidung treffen.
#
# 804
# translate English to German: It is unfortunate that he has been in a difficult situation that has helped him for so long and is now oversees after taking all of their money.
# Es ist bedauerlich, dass er sich in einer schwierigen Situation befindet, die ihm so lange geholfen hat und nun überwacht, nachdem er ihr gesamtes Geld eingenommen hat.
#
# 805
# translate English to German: She needs to discipline her children, they can't just throw a tantrum every time they cross the ice cream parlour.
# Sie muss ihre Kinder disziplinieren, sie können nicht nur jedes Mal ein Sprühen werfen, wenn sie die Eishalle überqueren.
#
# 806
# translate English to German: If you think you will solve the problem by following those steps, you are wasting your effort.
# Wenn Sie glauben, dass Sie das Problem durch die Einhaltung dieser Schritte lösen werden, vergeuden Sie Ihre Anstrengungen.
#
# 807
# translate English to German: When the captain arrived at dock he worked so smoothly that it was clear he knows everything.
# Als der Kapitän an den Hafen kam, arbeitete er so reibungslos, dass es klar war, dass er alles kennt.
#
# 808
# translate English to German: I am tired of spending time with my family, and it's okay.
# Ich bin müde, Zeit mit meiner Familie zu verbringen, und es ist okay.
#
# 809
# translate English to German: I have to go on a business trip darling, but we'll talk soon, I promise.
# Ich muss auf eine Geschäftsreise wagen, aber wir werden bald reden, verspreche ich.
#
# 810
# translate English to German: You can't make save money by showing up with a gift.
# Sie können kein Geld sparen, indem Sie ein Geschenk anzeigen.
#
# 811
# translate English to German: I don't think removing the director of the company in a wrong manner was a good move for your career.
# Ich denke nicht, dass die Abschaffung des Direktors der Firma auf falsche Weise ein guter Schritt für Ihre Karriere war.
#
# 812
# translate English to German: I can't figure out this mathematical equation, even though I have been working on it for days, I am just going to stop trying.
# Ich kann diese mathematische Gleichung nicht ermitteln, auch wenn ich sie seit Tagen bearbeitet habe, werde ich einfach aufhören zu versuchen.
#
# 813
# translate English to German: He makes a very persuasive point and I am tending towards voting for him.
# Er macht einen sehr überzeugenden Punkt, und ich tendiere dazu, für ihn zu stimmen.
#
# 814
# translate English to German: I often had to take short cuts when we were kids in order to feed all of us.
# Ich musste oft kurzschneiden, als wir Kinder waren, um uns alle zu ernähren.
#
# 815
# translate English to German: To her, he was a way to her.
# Für sie war er ein Weg zu ihr.
#
# 816
# translate English to German: After suffering an injury in his last match, the player was out of action for several months.
# Nachdem er in seinem letzten Spiel eine Verletzung erlitten hatte, war der Spieler mehrere Monate lang aus dem Spiel ausgeschlossen.
#
# 817
# translate English to German: I am a supporter of his aerobics techniques.
# Ich bin ein Befürworter seiner Aerobictechniken.
#
# 818
# translate English to German: I thought about buying you the groceries for the week because it made sense logically that you will need it while I am away.
# Ich dachte an den Kauf der Lebensmittel für die Woche, weil es logischerweise vernünftig war, dass Sie sie benötigen werden, während ich weg bin.
#
# 819
# translate English to German: At the end of a long trek, we were all hungry and ready to eat whatever was offered for dinner.
# Am Ende einer langen Wanderung waren wir alle hungrig und bereit, alles zu essen, was für das Abendessen angeboten wurde.
#
# 820
# translate English to German: She is so addicted to such fast food that she now she completely avoids proper meals.
# Sie ist so süchtig für solche Schnellnahrung, dass sie jetzt vollkommen vermeidet richtige Mahlzeiten.
#
# 821
# translate English to German: Don't get caught up in his speech, it's only for show.
# Nehmen Sie sich nicht in seine Rede ein, es ist nur für die Show.
#
# 822
# translate English to German: My teacher watched me carefully after she found me not paying as much attention during her lectures.
# Meine Lehrerin hat mich aufmerksam verfolgt, nachdem sie mir in ihren Vorträgen nicht so viel Aufmerksamkeit geschenkt hatte.
#
# translate English to German: Irrespective of the situation , people should hang on to their sanity .
# translate English to German: sanity.
# Vernunft.
#
# translate English to German: She is so lazy that she hardly able to make both ends meet each month . '
# translate English to German: '
# "
#
# translate English to German: Some schools prefer the carrot and stick method when it comes to education .
# translate English to German: '
# "
#
#
# translate English to German: I love staying at that hotel and They go the extra mile to make their guests happy .
# translate English to German: I love staying at that hotel and They make every possible effort to make their guests happy.
# The hotel was very clean and the staff were very helpful.
#
#
# translate English to German: It was really good to have you here and I would like to thank all of you from the bottom of my heart .
# translate English to German: I am very glad to have you here and I would like to thank you all.
# Ich bin sehr froh, Sie hier zu haben, und ich möchte Ihnen allen danken.
#
#
# translate English to German: Exams are near it's do or die people .
# translate English to German: Exams are near it's critical people.
# Die Prüfungen befinden sich in der Nähe der kritischen Menschen.

# %% [markdown]
# #### Idiomatic sentences

# %%
# Generate translations to idiomatic sentences
#T5Generate(input_data=en_id_input, input_text="input", model_type="t5-small", output_dir=path+"outputs")

# %%
# Load translations
translations_id = pd.read_csv(path+"outputs/translations_idiomatic.csv")
for i in range(len(translations_id)):
  print(i)
  print(translations_id['Input'].iloc[i])
  print(translations_id['Generated Text'].iloc[i])
  print()
# Out:
# 0
# translate English to German: I don't believe that he didn't take the money , but I will give him the benefit of the doubt until I can prove otherwise .
# Ich glaube nicht, dass er das Geld nicht genommen hat, aber ich werde ihm den Vorteil des Zweifels geben, solange ich nicht nachweisen kann.
#
# 1
# translate English to German: She manages to give her father a ballpark amount that she would need every week .
# Sie schafft es, ihrem Vater einen Ballparkbetrag zu geben, den sie jede Woche benötigen würde.
#
# 2
# translate English to German: It was really good to have you here and I would like to thank all of you from the bottom of my heart .
# Es war wirklich gut, Sie hier zu haben und ich möchte Ihnen allen von Herzen danken.
#
# 3
# translate English to German: I have seen many turning points in my life and don't believe that only one of them ever became the reason for my success .
# Ich habe viele Wendepunkte in meinem Leben gesehen und glaube nicht, dass nur einer von ihnen jemals der Grund für meinen Erfolg wurde.
#
# 4
# translate English to German: I love staying at that hotel and They go the extra mile to make their guests happy .
# Das Hotel ist sehr zentral gelegen und die Mitarbeiter sind sehr freundlich.
#
# 5
# translate English to German: Maggie was deeply in love with Stuart , so when he popped the question , she said yes without any further thought .
# Maggie liebte Stuart, und als er die Frage ansprach, sagte sie ohne weiteres Ja.
#
# 6
# translate English to German: His sense of humour often gets in the way of getting the job done .
# Sein Humor wird oft im Weg gestellt, um die Arbeit zu bewältigen.
#
# 7
# translate English to German: I wanted to turn back on my decision of moving to a new city but the fact that you spoke to me gave me the confidence to go ahead .
# Ich wollte meine Entscheidung, in eine neue Stadt zu verlegen, zurückkehren, aber die Tatsache, dass Sie mit mir gesprochen haben, gab mir das Vertrauen, voranzukommen.
#
# 8
# translate English to German: When Pete fractured his knee , it was a blessing in disguise , for he got some much needed rest and a break from his hectic work life and refocused on some important things in his life .
# Als Pete sein Knie zerstörte, war es ein Segen in der Verborgenheit, denn er bekam einige dringend benötigte Ruhe und eine Pause von seinem hektischen Arbeitsleben und widmete sich wieder auf einige wichtige Dinge in seinem Leben.
#
# 9
# translate English to German: I am going to put a sock in it until things are more finalized .
# Ich werde einen Schock in ihn setzen, bis die Dinge noch abgeschlossen sind.
#
# 10
# translate English to German: I told John that he could shave his head , over my dead body .
# Er hat sich in der Zeit des Krieges mit dem Tod befasst.
#
# 11
# translate English to German: Always be optimistic and look for the silver-lining .
# Seien Sie immer optimistisch und suchen Sie nach dem Silbernen.
#
# 12
# translate English to German: She slapped my wrist away from the cookie jar and has the whole thing to herself now .
# Sie hat mein Handgelenk vom Cookie-Gewächs entfernt und hat das Ganze nun für sich selbst.
#
# 13
# translate English to German: The retailer is not going to reduce the price of the new products but it will pay off in the long run .
# Der Händler wird den Preis für die neuen Produkte nicht senken, aber es wird sich langfristig lohnen.
#
# 14
# translate English to German: I have let the cat out of the bag , there is no point pretending that this job is working out for me .
# Ich habe die Katze aus der Tasche gelassen, es hat keinen Sinn, so zu tun, dass diese Arbeit für mich funktioniert.
#
# 15
# translate English to German: Exams are near it's do or die people .
# Die Prüfungen sind nahe es ist do oder sterben Menschen.
#
# 16
# translate English to German: It was a real call of the wild that he roughed up the cop so badly .
# Es war ein echter Aufruf der Wildnis, dass er den Cop so schlecht aufgerollt.
#
# 17
# translate English to German: He tried to explain the rules of the game to me , but it was all Greek to me .
# Er versuchte mir die Spielregeln zu erklären, aber es war für mich alles Griechisch.
#
# 18
# translate English to German: The railway minister will be as dead as a dodo when this sting operation is released by the news agency .
# Der Eisenbahnminister wird so tot sein wie ein Dodo, wenn die Nachrichtenagentur diesen Streik auf den Weg bringt.
#
# 19
# translate English to German: Before separating from family my life was a bed of roses in Australia because my Mom earns for family .
# Vor der Trennung von der Familie war mein Leben ein Bett von Rosen in Australien, weil meine Mutter verdient für die Familie.
#
# 20
# translate English to German: I like my fruits to be a cut above the rest and always go with the highest organic brands .
# Ich mag, dass meine Früchte über dem Rest geschnitten werden und immer mit den höchsten ökologischen Marken gehen.
#
# 21
# translate English to German: There is tornado coming , so batten down the hatches !
# Es gibt Tornados, so schlagen Sie die Schläge herunter!
#
# 22
# translate English to German: If you are going to attempt corporate espionage , you better have a way of getting out , else you will become a sitting duck .
# Wenn Sie Unternehmensspionage versuchen wollen, haben Sie besser eine Möglichkeit herauszukommen, sonst werden Sie zu einer sitzenden Ente.
#
# 23
# translate English to German: I have never seen you volte face before this , what is going on ?
# Ich habe Sie nie volte Gesicht vor diesem gesehen, was passiert?
#
# 24
# translate English to German: Stella is living a fool's paradise by thinking Tom is a good guy after what he did to her best friend .
# Stella ist ein Narrenparadies, indem er meint, Tom sei ein guter Mann nach dem, was er zu ihrem besten Freund getan hat.
#
# 25
# translate English to German: I have hired such nannies for my children at the drop of a dime , she is nothing special .
# Ich habe so viele Nächte für meine Kinder am Tropfen eines Dünners angeworben, sie ist nichts Besonderes.
#
# 26
# translate English to German: A good rule of thumb is to add the ingredients when the water starts to boil .
# Eine gute Faustregel ist es, die Zutaten zu fügen, wenn das Wasser anfängt zu kochen.
#
# 27
# translate English to German: The man has no experience in art and manages to burn his fingers through the purchase of fakes instead of the originals .
# Der Mann hat keine Erfahrung in der Kunst und schafft es, seine Finger durch den Kauf von Fälschungen anstelle der Originale zu verbrennen.
#
# 28
# translate English to German: My teacher has to bring up that he studied at Harvard at the beginning of every lecture .
# Mein Lehrer muss darauf hinweisen, dass er zu Beginn jeder Vortragsstunde an der Harvard-Universität studiert hat.
#
# 29
# translate English to German: The company launched the service as a dry run to understand what the customers actually want from it .
# Das Unternehmen hat den Service als Trockenlauf gestartet, um zu verstehen, was die Kunden tatsächlich von ihm wollen.
#
# 30
# translate English to German: I have been told over and over again as a child that money doesn't grow on trees .
# Als Kind wurde mir immer wieder gesagt, dass Geld nicht auf Bäumen wächst.
#
# 31
# translate English to German: Being a mom , a teacher and an athlete means I always have a lot on my plate every time .
# Als Mutter, Lehrer und Sportler habe ich immer viel auf meinem Teller.
#
# 32
# translate English to German: After reading the book of Lord Buddha's life story Steve felt black and blue throughout his soul .
# Nach dem Lesen des Buches der Lebensgeschichte von Lord Buddha fühlte Steve schwarz und blau in seiner Seele.
#
# 33
# translate English to German: I wonder if the marriage was up a blind alley from the very beginning .
# Ich frage mich, ob die Ehe von Anfang an auf einer blinden Straße war.
#
# 34
# translate English to German: To be celebrated , you have to toot your own horn .
# Um zu feiern, musst du deinen eigenen Hörner zufügen.
#
# 35
# translate English to German: I was supposed to meet my counselor for a pep talk .
# Ich sollte meinen Ratgeber für einen Pep-Talk treffen.
#
# 36
# translate English to German: It has come to pass that the dividend this year is going to be far lesser than what has been given in the previous years .
# Es ist sich herausgestellt, dass die Dividende in diesem Jahr weitaus geringer sein wird als in den vergangenen Jahren.
#
# 37
# translate English to German: After the long road trip , we were all dead tired and ready to hit the sack as soon as we reached home .
# Nach der langen Straße waren wir alle totmütig und bereit, den Sack zu schlagen, sobald wir zu Hause kamen.
#
# 38
# translate English to German: When John heard that his son and his daughter secured the first position in their final exams , it was music to his ears .
# Als John hörte, dass sein Sohn und seine Tochter die erste Position in ihren Abschlussprüfungen sicherten, war es Musik zu den Ohren.
#
# 39
# translate English to German: They could go to the museum since they are too long in the teeth to go to a discotheque .
# Sie konnten ins Museum gehen, da sie zu lange in den Zähnen sind, um eine Diskothek zu besuchen.
#
# 40
# translate English to German: The candidates comments were meant to be off the record , but the press reported it and it created a huge controversy .
# Die Kandidaten kommentierten nicht auf dem Protokoll, aber die Presse berichtete sie und führte zu einer riesigen Kontroverse.
#
# 41
# translate English to German: David knew that he would be facing difficulties , but he still entered the lion's den without any fear .
# Als er sich mit dem Löwen-Gefängnis befasst, wird er von der Sternenflotte vernichtet.
#
# 42
# translate English to German: The exams are only a month away , if you don't hit the books now , you'll surely fail .
# Die Prüfungen sind nur ein Monat entfernt, wenn Sie jetzt nicht die Bücher treffen, werden Sie sicher scheitern.
#
# 43
# translate English to German: He went out on a limb trying to support the views of his colleague and in the process earned the ire of his boss .
# Er hat sich auf einen Gliedmaßstab ausgebreitet, um die Ansichten seines Kollegen zu unterstützen und in diesem Prozess den Zorn seines Chefs verdient.
#
# 44
# translate English to German: This book covers everything from A to Z .
# Dieses Buch deckt alles von A bis Z ab.
#
# 45
# translate English to German: I have seen him smoke and bully people right from the time he was in high school and With such building blocks , what else were you expecting of his future ?
# Ich habe ihn schon von der Zeit gesehen, als er in der High School rauchte und die Menschen beschüchterte. Und mit solchen Bausteinen, was haben Sie von seiner Zukunft erwartet?
#
# 46
# translate English to German: His grandparents are set in their ways .
# Seine Großeltern sind auf ihre Weise gesetzt.
#
# 47
# translate English to German: Life is actually a learning curve and the process of achieving excellence should always continue .
# Das Leben ist eigentlich eine Lernkurve, und der Prozess des Erreichens von Exzellenz sollte immer fortgesetzt werden.
#
# 48
# translate English to German: Mothers often go through a phase of baby blues after their bundle of joy arrives .
# Muttern durchleben oft eine Phase der Babyblumen, nachdem ihr Bund von Freude ankommt.
#
# 49
# translate English to German: People living below poverty line protested against the new tax bill that favored the well-to-dos .
# Menschen, die unterhalb der Armutsgrenze leben, protestierten gegen die neue Steuergesetzgebung, die den Wohltätern zugute kam.
#
# 50
# translate English to German: People with blood on their hands do not stand a chance in our efficient justice system and they are persecuted as per their crime .
# Menschen mit Blut auf ihren Händen haben keine Chance in unserem effizienten Justizsystem und werden gemäß ihrer Verbrechen verfolgt.
#
# 51
# translate English to German: The comedian had the audience in stitches .
# Der Komponist hatte das Publikum in die Knie.
#
# 52
# translate English to German: I felt like I was on cloud nine when she said that she I loves me a lot .
# Ich fühlte mich wie ich auf der Wolke neu, als sie sagte, dass sie mich sehr liebt.
#
# 53
# translate English to German: Celebrities have a hard time keeping secrets and most of the time it is their close friends sell them out to the media .
# Prominente haben es schwer, Geheimnisse zu halten und die meisten der Zeit sind ihre engen Freunde sie an die Medien verkaufen.
#
# 54
# translate English to German: I used to be treated like a scapegoat in my team because I had less experience but I know better now .
# Ich war früher wie ein Sündenbock in meinem Team behandelt worden, weil ich weniger Erfahrung hatte, aber ich weiß jetzt besser.
#
# 55
# translate English to German: He said he will leave no stone unturned in order to prove her innocence .
# Er sagte, er werde keinen Stein hinterlassen, um ihre Unschuld zu beweisen.
#
# 56
# translate English to German: I could not account for the additional expenses at the wedding even though I added every guest's stay as well as sight-seeing .
# The room was very clean and the staff were very helpful.
#
# 57
# translate English to German: In order to win - all the team members are required to go with the flow .
# Um zu gewinnen - alle Teammitglieder müssen mit dem Fluß gehen.
#
# 58
# translate English to German: You should stop giving yourself airs , I know that you have been promoted but you are still just one of us .
# Sie sollten aufhören, sich Luft zu geben, ich weiß, dass Sie gefördert wurden, aber Sie sind immer noch nur einer von uns.
#
# 59
# translate English to German: The host made a mistake in saying out the name of the winner and instantly became a laughing stock for everyone .
# Der Host hat einen Fehler gemacht, den Namen des Gewinners auszusprechen und wurde sofort zu einem lachenden Stock für alle.
#
# 60
# translate English to German: When I was young , I had a big crush on one of the top actresses of our times .
# Als ich jung war, hatte ich einen großen Zwiebel auf eine der Top-Staatsmitglieder unserer Zeit.
#
# 61
# translate English to German: He tied the knot with his long time girlfriend in a quiet ceremony in his private farmhouse in his ancestral village .
# Er schloss den Knoten mit seiner langjährigen Freundin in einer ruhigen Zeremonie in seinem privaten Bauernhaus in seinem angestammten Dorf.
#
# 62
# translate English to German: I wish that everybody was as warm-hearted as you , Susan , it would make my life so much easier .
# Ich wünschte, dass jeder so herzlich wie Sie war, Susan, würde es mein Leben so viel einfacher machen.
#
# 63
# translate English to German: If you don't bring back my dad's car in one piece I will be in deep water .
# Wenn Sie nicht das Auto meines Vaters in einem Stück zurückbringen, werde ich im Tiefwasser sein.
#
# 64
# translate English to German: I know that you'll keep trying to make him a better person until the cows come home .
# Ich weiß, dass Sie immer versuchen werden, ihn zu einem besseren Menschen zu machen, bis die Kühe nach Hause kommen.
#
# 65
# translate English to German: I behaved like a bull in a china shop last night and I'm so sorry .
# Ich habe mich gestern Abend wie ein Stier in einem chinesischen Shop verhält und es tut mir sehr leid.
#
# 66
# translate English to German: Getting a job in USA for me is like a trip to the sun and Hence I have stopped thinking about it .
# Für mich ein Arbeitsplatz in den USA zu bekommen ist wie eine Reise zur Sonne und deshalb habe ich aufhören, darüber nachzudenken.
#
# 67
# translate English to German: It was heard through the grapevine that the captain of the team was stepping down , but the news could not be confirmed .
# Es wurde durch das Weingut angehört, dass der Kapitän des Teams zurücktritt, aber die Nachricht konnte nicht bestätigt werden.
#
# 68
# translate English to German: The assignment was very lengthy so she was forced to burn the midnight oil to get it done on time .
# Als sie die Enterprise zerstört, wird sie von der Enterprise vernichtet.
#
# 69
# translate English to German: My mom will never fall for it if I say that your parents are home and She was not born yesterday .
# Meine Mutter wird nie für es fallen, wenn ich sage, dass Ihre Eltern zu Hause sind und sie wurde gestern nicht geboren.
#
# 70
# translate English to German: I do not believe in fighting below the belt and The dignity of a fight is lost when people do that .
# Ich glaube nicht an den Kampf unter dem Gürtel, und die Würde eines Kampfes wird verloren, wenn die Menschen das tun.
#
# 71
# translate English to German: We will inform you as and when your order will be ready .
# Wir werden Sie darüber informieren, wann Ihre Bestellung fertig ist.
#
# 72
# translate English to German: I just don't have the patience to check prices with individual vendors so I go to a one stop shop for all my grocery requirements .
# Ich habe einfach nicht die Geduld, Preise mit einzelnen Verkäufern zu überprüfen, so dass ich in eine einzige Haltestelle für alle meine Lebensmittelanforderungen gehen.
#
# 73
# translate English to German: Its strange how two different people wrote about the same thing in different places and arrived at similar conclusions ! Indeed , great minds think alike .
# Es ist seltsam, dass zwei verschiedene Leute über dasselbe schrieben und zu ähnlichen Schlussfolgerungen kamen.
#
# 74
# translate English to German: Voting against the bill on reservation for the villagers of Scotland at the last minute was a real stab in the back .
# Die Ablehnung des Gesetzes über die Reservierung der Dorfbewohner in letzter Minute war ein echter Sturz im Rücken.
#
# 75
# translate English to German: I have told him over and over again that I would not be going , but he won't listen .
# Ich habe ihm immer wieder gesagt, dass ich nicht gehen würde, aber er wird nicht zuhören.
#
# 76
# translate English to German: I would like to advise you to not zip past the process and to follow the correct path to get to your destination .
# Ich möchte Ihnen empfehlen, den Prozess nicht vorbeizuziehen und den richtigen Pfad zu beschreiten, um Ihren Zielort zu erreichen.
#
# 77
# translate English to German: Sheena was feeling a bit under the weather , so she decided not to go to the movie with her friends .
# Sheena fühlte sich ein wenig unter dem Wetter, so dass sie beschloss, nicht mit ihren Freunden zum Film zu gehen.
#
# 78
# translate English to German: The criminals of this standard often fall between the cracks because neither are their crimes so severe that they are incarcerated nor are they accepted as any other person in the society .
# Die Verbrecher dieser Standardklasse fallen oft zwischen den Risse, weil ihre Verbrechen nicht so schwer wiegen, dass sie inhaftiert werden oder als andere Person in der Gesellschaft akzeptiert werden.
#
# 79
# translate English to German: Did you see Bob today ? Oh , there he comes ! Speak of the devil .
# Sie haben Bob heute gesehen, da kommt er zum Teufel.
#
# 80
# translate English to German: After a few months of dating , Joe said those three little words to his girlfriend .
# Nach ein paar Monaten der Dating, sagte Joe diese drei kleinen Worte an seine Freundin.
#
# 81
# translate English to German: Little Jon is down in the dumps because all her friends are gone away with their parents .
# Little Jon ist in den Müllen, weil alle ihre Freunde mit ihren Eltern weg sind.
#
# 82
# translate English to German: He had a major accident and had a hard time pulling himself together after that .
# Er hat einen schweren Unfall und hatte sich dann schwer, sich zusammenzuziehen.
#
# 83
# translate English to German: Tomorrow is her red letter day , she always celebrates it with a big party .
# Morgen ist ihr roter Brieftag, sie feiert es immer mit einer großen Party.
#
# 84
# translate English to German: The issue that the politician raised in his speech went down like a lead balloon with the public .
# Die Frage, die der Politiker in seiner Rede angesprochen hat, ging wie ein Bleibballon mit der ffentlichkeit herunter.
#
# 85
# translate English to German: He said he would take a rain check on visiting us today .
# Er sagte, er würde einen Regencheck auf uns heute besuchen.
#
# 86
# translate English to German: His presents may be small and humble , but I cherish them because all of them are sealed with a kiss .
# Seine Geschenke mögen klein und demütig sein, aber ich schätze sie, weil alle mit einem Kuß versiegelt sind.
#
# 87
# translate English to German: She broke the mould by being the first person in her family to go to the university .
# Sie ist die erste Person in ihrer Familie, die an der Universität studiert.
#
# 88
# translate English to German: Good grief , keep up the same work and you will end up losing your new job .
# Gute Trauer, halten Sie die gleiche Arbeit und Sie verlieren am Ende Ihren neuen Job.
#
# 89
# translate English to German: The fact that Peter did not go to medical school is a bone of contention between him and his father .
# Die Tatsache, dass Peter nicht zur medizinischen Schule ging, ist ein Knochen der Streitigkeit zwischen ihm und seinem Vater.
#
# 90
# translate English to German: From now on , both men and women will be allowed to make equal contributions to the community's fund trust .
# Von nun an werden sowohl Männer als auch Frauen gleiche Beiträge zum Fondsvertrauen der Gemeinschaft leisten können.
#
# 91
# translate English to German: My grandfather had decided to work hard until he turned 50 and then veg out and enjoy life .
# Mein Großvater hatte sich entschieden, hart zu arbeiten, bis er 50 Jahre alt war und dann ausgiebte und das Leben geniesst.
#
# 92
# translate English to German: The result of the election saw the republican candidate being snowed under by a margin of 15 to 4 .
# Der republikanische Kandidat wurde mit einer Marge von 15 bis 4 eingeschneit.
#
# 93
# translate English to German: The girl's story about her lost dog was heart touching .
# Die Geschichte des Mädchens über ihren verlorenen Hund war Herz berührend.
#
# 94
# translate English to German: Sara seems to be miles away - she must be thinking about her home .
# Sara scheint weit entfernt zu sein - sie muss über ihr Zuhause nachdenken.
#
# 95
# translate English to German: She and her husband had fallen for each other the first time they had met - at a singing competition in their neighbourhood .
# Sie und ihr Mann waren zum ersten Mal zusammengefallen - bei einem Gesangswettbewerb in ihrer Nachbarschaft.
#
# 96
# translate English to German: During an award show all the tall poppies were invited on stage to present the star of the millennium award .
# Während einer Preisausstellung wurden alle großen Poppies auf der Bühne eingeladen, um den Star des Jahrtausendpreises zu präsentieren.
#
# 97
# translate English to German: I have to be at the exam hall in 10 minutes , please come on !
# Ich muss in 10 Minuten im Prüfungsraum sein, bitte kommen Sie auf!
#
# 98
# translate English to German: I was in the cross hairs when I visited my sister while she was having a fight with her husband .
# Ich war in den Kreuzhaar, als ich meine Schwester besuchte, während sie einen Kampf mit ihrem Mann hatte.
#
# 99
# translate English to German: This is just the calm before the storm , when the kids get home from school this house will be chaos .
# Das ist nur die Ruhe vor dem Sturm, wenn die Kinder von der Schule nach Hause kommen wird dieses Haus Chaos sein.
#
# 100
# translate English to German: I understand that there's no time like the present but I have to develop this idea further before I start working on the business plan .
# Ich verstehe, dass es keine Zeit wie die Gegenwart gibt, aber ich muss diese Idee weiterentwickeln, bevor ich mit der Arbeit an dem Geschäftsplan beginnen kann.
#
# 101
# translate English to German: She loves trying different sports every year as she knows variety is the spice of life .
# Sie liebt jedes Jahr verschiedene Sportarten zu probieren, da sie weiß, dass Vielfalt das Gewürz des Lebens ist.
#
# 102
# translate English to German: The children are always jumping out of their seats and running all around , They seems to have ants in their pants .
# Die Kinder springen immer aus ihren Sitzen und laufen um sie herum, Sie haben Ameisen in ihrer Hose.
#
# 103
# translate English to German: Websites on health and fitness are a dime a dozen nowadays , but not all of them are accurate and have correct information .
# Websites über Gesundheit und Fitness sind heute ein Dutzend, aber nicht alle sind genau und haben korrekte Informationen.
#
# 104
# translate English to German: I have decided to go to London to complete my higher education come what may .
# Ich habe mich entschlossen, nach London zu gehen, um meine Hochschulausbildung zu beenden, womöglich.
#
# 105
# translate English to German: When I see him strongly supporting someone who could be his rival , I can not help but think that he has an axe to grind .
# Wenn ich sehe, dass er stark unterstützt jemanden, der sein Rival sein könnte, kann ich nicht umhin zu glauben, dass er eine Achse zu schleifen hat.
#
# 106
# translate English to German: I got him to ginger up about the vacation that I have been planning for months by showing him the itinerary .
# Ich habe ihn dazu gebracht, sich über den Urlaub zu informieren, den ich seit Monaten plant, indem ich ihm die Reiseroute vorzeige.
#
# 107
# translate English to German: I was really taken aback by her rude and childish behaviour .
# Ich war wirklich erschüttert von ihrem unhöflichen und kinderfeindlichen Verhalten.
#
# 108
# translate English to German: The prisoners are monitored round the clock by the officers .
# Die Gefangenen werden von den Offizieren rund um die Uhr überwacht.
#
# 109
# translate English to German: She promises to turn over a new leaf if we give her one more chance
# Sie verspricht, ein neues Blatt umzudrehen, wenn wir ihr noch eine Chance geben.
#
# 110
# translate English to German: Orange is the one colour that stands out anywhere .
# Orange ist die einzige Farbe, die sich überall herausstellt.
#
# 111
# translate English to German: I can not complain of the path being harsh when I walk arm in arm with you .
# Ich kann mich nicht darüber beschweren, dass der Pfad hart ist, wenn ich Arm in Arm mit Ihnen gehen.
#
# 112
# translate English to German: Leo's constant nagging certainly drives me crazy .
# Leos ständiger Nagging treibt mich sicher verrückt.
#
# 113
# translate English to German: Don't you dare hang up until I have had a chance to ask my question !
# Du wagst nicht, bis ich eine Chance hatte, meine Frage zu stellen!
#
# 114
# translate English to German: They would be gone before you can say Jack Robinson , mark my words .
# Sie wären verschwunden, bevor man Jack Robinson sagen kann, markiere meine Worte.
#
# 115
# translate English to German: I think its best for them to separate and They are no good together and are having blazing rows with each other almost every day .
# Ich denke, dass es ihr Bestes ist, sich zu trennen und sie sind nicht gut zusammen und haben fast jeden Tag blasende Streitigkeiten miteinander.
#
# 116
# translate English to German: Her daughter seems like she could not hurt a flea but she is not so in reality .
# Ihre Tochter scheint, als könne sie nicht fliehen, aber in Wirklichkeit ist sie nicht so.
#
# 117
# translate English to German: My heart goes out to all the people who lost loved ones in the terrorist attacks of yesterday .
# Mein Herz geht an alle Menschen, die bei den Terroranschlägen von gestern Angehörige verloren haben.
#
# 118
# translate English to German: I used to try to strike while the iron was hot but barely ever succeeded .
# Ich versuchte, zu stören, während die Eisen war heiß, aber kaum erfolgreich.
#
# 119
# translate English to German: It makes life easier in our department when we are all on the same page .
# Es erleichtert das Leben in unserem Abteilung, wenn wir alle auf der gleichen Seite sind.
#
# 120
# translate English to German: The Metro train arrived at five o ' clock on the dot .
# Der Bahnhof ist ziemlich zentral gelegen, aber man kann auch die Stadt mit dem Bus erreichen.
#
# 121
# translate English to German: I will listen to all of your opinions , but at the end of the day I will decide where we go on holiday .
# Ich werde alle Ihre Meinungen hören, aber am Ende des Tages werde ich entscheiden, wo wir in den Urlaub gehen.
#
# 122
# translate English to German: I had to wag the dog so that he does not find out where I had actually gone this afternoon .
# Ich musste den Hund wagn, so dass er nicht herausfindet, wo ich heute Nachmittag tatsächlich gereist war.
#
# 123
# translate English to German: It feels like I bit off more than I could chew when I promised to complete this worksheet in one day .
# Es fühlt sich an, als ob ich mehr abschluckte, als ich versprach, diese Tabelle in einem Tag zu vollenden.
#
# 124
# translate English to German: When I asked him about his progress he tried to give me a cock and bull story , but did not care to hear what he said .
# Als ich ihn über seinen Fortschritt fragte, versuchte er mir eine Hahne- und Stiergeschichte zu geben, aber kümmerte sich nicht um seine Aussagen.
#
# 125
# translate English to German: The only way I get to fail that exam is if there is an act of God because I prepared well for it .
# Der einzige Weg, um diese Prüfung zu scheitern, ist, wenn es einen Akt von Gott gibt, weil ich gut darauf vorbereitet habe.
#
# 126
# translate English to German: The new kid on the block is showing some definite potential and the boss is noticing .
# Der neue Junge auf dem Block zeigt ein gewisses Potential und der Chef bemerkt.
#
# 127
# translate English to German: I make the best of what I have because hiring people at such close proximities is no longer feasible for my business .
# Ich mache das Beste aus dem, was ich habe, weil die Einstellung von Menschen in so engen Nähen für mein Unternehmen nicht mehr möglich ist.
#
# 128
# translate English to German: All of my studying was in vain .
# Alles, was ich gelernt habe, war vergeblich.
#
# 129
# translate English to German: No one likes being as sick as a dog , that is why it is important to take care of one's self on a regular basis and eat with moderation .
# Niemand mag so krank zu sein wie ein Hund, daher ist es wichtig, sich regelmäßig um das Selbst zu kümmern und mit Mäßigung zu essen.
#
# 130
# translate English to German: I get a chill to the marrow on even passing by that building , it is just so creepy .
# Ich bekomme eine Kühlung auf dem Weg durch dieses Gebäude, es ist so schleichend.
#
# 131
# translate English to German: John says that the new cars are selling like hotcakes .
# John sagt, dass die neuen Autos verkaufen wie Hotcakes.
#
# 132
# translate English to German: Now it's calm and quiet in the house - just what the doctor ordered .
# Jetzt ist es ruhig und ruhig im Haus - genau das, was der Arzt bestellt.
#
# 133
# translate English to German: We would like to leave by mid-day and what time can you get off work on Friday ?
# Wir möchten bis Mittag abreisen und welche Zeit können Sie am Freitag aus der Arbeit fahren?
#
# 134
# translate English to German: These are turbulent times , but it must come to an end sometime and There must be some method to this madness .
# Es sind turbulente Zeiten, aber es muss irgendwann zu Ende kommen und es muss eine Methode für diesen Wahnsinn geben.
#
# 135
# translate English to German: The investigation came to a head last week when my colleague was found guilty of fraud .
# Die Untersuchung kam letzte Woche zu einem Ende, als mein Kollege für Betrügereien verantwortlich gemacht wurde.
#
# 136
# translate English to German: She came out of the closet quite late herself but now speaks about how others should make the move much sooner in their lives .
# Sie kam aus dem Schrank ziemlich spät selbst, aber jetzt spricht darüber, wie andere die Bewegung viel früher in ihrem Leben machen sollten.
#
# 137
# translate English to German: Jane always looks forward to taking official tours .
# Jane freut sich immer auf offizielle Touren.
#
# 138
# translate English to German: My first solo piano recital is tomorrow evening , I already have butterflies in my stomach and Standing in the crowd , waiting for my favourite band to take the stage , I have
# Mein erstes Solo-Piano recital ist morgen Abend, ich habe bereits Schmetterlinge in meinem Magen und Standing in der Menge, warten auf meine Lieblingsband die Bühne zu nehmen, ich habe
#
# 139
# translate English to German: I can't think about leaving my two kids at home all alone and They are just apples and oranges .
# Ich kann nicht daran denken, meine beiden Kinder allein zu Hause zu lassen und sie sind nur pfel und Orangen.
#
# 140
# translate English to German: Unless we put pedal to the metal we won't be able to submit the proposal on time .
# Wenn wir nicht auf das Metall treten, werden wir den Vorschlag nicht rechtzeitig vorlegen können.
#
# 141
# translate English to German: You think I'll get in to UCLA ? I wish !
# Sie denken, ich werde in die UCLA einsteigen - ich wünschte!
#
# 142
# translate English to German: I didn't take the news of my mom passing away too well .
# Ich habe die Nachricht, dass meine Mutter zu gut vergeht, nicht aufgenommen.
#
# 143
# translate English to German: Winning the tender for the reconstruction of Taj Mahal was the zenith of her career .
# Die Ausschreibung für den Wiederaufbau von Taj Mahal war der Zentrum ihrer Karriere.
#
# 144
# translate English to German: While cleaning out her house , Amanda found a treasure trove of childhood pictures .
# Während sie ihr Haus ausruht, entdeckt Amanda einen Schatz von Kindheitsbildern.
#
# 145
# translate English to German: If it had not been for a good Samaritan who rushed him to the hospital , the accident victim would not have been living today .
# Wenn es nicht für einen guten Samaritaner gewesen wäre, der ihn ins Krankenhaus gedrängt hatte, hätte das Unfallopfer heute nicht leben können.
#
# 146
# translate English to German: The competition in the business world today is such that it is best to keep your friends close and your enemies closer .
# Der Wettbewerb in der Geschäftswelt ist heute so, dass es am besten ist, Ihre Freunde und Feinde näher zu halten.
#
# 147
# translate English to German: In a nutshell , Mary only wants everyone to be happy and she is willing to do whatever it takes to achieve this .
# Kurz gesagt, Mary will nur alle glücklich sein, und sie ist bereit, alles zu tun, um dies zu erreichen.
#
# 148
# translate English to German: I will drop by to pick up my glasses that I left there , last weekend .
# Ich lasse vorbei, um meine Gläser zu holen, die ich dort am vergangenen Wochenende verlassen habe.
#
# 149
# translate English to German: His jokes always crack me up .
# Seine Witze knallen mich immer auf.
#
# 150
# translate English to German: It was widely expected that he would get the funding , but he missed the boat by not keeping his appointment .
# Er hat die Möglichkeit, sich mit dem Schiff zu befassen.
#
# 151
# translate English to German: Even if things have been difficult for you , always keep your chin up , everything will be normal and alright soon .
# Auch wenn es für Sie schwierig war, halten Sie immer Ihren Kinn hoch, alles wird normal und richtig bald sein.
#
# 152
# translate English to German: I know that I said I would go to the concert with you but I have had a change of heart .
# Ich weiß, dass ich sagte, ich würde zu dem Konzert mit Ihnen gehen, aber ich hatte einen Herzwechsel.
#
# 153
# translate English to German: Irrespective of the situation , people should hang on to their sanity .
# Unabhängig von der Situation sollten die Menschen an ihrer Vernunft festhalten.
#
# 154
# translate English to German: My old English teacher is your aunt ? Well , it's a small world indeed !
# Ich habe meinen alten Englischlehrer als deine Tante gesehen, aber es ist eine kleine Welt!
#
# 155
# translate English to German: I am not going to bite the dust so easily because throughout my life I have been a fighter .
# Ich werde den Staub nicht so leicht bitten, weil ich während meines Lebens Kämpfer gewesen bin.
#
# 156
# translate English to German: They will cool their heels tonight at a five star hotel to commence travelling again from morning .
# Sie kühlen heute Abend in einem 5-Sterne-Hotel, um von morgens wieder zu reisen.
#
# 157
# translate English to German: The politician said in his speech that he wanted to provide for a level playing field to the downtrodden and marginalized sections of the society .
# Der Politiker sagte in seiner Rede, er wollte gleiche Wettbewerbsbedingungen für die unterdrückten und marginalisierten Teile der Gesellschaft vorsehen.
#
# 158
# translate English to German: Her account of the fight seems far-fetched .
# Ihr Bericht über den Kampf scheint weit hergeholt zu sein.
#
# 159
# translate English to German: The meeting was adjourned followed by the staff gathering at her desk to find out what happened .
# Die Sitzung wurde unterbrochen, danach trafen sich die Mitarbeiter an ihrem Schreibtisch um herauszufinden, was passiert ist.
#
# 160
# translate English to German: In order to effectively convey the health hazards of smoking , a cigarette pack now contains a picture of diseased lungs , instead of just the statutory warning message because a picture is worth a thousand words .
# Um die gesundheitlichen Gefahren des Rauchens effektiv zu vermitteln, enthält ein Zigarettenpack jetzt ein Bild von kranken Lungen anstatt der gesetzlichen Warnung, weil ein Bild tausend Wörter wert ist.
#
# 161
# translate English to German: I better get cracking for my interview tomorrow if I want it to go well .
# Ich werde morgen knirschen, wenn ich will, dass es gut geht.
#
# 162
# translate English to German: My history teacher has a habit of harping on and on .
# Mein Geschichtslehrer hat die Gewohnheit, weiter und weiterzuharren.
#
# 163
# translate English to German: I am sure that herbal medicines will do the trick to cure your back-pain .
# Ich bin mir sicher, dass pflanzliche Arzneimittel den Trick zur Heilung Ihres Rückenschmerzes tun werden.
#
# 164
# translate English to German: His homework for the holidays is in the can although I can not guarantee he will get the best grade this time .
# Seine Hausaufgaben für den Urlaub ist in der Dose, obwohl ich nicht garantieren kann, dass er die beste Bewertung dieses Mal erhalten.
#
# 165
# translate English to German: None of the committee members like me and it's not going to be an easy meeting and If they start to bully me , I suppose I'll just have to take it on the chin .
# Keiner der Mitglieder des Ausschusses wie ich und es wird nicht leicht sein, und Wenn sie mich zu bullen beginnen, dann nehme ich an, dass ich es nur auf den Kinn nehmen muss.
#
# 166
# translate English to German: I must have to get my forty winks today since I didn't sleep well since couple of days .
# Ich muss meine vierzig Winks heute bekommen, da ich seit ein paar Tagen nicht gut schlafen konnte.
#
# 167
# translate English to German: Listen , our relationship may have real problems , but it's unfortunate that you have chosen to wash our dirty linen in public .
# Hören Sie, unsere Beziehung mag wirkliche Probleme haben, aber es ist bedauerlich, dass Sie sich entschieden haben, unsere schmutzige Leinwand in der ffentlichkeit zu waschen.
#
# 168
# translate English to German: My father can become downright cold hearted when he wants to .
# Mein Vater kann ganz kalt werden, wenn er will.
#
# 169
# translate English to German: He always comes home and stirs up a hornet's nest when his school day has not gone well .
# Er kommt immer nach Hause und stirbt ein Hornet's Nest, wenn sein Schultag nicht gut gegangen ist.
#
# 170
# translate English to German: " You can get this item for cheap , but you'll have to compromise on quality and you can not have the best of both worlds . "
# " Sie können diesen Artikel für billige, aber Sie müssen Kompromisse auf Qualität und nicht das Beste von beiden Welten haben. "
#
# 171
# translate English to German: Valarie's car was badly damaged in the accident and he was angry about what had happened , but he soon realized that there was no use crying over spilt milk .
# Valarie ist ein Mitglied der Sternenflotte.
#
# 172
# translate English to German: The hostages were in a cold sweat as they saw the hijacker pointing a gun on the air-hostess .
# Die Geiseln waren in einem kalten Schweiß, als sie sahen, dass der Entführer eine Schusswaffe auf die Luft-Hostess zeigte.
#
# 173
# translate English to German: Don't try to pull the wool over his eyes , he's too smart .
# Versuchen Sie nicht, die Wolle über seine Augen zu ziehen, er ist zu klug.
#
# 174
# translate English to German: She can barely keep the wolf from the door with the help of such a small shop in town .
# Sie kann den Wolf mit Hilfe eines so kleinen Ladens in der Stadt kaum von der Tür halten.
#
# 175
# translate English to German: I had the last straw with my lab partner when he submitted our lab report late last week .
# Ich hatte das letzte Stroh mit meinem Laborpartner, als er Ende vergangener Woche unseren Laborbericht vorlegte.
#
# 176
# translate English to German: The lawyers who attended the seminar were like birds of a feather flocking together .
# Die Anwälte, die an diesem Seminar teilnahmen, waren wie Federvögel zusammen.
#
# 177
# translate English to German: I must have the document on my desk by noon , no later .
# Ich muß das Dokument bis Mittag auf meinem Schreibtisch haben, spätestens jedoch.
#
# 178
# translate English to German: I've been eating like a horse since I've been pregnant and I know they say you're eating for two now , but this is ridiculous !
# Ich essen wie ein Pferd seit meiner Schwangerschaft und ich weiß, dass sie sagen, Sie essen jetzt für zwei, aber das ist lächerlich!
#
# 179
# translate English to German: Now that we have the management's stamp of approval , we can finally go ahead with the implementation of our ideas .
# Jetzt, da wir den Stempel der Zustimmung des Managements haben, können wir endlich die Umsetzung unserer Ideen fortsetzen.
#
# 180
# translate English to German: I do not need to learn the tricks of my trade from a has-been .
# Ich brauche nicht die Tricks meines Handels von einem Has-been zu lernen.
#
# 181
# translate English to German: It's not a good idea to stay up when you have to be in school the next day .
# Es ist keine gute Idee, auf dem Laufenden zu bleiben, wenn man am nächsten Tag in der Schule sein muss.
#
# 182
# translate English to German: It has been raining cats and dogs all day long .
# Es regnete den ganzen Tag Katzen und Hunde.
#
# 183
# translate English to German: Don't spend money like a blue blood rather save it for the future .
# Geben Sie nicht Geld wie ein blaues Blut aus, sondern sparen Sie es für die Zukunft.
#
# 184
# translate English to German: If you train harder and longer than everybody else , you'll be head and shoulders above the competition by the time the race comes around .
# Wenn man sich härter und länger als jeder andere trainiert, wird man bis zum Start des Rennens Kopf und Schulter über dem Wettbewerb stehen.
#
# 185
# translate English to German: When you are in the real estate industry then thinking avant-garde helps tremendously .
# Wenn Sie in der Immobilienbranche sind, hilft das Denken an Avantgarde enorm.
#
# 186
# translate English to German: The ancestral property became an apple of discord among the three brothers .
# Das uralte Eigentum wurde zu einem Apfel der Diskrepanz zwischen den drei Brüdern.
#
# 187
# translate English to German: Teenagers have a mind of their own and Its best to cut them some slack and let them do what they are doing instead of enforcing things on them .
# Teenager haben einen eigenen Sinn und Es ist am besten, sie etwas zu schneiden und sie tun, was sie tun, anstatt Dinge auf sie durchzusetzen.
#
# 188
# translate English to German: His recent performances are a far cry from what they used to be during his peak years .
# Seine jüngsten Auftritte sind weit von dem entfernt, was er in seinen Spitzenjahren war.
#
# 189
# translate English to German: The divorce screwed him up for a long time .
# Die Scheidung schlug ihn lange auf.
#
# 190
# translate English to German: I am mad at my boss for making me work over the long weekend and I wanted to relax with my family and
# Ich bin verrückt über meinen Chef, dass er mich über das lange Wochenende arbeiten lassen und wollte mich mit meiner Familie entspannen und
#
# 191
# translate English to German: I have already agreed to meet this guy to hear his proposal out but he did not show up in time , the ball is still in his court .
# Ich habe bereits vereinbart, diesen Kerl zu treffen, um seinen Vorschlag auszusprechen, aber er hat nicht rechtzeitig aufgetreten, der Ball ist noch in seinem Platz.
#
# 192
# translate English to German: Leaving high school has been tough but I know that the best is yet to come .
# Der Abschied von der High School war hart, aber ich weiß, dass das Beste noch kommen wird.
#
# 193
# translate English to German: The survivor , although still under shock , elaborately spoke off the cuff regarding the accident .
# Der Überlebende spricht, auch wenn er noch unter Schock steht, ausführlich von dem Unglück.
#
# 194
# translate English to German: She intends to kill as much time as possible before her parents get serious and start finding a groom for her .
# Sie beabsichtigt, so viel Zeit wie möglich zu töten, bevor ihre Eltern ernsthaft werden und anfangen, einen Gläubigen für sie zu finden.
#
# 195
# translate English to German: He has reached the crest of the wave with his new book .
# Mit seinem neuen Buch hat er den Wappen der Welle erreicht.
#
# 196
# translate English to German: I go to check on my mother's health from time to time .
# Ich werde von Zeit zu Zeit die Gesundheit meiner Mutter überprüfen.
#
# 197
# translate English to German: I always carry a baker's dozen chocolates in my purse .
# Ich habe immer ein Dutzend Schokoladenbäcker in meinem Geldbeutel.
#
# 198
# translate English to German: Doctors should try to persuade smokers to kick the habit .
# rzte sollten versuchen, Raucher zu überzeugen, die Gewohnheit zu knüpfen.
#
# 199
# translate English to German: He's had affairs with numerous women while still being married to her and He's a complete love rat .
# Er hat sich mit zahlreichen Frauen verheiratet und ist ein vollkommener Liebesrat.
#
# 200
# translate English to German: The company had gone over the top with its projections of growth in the current year .
# Das Unternehmen war mit seinen Wachstumsprognosen im laufenden Jahr über die Spitze gegangen.
#
# 201
# translate English to German: I can't believe that my husband has made me go the same place for our anniversary three years in a row and My sister has won eight tennis matches
# Ich kann nicht glauben, dass mein Mann mich für unseren Jubiläum drei Jahre in Folge an den gleichen Ort gebracht hat und meine Schwester acht Tennisspiele gewonnen hat.
#
# 202
# translate English to German: I don't think he's just a loose cannon , sometimes he really makes sense .
# Ich glaube nicht, dass er nur ein lockerer Kanon ist, manchmal macht er wirklich Sinn.
#
# 203
# translate English to German: She has gone out on the town with her friends to celebrate getting selected for the job she always wanted .
# Sie hat mit ihren Freunden auf der Stadt gereist, um zu feiern, dass sie für die Arbeit ausgewählt wurde, die sie immer wollte.
#
# 204
# translate English to German: The color that John has chosen to wear for his birthday party really knocked my socks off .
# Die Farbe, die John für seine Geburtstagsfeier tragen wollte, hat meine Socken wirklich ausgelöst.
#
# 205
# translate English to German: I fear of dying in harness before I become a soldier .
# Ich befürchte, in den Griff zu sterben, bevor ich Soldaten werde.
#
# 206
# translate English to German: Why are you so sad - who's got your goat ?
# Warum sind Sie so traurig - wer hat Ihre Ziege?
#
# 207
# translate English to German: John is such an eager beaver , nobody wants to work with him as he makes everyone else look bad .
# John ist ein so eifriger Bieter, niemand will mit ihm arbeiten, da er alle anderen schlecht aussehen lässt.
#
# 208
# translate English to German: The CEO hasn't been keeping in touch with the latest trends , so his company has gone bankrupt .
# Der CEO hat sich nicht mit den neuesten Trends in Verbindung gesetzt, so dass sein Unternehmen in Konkurs gegangen ist.
#
# 209
# translate English to German: Don't be afraid of this project , this is very easy and we can deal with it .
# Seien Sie nicht vor diesem Projekt, das ist sehr einfach und wir können damit umgehen.
#
# 210
# translate English to German: You're not helping the situation with your overcritical attitude and maybe you should take a hike .
# ...
# Das Insekt drehte sich um eine Schildkröte und das war es.
#
# 752
# translate English to German: The young business tycoon and his newly married wife set up their love nest in a luxurious villa off the beach .
# Der junge Geschäftsmann und seine neu verheiratete Frau haben ihre Liebe in einer luxuriösen Villa vor dem Strand aufgestellt.
#
# 753
# translate English to German: The win was marred in controversy , but the jubilant fans couldn't care less .
# Der Sieg war in Kontroversen geraten, aber die jubilanten Fans konnten sich nicht weniger kümmern.
#
# 754
# translate English to German: After the occurrence of such a terrible incident , I moved on ahead with a heavy heart .
# Nach dem Auftreten eines solchen schrecklichen Vorfalls ging ich mit einem schweren Herzen weiter.
#
# 755
# translate English to German: Start investing early and invest regularly in order to build a nest egg for the future .
# Beginnen Sie frühzeitig und investieren Sie regelmäßig, um ein Nestee für die Zukunft zu bauen.
#
# 756
# translate English to German: Throughout his career the actor has always seemed larger than life .
# Während seiner Karriere scheint der Schauspieler immer größer als das Leben zu sein.
#
# 757
# translate English to German: He offered to play devil's advocate and argue against our case so that we could find out any flaws in it .
# Er bot an, den Teufelsvertreter zu spielen und gegen unseren Fall zu streiten, damit wir alle Fehler in ihm herausfinden konnten.
#
# 758
# translate English to German: Though my uncle is always bungling and goofing things up , I have a soft spot for him ; he has a big heart and means well .
# Obwohl mein Onkel immer blüht und die Dinge nach oben treibt, habe ich einen weichen Platz für ihn; er hat ein großes Herz und bedeutet gut.
#
# 759
# translate English to German: His wife sits on his head , so to speak .
# Seine Frau sitzt sozusagen auf dem Kopf.
#
# 760
# translate English to German: Well , I think that he is just a yes man and does not have the strength to say what he actually feels in front of his wife .
# Nun, ich denke, dass er nur ein Ja ist und nicht die Kraft hat, zu sagen, was er eigentlich vor seiner Frau fühlt.
#
# 761
# translate English to German: The teacher in this class lets no student be fancy free and she has a schedule for the entire year made already and follows it very strictly .
# Die Lehrerin in dieser Klasse lässt keinen Studenten kostenlos sein und sie hat einen Zeitplan für das ganze Jahr bereits gemacht und folgt es sehr streng.
#
# 762
# translate English to German: Sayda and Michelle ran for cover as soon as they heard the forecast of hurricane in their way .
# Sayda und Michelle zogen um Deckung, sobald sie die Prognose des Hurrikans in ihrem Weg hörten.
#
# 763
# translate English to German: A few days before his wedding date , James started feeling extremely nervous and finally decided to leave his girlfriend at the altar .
# Als er sich in der Nähe von Paris befindet, ist er mit dem Schiff auf die Enterprise zurückgekehrt.
#
# 764
# translate English to German: A lot of meetings are held behind closed doors in order to prevent the public from knowing what is discussed .
# Viele Treffen werden hinter verschlossenen Türen abgehalten, um die ffentlichkeit davon abzuhalten, was diskutiert wird.
#
# 765
# translate English to German: Amelia's ability to accurately read someone's expressions is standing her in good stead in her career as a psychiatrist .
# Amelia ist ein Psychiater, der sich in ihrer Karriere als Psychiater aufhält.
#
# 766
# translate English to German: The teacher goes over and above for her students .
# Die Lehrerin geht über und über ihre Schüler hinaus.
#
# 767
# translate English to German: I always feel like I'm in a fog when I take that medication .
# Ich fühle mich immer in Nebel, wenn ich diese Medikamente nehme.
#
# 768
# translate English to German: I was already getting late for work stuck in the traffic , and to add insult to injury , I was stopped by the police for speeding .
# Ich bekam schon spät für die Arbeit im Verkehr gestoppt, und um zu beleidigen, wurde ich von der Polizei zur Beschleunigung gestoppt.
#
# 769
# translate English to German: My mother usually ends up searching every nook and cranny to find her keys and almost always finds it in her purse .
# Meine Mutter sucht gewöhnlich jeden Winkel und jede Kante, um ihre Schlüssel zu finden und findet es fast immer in ihrem Geldbeutel.
#
# 770
# translate English to German: I asked my boss if I could go on a two month vacation , he said when pigs fly !
# Ich fragte meinen Chef, ob ich in einen zweimonatigen Urlaub gehen könnte, sagte er, wenn Schweine fliegen!
#
# 771
# translate English to German: His career started off on the wrong foot when the company he joined had to shut down because of recession .
# Seine Karriere begann auf falschem Fuß, als das Unternehmen, bei dem er sich beteiligte, wegen Rezession geschlossen werden musste.
#
# 772
# translate English to German: He will have one more feather in his cap after he has finished this incredibly difficult assignment .
# Er wird noch eine Feder in seinem Kappen haben, nachdem er diese unglaublich schwierige Aufgabe beendet hat.
#
# 773
# translate English to German: My friends are going for a camping trip during the weekend , but I have to help my brother with his shifting and Blood is thicker than water , you know .
# Meine Freunde fahren am Wochenende für eine Campingreise, aber ich muss meinem Bruder bei seiner Verschiebung helfen und Blut ist dicker als Wasser, wissen Sie.
#
# 774
# translate English to German: Communities across the world have diverse traditions to celebrate the coming of age of their young ones .
# Gemeinden in der ganzen Welt haben verschiedene Traditionen, um das Alter ihrer jungen Menschen zu feiern.
#
# 775
# translate English to German: Only those participating in the event have to come tomorrow and All and sundry need not come .
# Nur diejenigen, die an der Veranstaltung teilnehmen, müssen morgen kommen und All und Sun nicht kommen.
#
# 776
# translate English to German: I am going to the coffee shop for a cup of joe .
# Ich werde in den Kaffeeshop für eine Tasse Joe.
#
# 777
# translate English to German: That too old car is just about done for .
# Dieses zu alte Auto ist gerade für.
#
# 778
# translate English to German: I never said that in a bad way , if she misunderstood then it was her job to get the statement clarified .
# Ich habe das nie schlecht gesagt, wenn sie falsch verstanden hat, dann war es ihre Aufgabe, die Erklärung zu klären.
#
# 779
# translate English to German: They need to take turns playing with an object .
# Sie müssen sich umdrehen, mit einem Objekt zu spielen.
#
# 780
# translate English to German: The acid test for the new theory would come when it is actually implemented and the results come out .
# Der Säuretest für die neue Theorie würde kommen, wenn sie tatsächlich umgesetzt wird und die Ergebnisse herauskommen.
#
# 781
# translate English to German: I am not one to bad-mouth anybody for their appearance .
# Ich bin nicht eins, um jemanden für sein Erscheinungsbild zu schleudern.
#
# 782
# translate English to German: The biggest park in the city is right at her doorstep .
# Der größte Park der Stadt liegt direkt vor ihrer Haustür.
#
# 783
# translate English to German: John and Susan needed to take stock of their finances before deciding whether they could go on an overseas holiday for Christmas .
# John und Susan mussten ihre Finanzen bewerten, bevor sie entscheiden konnten, ob sie einen Auslandsurlaub für Weihnachten verbringen könnten.
#
# 784
# translate English to German: These days the houses cave in even before they are built and Such is the quality that is used today .
# Heute sind die Häuser noch vor ihrer Errichtung eingehüllt, und so ist die Qualität, die heute verwendet wird.
#
# 785
# translate English to German: You need to bundle up the children before they go and play in the snow .
# Sie müssen die Kinder bündeln, bevor sie im Schnee spielen.
#
# 786
# translate English to German: I met my old school teacher yesterday and I was pleased to see that he was alive and kicking .
# Ich traf gestern meinen alten Schullehrer und ich war erfreut zu sehen, dass er lebendig und klingend war.
#
# 787
# translate English to German: It is difficult for the company to survive , unless the management pulls a rabbit out of its hat .
# Es ist schwierig für das Unternehmen zu überleben, wenn die Führung ein Kaninchen aus dem Hut zieht.
#
# 788
# translate English to German: I have not seen you get touched off with any of these conversations so far , so what happened today ?
# Ich habe nicht gesehen, dass Sie mit einem dieser Gespräche bislang berührt werden, also was passiert heute?
#
# 789
# translate English to German: With my new promotion at work it has been a struggle to keep my head above water .
# Mit meiner neuen Promotion am Arbeitsplatz war es ein Kampf, den Kopf über Wasser zu halten.
#
# 790
# translate English to German: Martha is always in her sister's shadow , playing second fiddle to her every time .
# Martha ist immer im Schatten ihrer Schwester und spielt jedes Mal zweifellos ihr zweites Fiddle.
#
# 791
# translate English to German: I am counting on this job for my bread and butter .
# Ich zähle auf diesen Job für mein Brot und Butter.
#
# 792
# translate English to German: The water is coming in dribs and drabs from the pipe .
# Das Wasser kommt in dribs und drabs aus dem Rohr.
#
# 793
# translate English to German: I am very careful about making payments for my share of food when we go out because there is no such thing as a free lunch .
# Ich habe sehr vorsichtig, wenn ich für meinen Anteil an Nahrungsmitteln bezahlt werde, weil es kein kostenloses Mittagessen gibt.
#
# 794
# translate English to German: It took her a month after the accident before she was really up and about .
# Es dauerte einen Monat nach dem Unfall, bevor sie wirklich aufgestiegen war.
#
# 795
# translate English to German: " Please button your lip . "
# " Bitte drücken Sie Ihre Lippen.
#
# 796
# translate English to German: My father has promised to be at my hockey game tomorrow and only time will tell whether he actually shows up .
# Mein Vater hat versprochen, morgen bei meinem Hockeyspiel zu sein und nur die Zeit wird sagen, ob er tatsächlich auftritt.
#
# 797
# translate English to German: I have to get home right away otherwise my parents will think I'm trying to skip curfew .
# Ich muss sofort nach Hause kommen, sonst werden meine Eltern denken, dass ich versuchen werde, die Fristen zu überspringen.
#
# 798
# translate English to German: John is the black sheep in our family and He almost ended up in jail a few times when we were younger .
# John ist die schwarze Schafe in unserer Familie und Er landete fast ein paar Male im Gefängnis, als wir jünger waren.
#
# 799
# translate English to German: I still have not decided which phone I am going to buy and I guess it is going to be toss-up between the two new launches by the top two companies .
# Ich habe immer noch nicht entschieden, welches Telefon ich kaufen werde und ich vermute, dass es zwischen den beiden neuen Starts der Top-Gesellschaften zu trennen sein wird.
#
# 800
# translate English to German: They held him in high regard and were prepared to bend over backwards to help him accomplish anything .
# Sie hielten ihn in hohem Maße und waren bereit, sich zurückzubiegen, um ihm dabei zu helfen, alles zu tun.
#
# 801
# translate English to German: The hotel we stayed in was a stone's throw away from the beach .
# Das Hotel ist sehr zentral gelegen und das Personal war sehr freundlich.
#
# 802
# translate English to German: Drive slowly and take care not to slip on the icy roads .
# Fahren Sie langsam und achten Sie darauf, nicht auf den eisigen Straßen zu rutschen.
#
# 803
# translate English to German: I had my back to the wall when I was forced to take such a difficult decision .
# Ich hatte meinen Rücken an die Wand, als ich gezwungen war, eine so schwierige Entscheidung zu treffen.
#
# 804
# translate English to German: It is unfortunate that he has bit the hand that fed him for so long and is now oversees after taking all of their money .
# Es ist bedauerlich, dass er die Hand geschlagen hat, die ihn so lange nährte und nun überwacht, nachdem er ihr gesamtes Geld genommen hat.
#
# 805
# translate English to German: She needs to discipline her children , they can't just throw a hissy fit every time they cross the ice cream parlour .
# Sie muss ihre Kinder disziplinieren, sie können nicht einfach nur ein hissy fit werfen, wenn sie die Eiscreme-Salon überqueren.
#
# 806
# translate English to German: If you think you will solve the problem by following those steps , you are barking up the wrong tree .
# Wenn Sie glauben, dass Sie das Problem durch die Befolgung dieser Schritte lösen werden, riechen Sie den falschen Baum auf.
#
# 807
# translate English to German: When the captain arrived at dock he worked so smoothly that it was clear he knows the ropes .
# Als der Kapitän an den Dock kam, arbeitete er so reibungslos, dass es klar war, dass er die Seilen kennt.
#
# 808
# translate English to German: I am tired of spending time with my family , and vice versa .
# Ich bin müde, Zeit mit meiner Familie zu verbringen und umgekehrt.
#
# 809
# translate English to German: I have to go on a business trip darling , but we'll speak soon , I promise .
# Ich muss auf eine Geschäftsreise wagen, aber wir werden in Kürze sprechen, verspreche ich.
#
# 810
# translate English to German: You can't save face by showing up with a gift .
# Sie können kein Gesicht retten, indem Sie ein Geschenk anzeigen.
#
# 811
# translate English to German: I don't think rubbing the director of the company in a wrong way was a good move for your career .
# Ich denke nicht, dass es ein guter Schritt für Ihre Karriere war, den Direktor des Unternehmens falsch zu reiben.
#
# 812
# translate English to German: I can't figure out this mathematical equation , even though I have been working on it for days , I am just going to give up .
# Ich kann diese mathematische Gleichung nicht ermitteln, auch wenn ich sie seit Tagen bearbeite, werde ich einfach aufgeben.
#
# 813
# translate English to German: He makes a very persuasive point and I am leaning towards voting for him .
# Er macht einen sehr überzeugenden Punkt, und ich möchte ihm zustimmen.
#
# 814
# translate English to German: My mom often had to cut corners when we were kids in order to feed all of us .
# Meine Mutter musste oft die Ecken schneiden, als wir Kinder waren, um uns alle zu ernähren.
#
# 815
# translate English to German: To her , he was a means to an end .
# Er war für sie ein Mittel zum Ende.
#
# 816
# translate English to German: After suffering an injury in his last match , the player was out of action for several months .
# Nach einer Verletzung in seinem letzten Spiel war der Spieler mehrere Monate lang nicht mehr aktiv.
#
# 817
# translate English to German: I am a camp follower of his aerobics techniques .
# Ich bin ein Camp-Nachfolger seiner Aerobic Techniken.
#
# 818
# translate English to German: I thought about buying you the groceries for the week because it stood to reason that you will need it while I am away .
# Ich dachte, dass Sie die Lebensmittel für die Woche kaufen, weil es zu Grunde stand, dass Sie sie brauchen, während ich weg bin.
#
# 819
# translate English to German: At the end of a long trek , we were all hungry and ready to chow down whatever was offered for dinner .
# Am Ende einer langen Wanderung waren wir alle hungrig und bereit, alles zu kneifen, was für das Abendessen angeboten wurde.
#
# 820
# translate English to German: She is so addicted to such fast food that she now she completely avoids proper meals .
# Sie ist so süchtig für solche Schnellnahrung, dass sie jetzt vollkommen vermeidet richtige Mahlzeiten.
#
# 821
# translate English to German: Don't get caught up in his speech , it's only for show .
# Nehmen Sie sich nicht in seine Rede ein, sondern nur für Show.
#
# 822
# translate English to German: My teacher kept a stern eye on me after she found me not paying as much attention during her lectures .
# Meine Lehrerin hielt mir ein scharfes Auge, nachdem sie mich bei ihren Vorträgen nicht so viel Aufmerksamkeit geschenkt hatte.

# %% [markdown]
# ## Full pipeline
#
# Load english sentences with idioms, feed into paraphrase model to get literal sentences, then feed into basic t5 for translation to german..

# %% [markdown]
# #### Paraphrase dataset

# %%
# Loading data
path = "/content/drive/MyDrive/MRP Idiom Translation/"
data = pd.read_csv(path+"data/data_idpar_test_split1.csv", sep="=")
data_en_id = data[['input']]

# %%
# Paraphrase
model_dir = "/content/drive/MyDrive/MRP Idiom Translation/outputs/id_par prefix + idiom (paraphrase model)/model 1: 50 epochs, batch 4, split 1/"
T5Generate(input_data=data_en_id, input_text="input", model_type=model_dir+"model_files", output_dir=model_dir)
# Out:
# INPUT data: (823, 1)
# Outputs generated.
# Generated data saved @ /content/drive/MyDrive/MRP Idiom Translation/outputs/id_par prefix + idiom (paraphrase model)/model 1: 50 epochs, batch 4, split 1/translations.csv

# %%
# Create input data for translation
data_para = pd.read_csv(model_dir+"translations.csv")

data_en_lit = pd.DataFrame()
data_en_lit['input'] = data_para.agg('translate English to German: {0[Generated Text]}'.format, axis=1)

# %%
# Translate
T5Generate(input_data=data_en_lit, input_text="input", model_type="t5-small", output_dir=model_dir)
# Out:
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:169: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-small automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,
# Downloading:   0%|          | 0.00/231M [00:00<?, ?B/s]
# INPUT data: (823, 1)
# Outputs generated.
# Generated data saved @ /content/drive/MyDrive/MRP Idiom Translation/outputs/id_par prefix + idiom (paraphrase model)/model 1: 50 epochs, batch 4, split 1/translations.csv

# %%
# Properly structure output file
data_translated = pd.read_csv(model_dir+"translations.csv")
data_par_test_IOB = pd.read_csv(path+'data/'+"data_test_IOB_split1.csv", sep="=")

# Clean idiom input
idiom_sents = data_para[["Input"]]
idiom_sents["Input"] = idiom_sents["Input"].apply(lambda x: re.sub("id_par sentence: ", "", x))
idiom_sents["Input"] = idiom_sents["Input"].apply(lambda x: re.sub("idiom: (.|\s)*", "", x))
data_output = pd.DataFrame({"Idiom": data_par_test_IOB['Idiom'], "Input": idiom_sents['Input'], "Paraphrased": data_para['Generated Text'], "Translated": data_translated["Generated Text"]})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_output
# Out:
#                                                  Idiom  \
# 0                             the benefit of the doubt
# 1                                      ballpark figure
# 2                          from the bottom of my heart
# 3                                        turning point
# 4                                    go the extra mile
# 5                                     pop the question
# 6                                      sense of humour
# 7                                         turn back on
# 8                               a blessing in disguise
# 9                                     put a sock in it
# 10                                   over my dead body
# 11                                       silver lining
# 12                                   slap on the wrist
# 13                                            long run
# 14                          let the cat out of the bag
# 15                                           do or die
# 16                                    call of the wild
# 17                                     all Greek to me
# 18                                      dead as a dodo
# 19                                      a bed of roses
# 20                                         a cut above
# 21                             batten down the hatches
# 22                                        sitting duck
# 23                                          volte face
# 24                                     fool's paradise
# 25                               at the drop of a dime
# 26                                       rule of thumb
# 27                                        burn fingers
# 28                                            bring up
# 29                                             dry run
# 30                         money doesn't grow on trees
# 31                                   a lot on my plate
# 32                                      black and blue
# 33                                    up a blind alley
# 34                                 toot one's own horn
# 35                                            pep talk
# 36                                        come to pass
# 37                                        hit the sack
# 38                                       music to ears
# 39                                   long in the tooth
# 40                                      off the record
# 41                                      the lion's den
# 42                                       hit the books
# 43                                    go out on a limb
# 44                                         from A to Z
# 45                                     building blocks
# 46                                         set in ways
# 47                                      learning curve
# 48                                          baby blues
# 49                                          well-to-do
# 50                                      blood on hands
# 51                                         in stitches
# 52                                          cloud nine
# 53                                    sell someone out
# 54                                           scapegoat
# 55                             leave no stone unturned
# 56                                         account for
# 57                                    go with the flow
# 58                                           give airs
# 59                                      laughing stock
# 60                                        have a crush
# 61                                        tie the knot
# 62                                        warm-hearted
# 63                                       in deep water
# 64                            until the cows come home
# 65                                bull in a china shop
# 66                                   a trip to the sun
# 67                               hear on the grapevine
# 68                               burn the midnight oil
# 69                                      born yesterday
# 70                                      below the belt
# 71                                         as and when
# 72                                       one stop shop
# 73                             great minds think alike
# 74                                    stab in the back
# 75                                 over and over again
# 76                                            zip past
# 77                                   under the weather
# 78                             fall between the cracks
# 79                                  speak of the devil
# 80                            those three little words
# 81                                   down in the dumps
# 82                              pull yourself together
# 83                                      red letter day
# 84                         go down like a lead balloon
# 85                                   take a rain check
# 86                                  sealed with a kiss
# 87                                     break the mould
# 88                                          good grief
# 89                                  bone of contention
# 90                                         from now on
# 91                                             veg out
# 92                                          snow under
# 93                                      heart touching
# 94                                          miles away
# 95                                            fall for
# 96                                          tall poppy
# 97                                             come on
# 98                                  in the cross hairs
# 99                           the calm before the storm
# 100                   there's no time like the present
# 101                       variety is the spice of life
# 102                                      ants in pants
# 103                                     a dime a dozen
# 104                                      come what may
# 105                                       axe to grind
# 106                                          ginger up
# 107                                         take aback
# 108                                    round the clock
# 109                               turn over a new leaf
# 110                                          stand out
# 111                                         arm in arm
# 112                                        drive crazy
# 113                                            hang up
# 114                   before one can say Jack Robinson
# 115                                        blazing row
# 116                             not hurt a fly or flea
# 117                                  heart goes out to
# 118                       strike while the iron is hot
# 119                                   on the same page
# 120                                         on the dot
# 121                                     end of the day
# 122                                        wag the dog
# 123                        bite off more than can chew
# 124                                cock and bull story
# 125                                         act of God
# 126                               new kid on the block
# 127                                   make the best of
# 128                                            in vain
# 129                                      sick as a dog
# 130                                chill to the marrow
# 131                                sell like hot cakes
# 132                       just what the doctor ordered
# 133                                            get off
# 134                                  method to madness
# 135                                     come to a head
# 136                                  out of the closet
# 137                                       look forward
# 138                             butterflies in stomach
# 139                                  apples to oranges
# 140                                 pedal to the metal
# 141                                           you wish
# 142                                          pass away
# 143                           zenith of career or life
# 144                                     treasure trove
# 145                                     good Samaritan
# 146    keep your friends close and your enemies closer
# 147                                      in a nutshell
# 148                                            drop by
# 149                                           crack up
# 150                                      miss the boat
# 151                                  keep your chin up
# 152                                    change of heart
# 153                                            hang on
# 154                                 it's a small world
# 155                                      bite the dust
# 156                                         cool heels
# 157                                level playing field
# 158                                        far-fetched
# 159                                          follow by
# 160                a picture is worth a thousand words
# 161                                       get cracking
# 162                                            harp on
# 163                                       do the trick
# 164                                         in the can
# 165                                take it on the chin
# 166                                        forty winks
# 167                         wash dirty linen in public
# 168                                       cold hearted
# 169                            stir up a hornet's nest
# 170                            the best of both worlds
# 171                                cry over spilt milk
# 172                                         cold sweat
# 173                            pull the wool over eyes
# 174                        keep the wolf from the door
# 175                                     the last straw
# 176                  birds of a feather flock together
# 177                                          must have
# 178                                   eat like a horse
# 179                                   seal of approval
# 180                                           has-been
# 181                                            stay up
# 182                                       all day long
# 183                                         blue blood
# 184                           head and shoulders above
# 185                                        avant-garde
# 186                                   apple of discord
# 187                                     cut some slack
# 188                                       far cry from
# 189                                           screw up
# 190                                             mad at
# 191                    the ball is in somebody's court
# 192                            the best is yet to come
# 193                                       off the cuff
# 194                                          kill time
# 195                             on the crest of a wave
# 196                                  from time to time
# 197                                      baker's dozen
# 198                                     kick the habit
# 199                                           love rat
# 200                                       over the top
# 201                                           in a row
# 202                                       loose cannon
# 203                                    out on the town
# 204                              knock one's socks off
# 205                                     die in harness
# 206                                           get goat
# 207                                       eager beaver
# 208                                           in touch
# 209                                          deal with
# 210                                        take a hike
# 211             forbidden fruit is always the sweetest
# 212                                    finishing touch
# 213                                     in the cahoots
# 214                                 start from scratch
# 215                                           heads up
# 216                           can't stand the sight of
# 217                                  against the clock
# 218                                in the nick of time
# 219                                  weak in the knees
# 220                                        on the ball
# 221                                            no dice
# 222                                    kick the bucket
# 223                                     make ends meet
# 224                                       chew the fat
# 225                                            set off
# 226                                         chill pill
# 227                                      roll the dice
# 228                                  the eleventh hour
# 229                                         take heart
# 230                                       just deserts
# 231            drastic times call for drastic measures
# 232  you can't make an omelette without breaking a ...
# 233                              raining cats and dogs
# 234                                     faint of heart
# 235                                  bear the brunt of
# 236                out of the frying pan into the fire
# 237                                    wild and woolly
# 238                                           be up on
# 239                                   running on fumes
# 240                                at sixes and sevens
# 241              throw the baby out with the bathwater
# 242                                     viper in bosom
# 243                                      blowing smoke
# 244                                no man is an island
# 245                                    pat on the back
# 246                                    at death's door
# 247                                        belly laugh
# 248                                 on the back burner
# 249                                        basket case
# 250                                 in black and white
# 251                              cost an arm and a leg
# 252                                 first things first
# 253                                  take into account
# 254                                    happy as a clam
# 255                                         time flies
# 256                                        get over it
# 257                                          scot-free
# 258                         on the tip of one's tongue
# 259                                           carry on
# 260                                      cupboard love
# 261                                        clean slate
# 262                                        next of kin
# 263                                         status quo
# 264                                rake over the coals
# 265                                go through channels
# 266                                     come a cropper
# 267                                            old hat
# 268                                   down to the wire
# 269                                   kiss and make up
# 270                              smell something fishy
# 271                                  flog a dead horse
# 272                                      clear the air
# 273                                 it's anyone's call
# 274                                         sea change
# 275                                        under siege
# 276                                          your call
# 277                            come hell or high water
# 278                                          eat words
# 279                                            deja vu
# 280                                          in a huff
# 281                                          well read
# 282                                  foam at the mouth
# 283                                     down the drain
# 284                              back against the wall
# 285                               like father like son
# 286                                            make do
# 287                                            earworm
# 288                                     household name
# 289                                    head over heels
# 290                                         make sense
# 291                                        come across
# 292                                   across the board
# 293                                   piece of writing
# 294                                love at first sight
# 295                                      self-made man
# 296                               zoom away | zoom off
# 297                                  man's best friend
# 298                                          point out
# 299                                 back to square one
# 300                                 have eyes only for
# 301                                      get on nerves
# 302                                       fall in love
# 303                            get down to brass tacks
# 304                                        on the case
# 305                               keep your nose clean
# 306                                        up the ante
# 307                                          take over
# 308                                    bird of passage
# 309                                memory like a sieve
# 310                                         hot potato
# 311                               be joined at the hip
# 312                                            all set
# 313                                         black hole
# 314                              mind your own beeswax
# 315                                          bona fide
# 316                                         call names
# 317                                   at daggers drawn
# 318                                       tight-lipped
# 319                            tar with the same brush
# 320                                          pipe down
# 321                                  as the crow flies
# 322                        keep body and soul together
# 323                                         young turk
# 324                              think outside the box
# 325                                        mend fences
# 326                                 ignorance is bliss
# 327                      kill two birds with one stone
# 328                                   chip on shoulder
# 329                                     eat humble pie
# 330                 that's the way the cookie crumbles
# 331                                      beat the heat
# 332                                           dog days
# 333                   a voice crying in the wilderness
# 334                          take with a grain of salt
# 335                                      yellow streak
# 336                                   the ball rolling
# 337                     get the wrong end of the stick
# 338                                       couch potato
# 339                                         come again
# 340                              blow your own trumpet
# 341                     when in Rome, do as the Romans
# 342                                           chime in
# 343                                    time after time
# 344                                    beyond the pale
# 345                                        high roller
# 346                               bring home the bacon
# 347                                     as easy as pie
# 348                                       fit of anger
# 349                                       scratch back
# 350                                       dig heels in
# 351                                      ups and downs
# 352                                      roaring trade
# 353                                    a piece of cake
# 354                                        free spirit
# 355                                   run out of steam
# 356                                   wild goose chase
# 357                                       quantum leap
# 358                         kick the can down the road
# 359                                           snow job
# 360                              taste of own medicine
# 361                                           speak up
# 362                                   carrot and stick
# 363                                   take for granted
# 364                                         under fire
# 365                          back to the drawing board
# 366                                         break open
# 367                                      vale of years
# 368                                wet behind the ears
# 369                                      up in the air
# 370                                     seventh heaven
# 371                                           skid row
# 372                                   save your breath
# 373                         knock on wood (touch wood)
# 374                                         in a trice
# 375                                           cry wolf
# 376                    between a rock and a hard place
# 377                           all singing, all dancing
# 378                               third time's a charm
# 379                                     necessary evil
# 380                                         a bit much
# 381                                         figure out
# 382                                           pitch in
# 383                                            stop by
# 384                                         dark horse
# 385                           fortune favours the bold
# 386                         you can't take it with you
# 387                                 have no truck with
# 388                                      dance to tune
# 389                                  drive up the wall
# 390                      put the cart before the horse
# 391                                      zero-sum game
# 392                                   in the ascendant
# 393                                           rat race
# 394                                     hands are tied
# 395                                  dollars to donuts
# 396                                    drop like flies
# 397                                     stack the deck
# 398                                    unring the bell
# 399                                 pour cold water on
# 400                              dish fit for the gods
# 401                                      neck and neck
# 402                                         for a song
# 403                                       in your face
# 404                                   turn a blind eye
# 405                                   take breath away
# 406                                    brought forward
# 407                                          in tandem
# 408                                 easy come, easy go
# 409                                      carte blanche
# 410                                 head in the clouds
# 411                                         ring fence
# 412                                          new blood
# 413                                  creme de la creme
# 414                                    dream come true
# 415                                        vent spleen
# 416                                   cross the bridge
# 417                                    drain the swamp
# 418                                      crack of dawn
# 419                                        bon appetit
# 420                             green around the gills
# 421                                       lion's share
# 422                                     speak too soon
# 423                                     cut and thrust
# 424                                           at stake
# 425                    if it ain't broke, don't fix it
# 426                                            made it
# 427                                     heart and soul
# 428                       not playing with a full deck
# 429                                      steal thunder
# 430                                        gut feeling
# 431                                  against the grain
# 432                             when hell freezes over
# 433                                      wine and dine
# 434                             let bygones be bygones
# 435                                      make light of
# 436                                     apple polisher
# 437                                       tickled pink
# 438                                        to the core
# 439                                         own accord
# 440                                     spitting image
# 441                                          field day
# 442                                            bang on
# 443                                            on edge
# 444                                      down to earth
# 445                                            head-on
# 446                                          night owl
# 447                                          knock out
# 448                                         in no time
# 449                                   sit on the fence
# 450                                        upper crust
# 451                                      beg to differ
# 452                                      double whammy
# 453                                   hive of activity
# 454                                 burst at the seams
# 455                                         love child
# 456                            accidentally on purpose
# 457                                      use your loaf
# 458                                     come down with
# 459                                            an item
# 460                                  keep your hair on
# 461                                        in the buff
# 462                                         upper hand
# 463                           go through a rough patch
# 464                                        make it big
# 465                                        class clown
# 466                               beat around the bush
# 467                                        red herring
# 468              don't put all your eggs in one basket
# 469                               beat a hasty retreat
# 470                                  dog in the manger
# 471                                         head start
# 472                                         big cheese
# 473                                    bite the bullet
# 474                                         never mind
# 475                                     see eye to eye
# 476                                        page-turner
# 477                                      up to no good
# 478                                    in high dudgeon
# 479                                          black out
# 480                                    on one's uppers
# 481                                  get to the bottom
# 482                            wouldn't be caught dead
# 483                                              so-so
# 484                                           doldrums
# 485                                          you're on
# 486                                    monkey business
# 487                                        on the mend
# 488                                    stiff upper lip
# 489                                      give the slip
# 490                                        get through
# 491                                    not give a damn
# 492                                on pins and needles
# 493                                    high on the hog
# 494                             like a bat out of hell
# 495                                            cash in
# 496                                       just in case
# 497                                          twist arm
# 498                                          sit tight
# 499                             once bitten, twice shy
# 500                                 dead as a doornail
# 501                                      pull the plug
# 502                                             leg it
# 503                                  low hanging fruit
# 504                                    tongue in cheek
# 505                                       can of worms
# 506                                         tall story
# 507                                   whole nine yards
# 508                                      foot the bill
# 509                                     pie in the sky
# 510                                    bitter medicine
# 511                      a burnt child dreads the fire
# 512                                     blind as a bat
# 513                                   paddle own canoe
# 514                                  chill to the bone
# 515                                        spin a yarn
# 516                                           dead end
# 517                             practice makes perfect
# 518                                           tick off
# 519                                 as mad as a hatter
# 520                                          pin money
# 521                                         blow cover
# 522                                           full cry
# 523                                     feel the pinch
# 524                                     get under skin
# 525                                        lovey-dovey
# 526                         throw caution to the winds
# 527                                       anything but
# 528                                       comb through
# 529                                      the better of
# 530                                           turn out
# 531                                      over the moon
# 532                                 under no illusions
# 533                                         by the way
# 534                                       tear-jerking
# 535                                        walk out on
# 536                          by the skin of your teeth
# 537                                          smack dab
# 538                                            high up
# 539                                          and so on
# 540                                           big deal
# 541                                       come up with
# 542                                    close the books
# 543                                        hard cheese
# 544              six of one, half a dozen of the other
# 545                             no room to swing a cat
# 546                             add fuel to the flames
# 547                                      fill the bill
# 548                                     walking on air
# 549                                          ride high
# 550                       pot calling the kettle black
# 551                                          cold feet
# 552                         go to hell in a handbasket
# 553                            like a hole in the head
# 554                                         better off
# 555                                           wear out
# 556                                 armed to the teeth
# 557                                        give a shot
# 558                                      full of beans
# 559                                          by chance
# 560                                    backseat driver
# 561                                          go steady
# 562                                fair-weather friend
# 563                                     labour of love
# 564                                     rise and shine
# 565                                  saved by the bell
# 566                                           go after
# 567                                         year-round
# 568                              the last thing I want
# 569                                        first light
# 570           the bigger they are the harder they fall
# 571                                        sixth sense
# 572                                       off the hook
# 573                                             catnap
# 574                                     shades of grey
# 575                                 shoot from the hip
# 576                                         in the air
# 577                                        dead ringer
# 578                                      see the light
# 579                                      hang in there
# 580                             give the devil his due
# 581                                           count on
# 582                          out of sight, out of mind
# 583                           beyond a shadow of doubt
# 584                                       tighten belt
# 585                                        have a ball
# 586                                            clam up
# 587                                         up in arms
# 588                                 to heart's content
# 589                          hide light under a bushel
# 590                              a sight for sore eyes
# 591                                  on the other hand
# 592                                  icing on the cake
# 593                                           de facto
# 594                                      vim and vigor
# 595                                betwixt and between
# 596                                    bun in the oven
# 597                      best thing since sliced bread
# 598                                    fall from grace
# 599                                          give hell
# 600                                            wind up
# 601                                        bite tongue
# 602                                       apple of eye
# 603                                        way forward
# 604                                          on a roll
# 605                                          catch eye
# 606                               spanner in the works
# 607              you can't teach an old dog new tricks
# 608                                       all the rage
# 609                                       go for broke
# 610                                         salad days
# 611                                   flash in the pan
# 612                                      pig in a poke
# 613                                           southpaw
# 614                                       on the rocks
# 615                                  haste makes waste
# 616                                       no love lost
# 617                                         lose touch
# 618                                      under a cloud
# 619                                    green with envy
# 620                                          bide time
# 621                                         shed light
# 622                                      do justice to
# 623                                      call it a day
# 624                                      put damper on
# 625                                            lie low
# 626                                          blow away
# 627                                        go out with
# 628                                       over and out
# 629                                        smell a rat
# 630                                   pain in the neck
# 631                      laughter is the best medicine
# 632                                          white lie
# 633                                       zip ones lip
# 634                            penny for your thoughts
# 635                                     play it by ear
# 636                                  too close to call
# 637                                          bump into
# 638                                     mum's the word
# 639                               at the drop of a hat
# 640                                   walk on eggshell
# 641                                           choke up
# 642                                   run amok (amuck)
# 643                   get out of bed on the wrong side
# 644                                                bug
# 645                                              doozy
# 646                                  suited and booted
# 647                                  as bald as a coot
# 648                                             to a T
# 649                                           bug-eyed
# 650                                        young blood
# 651                                 to see the back of
# 652                                       child's play
# 653                                           all ears
# 654                                    cut the mustard
# 655                           hit the nail on the head
# 656                                        filthy rich
# 657                                       quality time
# 658                             a needle in a haystack
# 659                                     spine-tingling
# 660                                            run out
# 661                                    troubled waters
# 662                                          mull over
# 663                                 castles in the air
# 664                                    on the brink of
# 665                                      cut and dried
# 666                               wear heart on sleeve
# 667                                         come clean
# 668                                   cut to the chase
# 669                               you've made your bed
# 670                                     zero tolerance
# 671                                     rags to riches
# 672                                        bucket list
# 673                                            lost on
# 674                                 knee jerk reaction
# 675                                    surgical strike
# 676                               keep at arm's length
# 677                                    fingers crossed
# 678                                     on the horizon
# 679                                       draw a blank
# 680                                   get act together
# 681                                       in the black
# 682                                   run a tight ship
# 683                                            beef up
# 684                                         in the bag
# 685                                        break a leg
# 686                                            buck up
# 687                  the squeaky wheel gets the grease
# 688                                    bits and pieces
# 689                                  race against time
# 690                                           pull leg
# 691                               blow-by-blow account
# 692                  not the sharpest tool in the shed
# 693                    straight from the horse's mouth
# 694                    everything but the kitchen sink
# 695                                       smitten with
# 696                                be in the same boat
# 697                                         not at all
# 698                                            at odds
# 699                                    crocodile tears
# 700                   burn the candle at both the ends
# 701                                skating on thin ice
# 702                                     up to the mark
# 703                                   strike the chord
# 704                                    out of the blue
# 705                                      wash hands of
# 706                           uncle Tom Cobley and all
# 707                                     cry me a river
# 708                                     shifting sands
# 709                                 tip of the iceberg
# 710                                  dead in the water
# 711                                           ward off
# 712                                        for a while
# 713                                           belly up
# 714                             through thick and thin
# 715                                           cut down
# 716                                          lose head
# 717                                     bankers' hours
# 718                                once in a blue moon
# 719                                           qui vive
# 720                                         rain check
# 721                                             on cue
# 722                                       bated breath
# 723                                whet one's appetite
# 724                           knight in shining armour
# 725                                    keen as mustard
# 726                                           rule out
# 727                             water under the bridge
# 728                                           year dot
# 729                                    in the meantime
# 730       hope for the best, but prepare for the worst
# 731                  make a mountain out of a molehill
# 732                                    in the pipeline
# 733                               match made in heaven
# 734                              still waters run deep
# 735                         miles to go before I sleep
# 736                                          find feet
# 737                                        mumbo jumbo
# 738                            throw down the gauntlet
# 739                                   cool as cucumber
# 740                        if it's the last thing I do
# 741                                     take a beating
# 742                                          live wire
# 743                                      coin a phrase
# 744                                        cold turkey
# 745                                from pillar to post
# 746                                          buzz word
# 747                            when it rains, it pours
# 748                                take up the cudgels
# 749                                         puppy love
# 750                               look before you leap
# 751                                        turn turtle
# 752                                          love nest
# 753                                 couldn't care less
# 754                                        heavy heart
# 755                                           nest egg
# 756                                   larger than life
# 757                                   devil's advocate
# 758                                   have a soft spot
# 759                                        so to speak
# 760                                            yes man
# 761                                         fancy free
# 762                                      run for cover
# 763                                 leave at the altar
# 764                                behind closed doors
# 765                              stand in a good stead
# 766                                     over and above
# 767                                           in a fog
# 768                               add insult to injury
# 769                              every nook and cranny
# 770                                      when pigs fly
# 771                              off on the wrong foot
# 772                                feather in your cap
# 773                        blood is thicker than water
# 774                                        come of age
# 775                                     all and sundry
# 776                                         cup of joe
# 777                                           done for
# 778                                       in a bad way
# 779                                         take turns
# 780                                          acid test
# 781                                          bad-mouth
# 782                                        on doorstep
# 783                                         take stock
# 784                                            cave in
# 785                                          bundle up
# 786                                  alive and kicking
# 787                       pull a rabbit out of the hat
# 788                                          touch off
# 789                                   head above water
# 790                              playing second fiddle
# 791                                   bread and butter
# 792                                    dribs and drabs
# 793              there's no such thing as a free lunch
# 794                                       up and about
# 795                                    button your lip
# 796                                     time will tell
# 797                                         right away
# 798                                        black sheep
# 799                                            toss-up
# 800                                bend over backwards
# 801                                      stone's throw
# 802                                          take care
# 803                                   back to the wall
# 804                            bite the hand that feed
# 805                                          hissy fit
# 806                             bark up the wrong tree
# 807                                     know the ropes
# 808                                         vice versa
# 809                                         speak soon
# 810                                          save face
# 811                                  rub the wrong way
# 812                                            give up
# 813                                       lean towards
# 814                                        cut corners
# 815                                    means to an end
# 816                                      out of action
# 817                                      camp follower
# 818                                   stands to reason
# 819                                          chow down
# 820                                          fast food
# 821                                           catch up
# 822                                     keep an eye on
#
#                                                  Input  \
# 0    Let's give her the benefit of the doubt and as...
# 1    The management was given a ballpark figure at ...
# ...
# 543  Die Bauarbeiter haben eine harte Zeit draußen,...
# 544                                  Das ist dasselbe.
# 545  Das Hotel ist sehr zentral gelegen und die Mit...
# 546  Die provokative Rede des Präsidentschaftskandi...
# 547  Die Person, die behauptet, er erfüllt die Anfo...
# 548  Ich bin erstaunt, seit ich herausgefunden habe...
# 549              Warum wäre das Team nicht begeistert!
# 550  Ich kann nicht glauben, dass Sie erschüttert s...
# 551  Er zögerte, als er die Nachricht von seinem Tr...
# 552  Angesichts von Korruption und Missbrauch übera...
# 553  Ich brauche einen neuen Freund ist nicht nützl...
# 554  Die Familie hat eine bessere Zeit ohne diesen ...
# 555  So abrupte Stopps wie diese werden Ihre Pausen...
# 556  Der angebliche Steuerzahler war für alle ihre ...
# 557  Ich habe nie Sushi gegessen, aber ich werde es...
# 558  Nachdem sie die guten Nachrichten hörte, war M...
# 559  Ich fand einen schönen neuen Handwerksshop dur...
# 560  Ich kann nicht stecken, dass meine Verwandten ...
# 561   Kate und Jack heiraten sich seit einigen Jahren.
# 562  Simran sucht einen loyalen Freund, nicht einen...
# 563  Jeden Morgen hat er die alte Großvateruhr, die...
# 564      Die Sonne ist hoch, steigen Sie aus dem Bett!
# 565  Der Angeklagte wurde gerettet, andernfalls hät...
# 566  Leo hat beschlossen, seine Träume mit allem zu...
# 567  Der Park bietet jedes Jahr kostenlose Nahrung ...
# 568  Der Bericht hat alle Fehler im Projekt aufgeze...
# 569  Die Suche nach den vermissten Kindern wird am ...
# 570  Der Premierminister ist sich wahrscheinlich be...
# 571  Der Mann hat einen großen Instinkt und verwalt...
# 572  Da es sich um seine erste Straftat handelte, u...
# 573  Ich hatte gestern Abend eine sehr späte Nacht,...
# 574  Tinas Geschichte an die Polizei, wie sie geris...
# 575  Selbst wenn Sie nicht mit Ihren eigenen Ideen ...
# 576  Ich spürte die Kälte in der Atmosphäre, wenn s...
# 577     Sie ist ein Blick gleich einer meiner Freunde.
# 578  Nach meinem schrecklichen Grade in Mathematik ...
# 579  Unsere Firma durchlebt schwierige Zeiten, aber...
# 580  Ich mag nicht, was das neue Management getan h...
# 581            Es ist egal, wovon Sie abhängen können.
# 582  Das ist nicht gut genug für sie, aber das ist ...
# 583  Die Regierung hat sicher klargestellt, dass di...
# 584  Ich musste weniger Geld ausgeben, seit ich mei...
# 585  Das Team hat sich auf der Corporate-Event Spaß...
# 586  Sie weigert sich, jedes Mal zu antworten, wenn...
# 587  Meine Mutter war wütend über die neuen Gehalts...
# 588  Der Mann sah am Buffet bis er zufrieden war un...
# 589  Der Mann war bescheiden, obwohl die gesamte Na...
# 590  Ich kann nicht glauben, dass ich Sie in einem ...
# 591  Es scheint ein großartiges Gebäude zu sein, im...
# 592  Die Erlangung des ersten Rangs war eine zusätz...
# 593  Englisch wird heute als die gemeinsame Sprache...
# 594  Obwohl meine Großmutter in ihren 80er Jahren i...
# 595  Das Mädchen war unentschlossen, welche ihre El...
# 596  Mark war glücklich, als seine Frau ihm erzählt...
# 597  Die Erfindung des Internets hat die Art und We...
# 598  Der Rückzug der Wirtschafts- und Finanzministe...
# 599  Dieses Büro täuscht seine Mitarbeiter, weil de...
# 600  Meine Schwester weiß wirklich, wie man sich ab...
# 601  Ich musste mich aufhalten, als Peter sagte, er...
# 602  Sie hat drei Kinder, aber ihr jüngster Sohn is...
# 603  Ich glaube, dass digitales Lernen der beste Ha...
# 604  Unser Team hat in dieser Saison elf von unsere...
# 605  Während wir auf der Straße fuhren, wurde mir e...
# 606  Der Mangel an Macht hat unsere MS-PowerPoint P...
# 607  Ich habe versucht, meine Großmutter zu lernen,...
# 608  Sie waren sehr beliebt, als sie Jugendliche wa...
# 609  Die Spieler erkannten, dass sie aus dem Wettbe...
# 610  Sie hatten sich in ihrer jüngeren Zeit getroff...
# 611  Seine ersten guten Leistungen waren ein bloßer...
# 612  Wenn Sie ein gebrauchtes Auto kaufen, ohne es ...
# 613  Die Mutter erwartete, dass ihr Kind wie sie li...
# 614         Ihre Ehe hat sehr oft gewaltige Argumente.
# 615  Versuchen Sie nicht, die Dinge zu überstürzen,...
# 616          Sie haben sich gegenseitig hassen lassen.
# 617  Michelle war mein bester Freund an der Univers...
# 618  Die Luxustransportindustrie ist momentan unter...
# 619  Sally war sehr eifersüchtig, als er mein brand...
# 620  Der große Tiger verbrachte Zeit, bis der Zebra...
# 621  Aufgrund der komplizierten Gleichungen, haben ...
# 622  Ihr Plan ist ausgezeichnet - er verleiht allen...
# 623  Weil ich nicht fertig bin, kann ich meinen Arb...
# 624    Der Regen hat heute die Picknickpläne entfernt.
# 625  Jemand in seiner Position würde sich verstecke...
# 626  Dieses neue hat eine so interessante Geschicht...
# 627  Sue und Rob hatten sich fünf Jahre lang verhei...
# 628                             Das ist alles richtig.
# 629                       Ich sah etwas nicht richtig.
# 630  Mathematik ist im Allgemeinen ein echter Schme...
# 631  Nachdem sie mehrere Stunden in guter Gesellsch...
# 632  Wenn Sie Ihrem Freund sagen, dass Sie ihren ne...
# 633  Warum nicht einfach nur ruhig, ich bin müde, d...
# 634  " Du bist seit einiger Zeit still, kann ich de...
# 635  Anstatt eine neue akademische Strategie zu ver...
# 636  Die Wahl war zu nahe, um vorherzusehen, aber w...
# 637  Bitte bewegen Sie diesen riesigen Stuhl aus de...
# 638  Wir werfen eine Party für unseren Freund Jerem...
# 639  Wir haben jetzt eine Situation, in der Gesetze...
# 640  Immer wenn Lisa um das Haus herum ist, muss je...
# 641  Er tränkt jedes Mal, wenn jemand das Thema ihr...
# 642  Da der Lehrer nicht anwesend war, waren die Ki...
# 643  Sie scheinen heute in einer sehr schlechten St...
# 644  Ich habe Ihren Bruder gebeten, Sie nicht zu st...
# 645  Es ist eine einzigartige Malerei, sie ist so k...
# 646  Die Party war gut gekleidet, um heute Abend au...
# 647  Sie ist jetzt in der Vermission, aber die Chem...
# 648  Die Ankündigung der Ankunft des Chefgasts bei ...
# 649  Ich war schockiert, wenn ich ihr Hochzeitsklei...
# 650  Das Friedenskorps braucht eine junge Generatio...
# 651  Nachdem mein Chef mein Leben zehn Jahre lang s...
# 652  Wenn Sie genug üben, wird das Fahren letztlich...
# 653  Die Kinder in meiner Klasse waren sehr interes...
# 654  Mein Nachbar hatte sich für den Posten des Arc...
# 655  Stephen hatte Recht, als er sagte, dass das Un...
# 656  Sein Vater ist reich über die Maßen hinaus, so...
# 657  Es war so lange her, dass wir in einen Urlaub ...
# 658  Es ist wie zu versuchen, einen kleinen Artikel...
# 659  Der Film hat das beängstigendste Ende, dass ma...
# 660  Wenn jemand nach mir sucht, bitte sagen Sie ih...
# 661  Die Situation verschlechterte sich, aber wie a...
# 662  Ich werde noch einmal überdenken müssen, bevor...
# 663  Sie spricht immer wieder von ihren großen Ambi...
# 664  Der Staudamm war nah, als die Beamten beschlos...
# 665      Die Regeln in unserer Schule werden geändert.
# 666  Es war offensichtlich, dass er sich mit ihr ve...
# 667  Der Kerl erzählte die Wahrheit, nachdem die Po...
# 668  Nach den üblichen Grüßen und Handshaken haben ...
# 669  Sobald Sie Ihre Entscheidung getroffen haben, ...
# 670  In diesem Unternehmen gibt es keine Toleranz g...
# 671  Er ging von sehr arm zu sehr reich, nachdem se...
# 672  Gehen Sie und kaufen Sie einige Pullover, ich ...
# 673  Sie scheint wie eine sehr kluge Frau zu sein, ...
# 674  Es war eine typische Reaktion durch Wiederholu...
# 675  Die Präzisionsschläge, die die indische Armee ...
# 676  Ich möchte meine Bürokollegen gerne in Abstand...
# 677  Viel Glück mit Ihrem Test morgen, werde ich me...
# 678  Ich habe die Art und Weise gesehen, wie Ihr Ch...
# 679  Sie müssen auf Ihre Antworten vertrauen, und u...
# 680  Der Beamte wurde gebeten, sich zu organisieren...
# 681  Die Mitarbeiter waren erschöpft, bis das Manag...
# 682  Martha ist sehr reguliert zu Hause und mit 4 K...
# 683  Google hat den Suchalgorithmus verbessert, um ...
# 684  Das Abkommen wurde schließlich nach ein paar h...
# 685  "Das Beste Glück! " rief den Bühnenregisseur v...
# 686  Die Menschen sollten lernen, nach einer großen...
# 687  Mein jüngerer Bruder bekam viel mehr Sachen vo...
# 688  Nach dem Unfall gab es kleine Teile des Wracks...
# 689  Die Fertigstellung dieses Projekts war ehrlich...
# 690  Jedes Mal, wenn wir als Freunde ausgehen, begi...
# 691  Der Kleinkind gab seiner Mutter eine detaillie...
# 692                     Er ist nicht sehr intelligent.
# 693  Ich weiß, da ich das direkt von ihnen gehört h...
# 694   Als er aus dem Haus verlegte, nahm er alles mit.
# 695     Er verliebt sich völlig mit der Liebe für sie.
# 696  Der Redner sagte, dass jeder sich für den Umwe...
# 697  Das Frühstück war sehr reichhaltig, aber die Z...
# 698  Ihr bestrahlendes Lächeln war gegenüber den Ge...
# 699  Sie täuschte ihn, als er alles in seinem Leben...
# 700  Seit Beginn meines neuen Arbeitsplatzes arbeit...
# 701  Sebastian, der alle seine Ersparnisse nutzt, u...
# 702  Leider ist diese Einsendung nicht auf das, was...
# 703  Die beiden stimmen sofort darin überein, dass ...
# 704  Ich war schockiert, ein Hirsch kam vor meinem ...
# 705  Diese Arbeit hat mir nichts Gutes gebracht, un...
# 706  Tom Cobley und alle waren im vergangenen Monat...
# 707  " Mein Baby würde gestern abend nicht schlafen...
# 708  Mein Mann hatte Schwierigkeiten, einen Arbeits...
# 709  Die Probleme der Manager-Beschäftigten in dies...
# 710  Meine Idee, auf einer Feldreise zu gehen, ist ...
# 711  Unsere Regierung hat die Zahl der Soldaten an ...
# 712  Ich werde mit Ihnen eine Zeit lang sitzen könn...
# 713  Das neue Restaurant in der Stadt wurde nach ei...
# 714  Mein bester Freund hat mich durch raue Patches...
# 715  Ich versuche in diesem Monat, Zucker zu reduzi...
# 716  Er ist in der Regel sehr ruhig und verliert se...
# 717  Mit unserem Chef im Urlaub haben die meisten v...
# 718  Das Erdbeben trifft fast jedes Mal in diesem T...
# 719  Ihre Pflicht erfordert, dass die meisten Solda...
# 720  Das Paar versprach, den Tag gemeinsam zu verbr...
# 721                     Das Rennen begann rechtzeitig.
# 722  Der Ankündiger hat die letzte Zahl auf Nervosi...
# 723  Sie haben mich dazu veranlasst, dieses zu beob...
# 724  Vielen Dank für die Befestigung meines Flachre...
# 725  Kleine Kinder sind immer daran interessiert, n...
# 726  Niemand konnte ein Medikament schaffen, das vo...
# 727  Wir hatten schon vor einigen Jahren große Mein...
# 728  Ich wohne seit langem in diesem Haus und kennt...
# 729  Die Partei bereitete sich bis dahin an einen a...
# 730  Die Tendenz heutzutage besteht darin, zu hoffe...
# 731  Sie machen einfach einen Fehler, Sie haben ein...
# 732                      Das Projekt läuft seit immer.
# 733  Jules und Nora sind perfekt füreinander und si...
# 734  Obwohl er selten in der Klasse spricht, sind r...
# 735      Ich habe noch viel zu tun, bevor ich aufhört.
# 736  Er ist noch neu in seinem Job ; geben Sie ihm ...
# 737  Ich glaube nicht an dieses frivole Ritual, das...
# 738  Was die Rechte der Tiere betrifft, so sind wir...
# 739  Dort stand er, ruhig und völlig vergessen von ...
# 740  Ich werde lernen, die Gitarre zu spielen, egal...
# 741  Der jüngere Geschwister nimmt niemals einen Ve...
# 742  John ist ein solcher Animateur ; er ist eine g...
# 743  Sie war, wie man sagen würde, so geschickt wie...
# 744  Er versuchte seit einem Jahr, auf dem Rauchen ...
# 745  Mary hat nicht eine zufrieden stellende Antwor...
# 746  Die Studenten des Colleges haben heute viele b...
# 747  Aber Sie wissen, was sie sagen, wenn es kommt,...
# 748  Das ganze Land hat die Kritik an den beiden Mä...
# 749  Die meisten Teenager sind schnell verliebt und...
# 750  Sie sollten die Kosten, die Sie während der La...
# 751  Das Auto drehte sich auf der Autobahn, als der...
# 752  Offensichtlich hatte er einen geheimen Treffpu...
# 753  Ich habe gehört, dass mein Ex-Frau eine weiter...
# 754  Er war so wütend, mussten wir die Beerdigungsz...
# 755  Der Börsenmarkt hat mir gute Renditen gegeben ...
# 756  Sein Vater ist ein großer Mann und sehr intell...
# 757  Ich stimme Ihnen zu, aber ich werde so tun, al...
# 758  Mein Bruder hatte früher einen weichen Platz f...
# 759  Ich werde Ihnen sagen, was vor sich geht, aber...
# 760  Die Tatsache, dass er ein solcher Freund ist, ...
# 761  Bis zu seiner Zeit, als sein Vater um ihn heru...
# 762  Lassen Sie uns Unterkünfte suchen, denn ich ha...
# 763  Judy wurde verwüstet, als ihr Fiesta nicht zur...
# 764  Der Planungsgremium der Finanzabteilung trifft...
# 765  Seine langjährige Erfahrung im Englischen hat ...
# 766  Feuerwehrleute gehen immer über die Grenzen hi...
# 767               Jane scheint immer verwirrt zu sein.
# 768  Das Unternehmen lehnte seinen Antrag auf einen...
# 769  Die Anwälte durchsuchten alle Gebiete des Land...
# 770  Ihre verrückte Mutter sagte, dass Megan so fau...
# 771  Ihre Beziehungen begannen schlecht, als sie ei...
# 772  Ruth hat das letzte Tor für ihr Team erreicht,...
# 773  Wenn Sie in Schwierigkeiten geraten, wird Ihre...
# 774  Nach Jahren der Experimentation mit Farben und...
# 775  Ich möchte nicht, dass jeder über unsere Unter...
# 776  Wenn ich morgens aufwache, dann mache ich mich...
# 777  Das Abkommen ist immer wieder, ich werde nicht...
# 778  Der Lehrer hat es nicht in mittelbarer Weise g...
# 779  Ich verstehe, dass jeder versuchen will, zu fa...
# 780  Er spielte gut im letzten Spiel, aber der hart...
# 781  Die sozialen Parteien in diesem Bereich sind n...
# 782  Das Beste an einem Haus in dieser Gesellschaft...
# 783  Bevor er sich entscheidet, welchen Job er über...
# 784  Das Gebäude zerstörte sich selbst, nachdem es ...
# 785  Es ist wichtig, sich zu erwärmen, bevor Sie au...
# 786  Sie hatte ihre jüngere Schwester nach ihrer Eh...
# 787  Das Team verlor bis zum Ende, aber plötzlich g...
# 788  Die Präsentation hat einen sehr wichtigen Punk...
# 789  Ich muss 60 Stunden pro Woche arbeiten, um mei...
# 790  Sheila war entschlossen, der Star der Show zu ...
# 791  Die Person hängt von Ihnen für sein Brot und B...
# 792  Die Kontrollen für die Wohltätigkeitsorganisat...
# 793                      Es gibt nichts ist kostenlos.
# 794  Er war innerhalb weniger Tage nach der Operati...
# 795  " Sein kontinuierliches Sprechen macht mich wü...
# 796  Ich glaube nicht, dass er für seinen Test stud...
# 797  Ich verspreche, meine Hausaufgaben sofort zu v...
# 798  Ich war immer die unpopuläre Person meiner Fam...
# 799  Am Ende war es ein unerreichbares Verhältnis z...
# 800  Die Banken tun alles, um den Einlegern Einrich...
# 801  Sein Arbeitsplatz ist nur wenige Schritte von ...
# 802  Stellen Sie sicher, dass Sie sich nicht auf di...
# 803  Sie haben ihn in Schwierigkeiten, und jetzt ha...
# 804  Die Strategien der Staatsregierung sind nicht ...
# 805  Ein Sprichwort ist nicht nur gerechtfertigt, u...
# 806  Es war ein sehr heikler Fall, und dennoch habe...
# 807  Sie arbeitet hier seit 30 Jahren und weiß alle...
# 808  Ich mag den neuen Mann meiner Schwester nicht,...
# 809  Vielen Dank für Ihre Hilfe Sandra, sprechen Si...
# 810  Ich konnte Korrekturen vornehmen, indem ich üb...
# 811  Der Kerl hat mich in einem so schlechten Licht...
# 812  John war so müde, den Ofen zu fixieren, dass e...
# 813  Ich bin mir nicht sicher, welche Couch in unse...
# 814  Es ist sicherlich kein vernünftiger Schritt, s...
# 815  Ihre Arbeit als öffentliche Verteidigerin war ...
# 816  Ich fürchte, ich kann Ihnen nicht sagen, die K...
# 817  Das einzige Problem, mit einer Prominenten ver...
# 818  Das Unternehmen stimmt zu, dass das Projekt mi...
# 819  Ich bin hungrig und bereit, alles zu essen, wa...
# 820  Nina liebt Französische Pommes und andere Fast...
# 821  Ich war so besessen von der Schönheit der Kuns...
# 822  Die Polizei hat immer die Top-Störer der Stadt...

# %%
# Save results
data_output.to_csv(model_dir+"translations_para.csv")

# %% [markdown]
# #### Comparison test set

# %%
# Load comparison
path= "/content/drive/MyDrive/MRP Idiom Translation/data/"
data = pd.read_csv(path+"comparison_data.csv")

# %%
# Prepare for paraphrasing
data_en_id = pd.DataFrame()
data_en_id['input'] = data.agg('id_par sentence: {0[input]} idiom: {0[idiom]}'.format, axis=1)

# %%
# Check max length
lengths_data = data_en_id["input"].str.split(" ")

print("Max number of tokens input = ", lengths_data.str.len().max())
# Out:
# Max number of tokens input =  95

# %%
# Paraphrase
model_dir = "/content/drive/MyDrive/MRP Idiom Translation/outputs/id_par prefix + idiom (paraphrase model)/model 1: 50 epochs, batch 4, split 1/"
T5Generate(input_data=data_en_id, input_text="input", model_type=model_dir+"model_files", output_dir=model_dir)
# Out:
# INPUT data: (122, 1)
# Outputs generated.
# Generated data saved @ /content/drive/MyDrive/MRP Idiom Translation/outputs/id_par prefix + idiom (paraphrase model)/model 1: 50 epochs, batch 4, split 1/translations.csv

# %%
# Create input data for translation
data_para = pd.read_csv(model_dir+"translations.csv")

data_en_lit = pd.DataFrame()
data_en_lit['input'] = data_para.agg('translate English to German: {0[Generated Text]}'.format, axis=1)

# %%
# Translate
T5Generate(input_data=data_en_lit, input_text="input", model_type="t5-small", output_dir=model_dir)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:169: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-small automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,
# INPUT data: (122, 1)
# Outputs generated.
# Generated data saved @ /content/drive/MyDrive/MRP Idiom Translation/outputs/id_par prefix + idiom (paraphrase model)/model 1: 50 epochs, batch 4, split 1/translations.csv

# %%
# Properly structure output file
data_translated = pd.read_csv(model_dir+"translations.csv")

# Clean idiom input
idiom_sents = data_para[["Input"]]
idiom_sents["Input"] = idiom_sents["Input"].apply(lambda x: re.sub("id_par sentence: ", "", x))
idiom_sents["Input"] = idiom_sents["Input"].apply(lambda x: re.sub("idiom: (.|\s)*", "", x))
data_output = pd.DataFrame({"Idiom": data['idiom'],"Input": idiom_sents['Input'], "Paraphrased": data_para['Generated Text'], "Translated": data_translated["Generated Text"]})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
data_output
# Out:
#                                 Idiom  \
# 0                     head over heels
# 1               a sight for sore eyes
# 2                       in a nutshell
# 3            beyond a shadow of doubt
# 4       kill two birds with one stone
# 5               think outside the box
# 6                   go the extra mile
# 7                     bite the bullet
# 8                           take care
# 9                       pig in a poke
# 10                   the ball rolling
# 11             pull yourself together
# 12                    head over heels
# 13                    head over heels
# 14              a sight for sore eyes
# 15              a sight for sore eyes
# 16                      in a nutshell
# 17                      in a nutshell
# 18                      in a nutshell
# 19                      in a nutshell
# 20                      in a nutshell
# 21                      in a nutshell
# 22                      in a nutshell
# 23                      in a nutshell
# 24                      in a nutshell
# 25                      in a nutshell
# 26                      in a nutshell
# 27                      in a nutshell
# 28                      in a nutshell
# 29                      in a nutshell
# 30                      in a nutshell
# 31                      in a nutshell
# 32                      in a nutshell
# 33                      in a nutshell
# 34                      in a nutshell
# 35                      in a nutshell
# 36                      in a nutshell
# 37                      in a nutshell
# 38                      in a nutshell
# 39                      in a nutshell
# 40                      in a nutshell
# 41                      in a nutshell
# 42                      in a nutshell
# 43                      in a nutshell
# 44                      in a nutshell
# 45                      in a nutshell
# 46                      in a nutshell
# 47                      in a nutshell
# 48                      in a nutshell
# 49                      in a nutshell
# 50                      in a nutshell
# 51                      in a nutshell
# 52                      in a nutshell
# 53                      in a nutshell
# 54                      in a nutshell
# 55                      in a nutshell
# 56                      in a nutshell
# 57                      in a nutshell
# 58                      in a nutshell
# 59                      in a nutshell
# 60                      in a nutshell
# 61                      in a nutshell
# 62                      in a nutshell
# 63                      in a nutshell
# 64                      in a nutshell
# 65                      in a nutshell
# 66                      in a nutshell
# 67                      in a nutshell
# 68                      in a nutshell
# 69                      in a nutshell
# 70                      in a nutshell
# 71                      in a nutshell
# 72                      in a nutshell
# 73                      in a nutshell
# 74                      in a nutshell
# 75                      in a nutshell
# 76                      in a nutshell
# 77                      in a nutshell
# 78                      in a nutshell
# 79                      in a nutshell
# 80                      in a nutshell
# 81         beyond a shadow of a doubt
# 82         beyond a shadow of a doubt
# 83   to kill two birds with one stone
# 84   to kill two birds with one stone
# 85           to think outside the box
# 86               to go the extra mile
# 87               to go the extra mile
# 88               to go the extra mile
# 89               to go the extra mile
# 90               to go the extra mile
# 91                 to bite the bullet
# 92                        take care !
# 93                        take care !
# 94                        take care !
# 95                        take care !
# 96                        take care !
# 97                        take care !
# 98                        take care !
# 99                        take care !
# 100                       take care !
# 101                       take care !
# 102                       take care !
# 103                       take care !
# 104                       take care !
# 105                       take care !
# 106                       take care !
# 107                       take care !
# 108            to buy a pig in a poke
# 109            to buy a pig in a poke
# 110            to buy a pig in a poke
# 111            to buy a pig in a poke
# 112            to buy a pig in a poke
# 113           to get the ball rolling
# 114           to get the ball rolling
# 115                  to pull together
# 116                  to pull together
# 117                  to pull together
# 118                  to pull together
# 119                  to pull together
# 120                  to pull together
# 121                  to pull together
#
#                                                  Input  \
# 0    Tom and Mary are head over heels in love with ...
# 1    I can't believe that I haven't seen you in a y...
# 2    In a nutshell , all the new mayor was saying i...
# 3    The government has clarified beyond a shadow o...
# 4    I have to go to the bank , and on the way back...
# 5    The team always thinks outside the box to come...
# 6    When it comes to weaker students , the teacher...
# 7    When the time comes , I'll bite the bullet and...
# 8    Take care not to cut yourself on that rusty pi...
# 9    If you buy a used car without examining it tho...
# 10   The ball was rolling when he struck that first...
# 11   I know its difficult to get over your loss , b...
# 12   Sook seems to be head over heels in love with ...
# 13   He first encountered the tin whistle as a yout...
# 14   In most Dalmatian towns the market is a sight ...
# 15   The Glorious DJ furniture line is a sight for ...
# 16   In a nutshell , we are working towards a recog...
# 17   Let us see , in a nutshell , the most importan...
# 18                 The Czech Republic in a nutshell .
# 19   As regards future objectives , in a nutshell ,...
# 20   In a nutshell : there were programmes being ru...
# 21   In a nutshell , our mission is to provide our ...
# 22   In a nutshell , this means strict adherence to...
# 23   Indeed , that , in a nutshell , is the story o...
# 24   In a nutshell , patients should be allowed to ...
# 25   In a nutshell it is the understanding that whi...
# 26   In a nutshell , Commissioner , you can count o...
# 27   This , to put it in a nutshell , is the busine...
# 28   In a nutshell , this is the ECB ’ s situation ...
# 29   In a nutshell , the child must learn how to le...
# 30   In a nutshell : the implosion of the brave new...
# 31   There you see the European crisis in a nutshel...
# 32   In a nutshell , the cost of our work to improv...
# 33   In a nutshell , I would say that maritime acti...
# 34   In a nutshell , I can say that , in spite of t...
# 35   In a nutshell , our regulatory system to comba...
# 36   In a nutshell , this is the most important par...
# 37   In a nutshell , the ECF ’ s conclusion is that...
# 38   In a nutshell , this report is a fine example ...
# 39   In a nutshell , Commissioner , Europe 's futur...
# 40   In a nutshell , H.264 is suited to any platfor...
# 41   I get the impression that no one is questionin...
# 42   These are , in a nutshell , the motives underl...
# 43   In a nutshell , I would like to reiterate the ...
# 44   Holders are also granted priority parking at s...
# 45   In a nutshell , I am pleased that the Commissi...
# 46   In a nutshell , our joint efforts have resulte...
# 47   This , in a nutshell , provided the main impet...
# 48   In a nutshell , Web-to-print is the dynamic ge...
# 49   In a nutshell , Keynes struggled against the n...
# 50         Discover our pages Belgium in a nutshell !
# 51   In a nutshell , guaranteeing EU citizens ' sec...
# 52   At our bank , it denotes experienced and ackno...
# 53   In a nutshell , they must enshrine all the val...
# 54   In a nutshell , the single currency can only l...
# 55   In a nutshell – a professional drill that coul...
# 56   That , in a nutshell , is what the Fed and the...
# 57   In a nutshell , HAL allows to set the exact sa...
# 58   Entrust yourself to our masseur . In a nutshel...
# 59   In a nutshell : everyone ’ s taste will be sat...
# 60   So , that ’ s in a nutshell how this model of ...
# 61   In a nutshell : it does have its advantages , ...
# 62   But it is more than justified . To put it in a...
# 63   Important financial figures of Q-Cells in a nu...
# 64   This will perhaps allow us to fight together s...
# 65   In a nutshell , we need to invest less in asph...
# 66   In a nutshell , you are always welcome from 07...
# 67   In a nutshell , Commissioner , the objective o...
# 68   In a nutshell , this is an attack on our world...
# 69       That is the social situation in a nutshell .
# 70   This is the Roma issue with all its intricacie...
# 71   In a nutshell , it is a retrograde , ill-thoug...
# 72   In a nutshell , we believe that those who view...
# 73   In a nutshell , public health and consumer pro...
# 74   In a nutshell , you are always welcome from 07...
# 75   In a nutshell , the legislative proposal under...
# 76   In a nutshell , this depends on a strong Europ...
# 77                That is the problem in a nutshell .
# 78   To put it in a nutshell , Europe has worked ag...
# 79   To put it in a nutshell , we are beginning to ...
# 80   In a nutshell , the report fails really to tac...
# 81   The annual campaigns since 1995 have brought n...
# 82   I think it has emerged beyond a shadow of a do...
# 83   This morning , the European Parliament sought ...
# 84   Have you decided to kill two birds with one st...
# 85               We needed to think outside the box .
# 86   However , I should also like to see the Counci...
# 87   However , ladies and gentlemen , it is importa...
# 88   You are self-motivated and willing to go the e...
# 89   I would like to urge the European Union govern...
# 90   Their outstanding traits are their high level ...
# 91   Member States must bite the bullet and be prep...
# 92          We take special care of the little ones !
# 93   It is a good practice to pre-load the output b...
# 94   Take care , all data on your pc will be delete...
# 95   While you ’ ll relax we will take care of all ...
# 96   For orders above € 100,00 we will take care of...
# 97   All Inclusive offers you and your family excel...
# 98   Either you choose for a Low budget- or a custo...
# 99   Enjoy your stay - we ’ ll take care of the res...
# 100  The families affected by new variant Creutzfel...
# 101  A wedding with a difference  let us take care...
# 102      We will take care for your perfect holiday !
# 103  In our five Austrian lounges ( two Business Lo...
# 104  Your company : Talk to us and we take care of ...
# 105  Let our professional team take care of everyth...
# 106  You simply cash the product from your site , s...
# 107  This is the custom . It is perhaps not justifi...
# 108             Nobody wants to buy a pig in a poke .
# 109     The Council wants us to buy a pig in a poke .
# 110  The electorate , I am convinced , will not be ...
# 111  And then I will also have to tell my constitue...
# 112  We are effectively being asked to buy the bovi...
# 113  It didn 't take long to get the ball rolling w...
# 114  These are all good suggestions to get the ball...
# 115  I should like Parliament to pull itself togeth...
# 116  National strategies alone will not produce cut...
# 117  Through this vote , we are calling on the Lith...
# 118  Now I am asking the Commission and the Council...
# 119  Mr Herman called on us to pull ourselves toget...
# 120  Now it is time , however , to pull ourselves t...
# 121  Fortunately , today we know that children who ...
#
#                                            Paraphrased  \
# 0    Tom and Mary are deeply in love with each othe...
# 1    I can't believe that I haven't seen you in a y...
# 2    I am certain that all the new mayor was saying...
# 3    The government has clarified for certain that ...
# 4    I have to go to the bank, and on the way back,...
# 5    The team always thinks of solutions out of the...
# 6    When it comes to weaker students, the teacher ...
# 7    When the time comes, I'll be quick and take my...
# 8    Take care not to cut yourself on that rusty pi...
# 9    If you buy a used car without examining it tho...
# 10   The first conversation with her, she could not...
# 11   I know its difficult to get over your loss, bu...
# 12   Sook seems to be deeply in love with her, but ...
# 13   He first encountered the tin whistle as a yout...
# 14   In most Dalmatian towns the market is good-loo...
# 15   The Glorious DJ furniture line is great for an...
# 16   I am quick to say, we are working towards a re...
# 17   Let us see, briefly, the most important factor...
# 18                         The Czech Republic briefly.
# 19   As regards future objectives, briefly, two thi...
# 20   I am quick to say : there were programmes bein...
# 21   Simply put, our mission is to provide our clie...
# 22   Simply put, this means strict adherence to the...
# 23   Indeed, that, briefly, is the story of the las...
# 24   Simply put, patients should be allowed to take...
# 25   To put it concisely it is the understanding th...
# 26   Simply put, Commissioner, you can count on our...
# 27   This, to put it briefly, is the business philo...
# 28   I am certain that this is the ECB ’ s situatio...
# 29   I am quick to say, the child must learn how to...
# 30   I am certain that the implosion of the brave n...
# 31   There you see the European crisis briefly ; th...
# 32   I am certain that the cost of our work to impr...
# 33   I would say that maritime activity is a very i...
# 34   I can say that, in spite of the criticism that...
# 35   I am unable to navigate through it and I hope ...
# 36   I am certain that this is the most important p...
# 37   To put it concisely, the ECF's conclusion is t...
# 38   I am certain that this report is a fine exampl...
# 39   Simply put, Commissioner, Europe's future will...
# 40   Simply put, H.264 is suited to any platform — ...
# 41   I get the impression that no one is questionin...
# 42   These are, briefly, the motives underlying the...
# 43   I would like to reiterate the Commission's con...
# 44   It ’ s a pass for getting the best for the lea...
# 45   I am happy that the Commissioner has accepted ...
# 46   Simply put, our joint efforts have resulted in...
# 47   This, that is to say, provided the main impetu...
# 48   Simply, Web-to-print is the dynamic generation...
# 49   To put it concisely, Keynes struggled against ...
# 50                 Discover our pages Belgium briefly!
# 51    I am certain, guaranteeing EU citizens'security.
# 52   At our bank, it denotes experienced and acknow...
# 53   Simply put, they must enshrine all the values ...
# 54   Simply put, the single currency can only lead ...
# 55   I can't put it briefly – a professional drill ...
# 56   That, that is to say, is what the Fed and the ...
# 57   Simply put, HAL allows to set the exact same p...
# 58    Simply put : enjoy all the comfort we offer you.
# 59   I am certain that everyone's taste will be sat...
# 60   So, that ’ s briefly how this model of economi...
# 61   I am certain that it does have its advantages,...
# 62   But it is more than justified. To put it brief...
# 63   I can't put the important financial figures of...
# 64   This will perhaps allow us to fight together s...
# 65   Simply put, we need to invest less in asphalt,...
# 66   I am quick to say, you are always welcome from...
# 67   To put it concisely, Commissioner, the objecti...
# 68   Simply put, this is an attack on our world, th...
# 69               That is the social situation briefly.
# 70   This is the Roma issue with all its intricacie...
# 71   Simply put, it is a retrograde, ill-thought-ou...
# 72   I am certain that those who view this sampling...
# 73   To put it concisely, public health and consume...
# 74   I am quick to say, you are always welcome from...
# 75   I am certain that the legislative proposal und...
# 76   I am certain that this depends on a strong Eur...
# 77                        That is the problem briefly.
# 78   To put it concisely, Europe has worked against...
# 79   To put it briefly, we are beginning to build t...
# 80   To put it concisely, the report fails really t...
# 81   The annual campaigns since 1995 have brought n...
# 82   I think it has emerged as something beyond a d...
# 83   This morning, the European Parliament sought t...
# 84   Have you decided to kill two of your precious ...
# 85   We needed to think of solutions out of the ord...
# 86   However, I should also like to see the Council...
# 87   However, ladies and gentlemen, it is important...
# 88   You are self-motivated and willing to do more ...
# 89   I would like to urge the European Union govern...
# 90   Their outstanding traits are their high level ...
# 91   Member States must be prepared to pay for adeq...
# 92                    We take care of the little ones!
# 93   It is a good practice to pre-load the output b...
# 94     Take care, all data on your pc will be deleted!
# 95   While you ’ ll relax we will take care of all ...
# 96   For orders above € 100,00 we will handle the s...
# 97   All Inclusive offers you and your family excel...
# 98   Either you choose for a Low budget- or a custo...
# 99    Enjoy your stay - we ’ ll take care of the rest!
# 100  The families affected by new variant Creutzfel...
# 101  A wedding with a difference  let us take care ...
# 102          We will arrange for your perfect holiday!
# 103  In our five Austrian lounges ( two Business lo...
# 104  Your company : Talk to us and we are responsib...
# 105  Let our professional team handle everything so...
# 106  You simply cash the product from your site, se...
# 107  This is the custom. It is perhaps not justifie...
# 108  Nobody wants to buy something without looking ...
# 109  The Council wants us to buy something without ...
# 110  The electorate, I am convinced, will not be fo...
# 111  And then I will also have to tell my constitue...
# 112  We are effectively being asked to buy the bovi...
# 113  It didn 't take long to get started with the V...
# 114  These are all good suggestions to get started,...
# 115  I should like Parliament to pull itself apart ...
# 116  National strategies alone will not produce cut...
# 117  Through this vote, we are calling on the Lithu...
# 118  Now I am asking the Commission and the Council...
# 119  Mr Herman called on us to organize ourselves i...
# 120  Now it is time, however, to organize ourselves...
# 121  Fortunately, today we know that children who h...
#
#                                             Translated
# 0    Tom und Mary verlieben sich tief miteinander u...
# 1    Ich kann nicht glauben, dass ich Sie in einem ...
# 2    Ich bin sicher, dass der neue Bürgermeister ge...
# 3    Die Regierung hat sicher klargestellt, dass di...
# 4    Ich muss an die Bank gehen, und auf dem Weg zu...
# 5    Das Team denkt stets an Lösungen, die aus der ...
# 6    Wenn es um schwächere Schüler geht, tut der Le...
# 7    Wenn die Zeit kommt, werde ich schnell sein un...
# 8    Stellen Sie sicher, dass Sie sich nicht auf di...
# 9    Wenn Sie ein gebrauchtes Auto kaufen, ohne es ...
# 10   Das erste Gespräch mit ihr, konnte sie seinen ...
# 11   Ich weiß, dass es schwierig ist, Ihren Verlust...
# 12   Sook scheint tief verliebt zu sein, aber obwoh...
# 13   Er befand sich zuerst als junger Junge auf den...
# 14   In den meisten dalmatinischen Städten ist der ...
# 15   Die Glorious DJ-Möbellinie eignet sich hervorr...
# 16   Ich möchte schnell sagen, dass wir auf eine er...
# 17   Lassen Sie uns kurz die wichtigsten Faktoren s...
# 18                     Die Tschechische Republik kurz.
# 19   Was die künftigen Ziele anbelangt, so sind zwe...
# 20   Ich sage schnell: Es gab Programme, für die un...
# 21   Einfach ausgedrückt: Unser Ziel ist es, unsere...
# 22   Einfach ausgedrückt bedeutet dies eine strikte...
# 23   Tatsächlich ist dies kurz die Geschichte der l...
# 24   Einfach ausgedrückt: Patienten sollten die Kon...
# 25   Um es kurz zu sagen, ist es das Verständnis, d...
# 26   Einfach ausgedrückt, Herr Kommissar, können Si...
# 27   Das ist, um es kurz zu sagen, die Geschäftsphi...
# 28   Ich bin mir sicher, dass dies heute die Situat...
# 29   Ich bin schnell zu sagen, dass das Kind lernen...
# 30   Ich bin sicher, dass die Implosion der tapfere...
# 31   Dort sehen Sie die europäische Krise kurz; das...
# 32   Ich bin mir sicher, dass die Kosten unserer Ar...
# 33   Ich würde sagen, dass die maritime Tätigkeit e...
# 34   Ich kann sagen, dass der neue Stabilitäts- und...
# 35   Ich kann nicht durchgehen, und ich hoffe, dass...
# 36   Ich bin mir sicher, dass dies der wichtigste T...
# 37   Kurz gesagt, die Schlussfolgerung des ECF laut...
# 38   Ich bin mir sicher, dass dieser Bericht ein gu...
# 39   Einfach ausgedrückt, Herr Kommissar, wird die ...
# 40   Einfach ausgedrückt, ist H.264 für jede Plattf...
# 41   Ich habe den Eindruck, dass niemand die Wirksa...
# 42   Das sind kurz die Motive, die der Stellungnahm...
# 43   Ich möchte hier noch einmal die Schlussfolgeru...
# 44   Es ist ein Pass, um das Beste für die geringst...
# 45   Ich freue mich, dass der Kommissar eine große ...
# 46   Einfach ausgedrückt: Unsere gemeinsamen Anstre...
# 47   Das hat, das heißt, den wichtigsten Impuls für...
# 48   Einfach: Web-to-Print ist die dynamische Erste...
# 49   Um es kurz zu sagen: Keynes kämpfte gegen die ...
# 50           Entdecken Sie unsere Seiten Belgien kurz!
# 51   Ich bin sicher, dass die Sicherheit der EU-Bür...
# 52   In unserer Bank werden erfahrene und anerkannt...
# 53   Einfach ausgedrückt, sie müssen alle Werte und...
# 54   Einfach ausgedrückt: Die einheitliche Währung ...
# 55   Ich kann es nicht kurz formulieren – eine prof...
# 56           Das heißt, die Fed und die EZB sagen das.
# 57   Einfach ausgedrückt, erlaubt HAL die genauen E...
# 58   Einfach gesagt: Genießen Sie den Komfort, den ...
# 59   Ich bin sicher, dass jeder Geschmack durch die...
# 60   Das ist also kurz, wie dieses Modell der wirts...
# 61   Ich bin mir sicher, dass es seine Vorteile hat...
# 62   Aber es ist mehr als gerechtfertigt: Die OLED-...
# 63   Ich kann die wichtigen Finanzzahlen von Q-Cell...
# 64   Das wird uns vielleicht erlauben, gemeinsam no...
# 65   Einfach ausgedrückt: Wir müssen weniger in Asp...
# 66   Ich bin schnell zu sagen, Sie sind immer willk...
# 67   Um es kurz zu sagen, Herr Kommissar, das Ziel ...
# 68   Einfach ausgedrückt: Dies ist ein Angriff auf ...
# 69                 Das ist die soziale Situation kurz.
# 70   Das ist das Roma-Problem mit all seinen Detail...
# 71   Einfach ausgedrückt: Es handelt sich um einen ...
# 72   Ich bin mir sicher, dass diejenigen, die diese...
# 73   Kurz gesagt, die öffentliche Gesundheit und de...
# 74   Ich bin schnell zu sagen, Sie sind immer willk...
# 75   Ich bin mir sicher, dass der vorliegende Legis...
# 76   Ich bin sicher, dass dies von einem starken Eu...
# 77                           Das ist das Problem kurz.
# 78   Um es kurz zu sagen: Europa hat gegen sich sel...
# 79   Um es kurz zu sagen: Wir beginnen, das Haus vo...
# 80   Um es kurz zu sagen: Der Bericht geht nicht wi...
# 81   Die jährlichen Kampagnen seit 1995 haben weder...
# 82   Ich denke, dass es zweifellos herausgekommen i...
# 83   Heute Morgen wollte das Europäische Parlament ...
# 84   Haben Sie sich entschieden, zwei Ihrer kostbar...
# 85        Wir mussten Lösungen außerordentlich denken.
# 86   Ich möchte jedoch auch, dass der Rat zusätzlic...
# 87   Allerdings, meine Damen und Herren, ist es wic...
# 88   Sie sind selbstmotiviert und bereit, mehr als ...
# 89   Ich möchte die Regierungen der Europäischen Un...
# 90   Ihre herausragenden Merkmale sind ihre hohe Qu...
# 91   Die Mitgliedstaaten müssen bereit sein, für an...
# 92                     Wir kümmern uns um die Kleinen!
# 93   Es ist eine gute Praxis, den Ausgabepuffer vor...
# 94   Beachten Sie, alle Daten auf Ihrem PC werden g...
# 95   Während Sie sich entspannen, kümmern wir uns u...
# 96   Bei Bestellungen über € 100,00 werden wir die ...
# 97   All Inclusive bietet Ihnen und Ihrer Familie e...
# 98   Entweder wählen Sie für einen niedrigen Budget...
# 99   Genießen Sie Ihren Aufenthalt - wir kümmern un...
# 100  Die von der neuen Variante Creutzfeld-Jacob-Kr...
# 101  Eine Hochzeit mit einem Unterschied kümmern wi...
# 102           Wir organisieren Ihren perfekten Urlaub!
# 103  In unseren fünf österreichischen Lounges ( zwe...
# 104  Ihr Unternehmen : Sprechen Sie mit uns und wir...
# 105  Wir organisieren Ihre Veranstaltung von Anfang...
# 106  Sie kasse das Produkt einfach von Ihrer Websit...
# 107  Das ist der Gewohnheit, vielleicht nicht gerec...
# 108       Niemand will etwas kaufen, ohne es zu sehen.
# 109  Der Rat will, dass wir etwas kaufen, ohne es z...
# 110  Ich bin überzeugt, dass die Wähler nicht gezwu...
# 111  Und dann muß ich auch meinen Wählern sagen, da...
# 112  Wir werden nämlich aufgefordert, das Rinderäqu...
# 113  Es dauerte nicht lange, bis man mit dem Volksw...
# 114  Das alles sind gute Vorschläge, um anfangen zu...
# 115  Ich möchte, daß sich das Parlament auseinander...
# 116  Die nationalen Strategien allein werden keine ...
# 117  Mit dieser Abstimmung fordern wir die Vertrete...
# 118  Nun bitte ich die Kommission und den Rat, sich...
# 119  Herr Herman hat uns aufgefordert, sich zu orga...
# 120  Jetzt ist es jedoch an der Zeit, uns selbst zu...
# 121  Glücklicherweise wissen wir heute, dass Kinder...

# %%
# Save results
data_output.to_csv(model_dir+"translations_comparison_pipeline.csv")

# %%
# Also directly translate sentences with T5
en_id_input = pd.DataFrame()
en_id_input['input'] = data.agg('translate English to German: {0[input]}'.format, axis=1)

T5Generate(input_data=en_id_input, input_text="input", model_type="t5-small", output_dir=path)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:169: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-small automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,
# INPUT data: (122, 1)
# Outputs generated.
# Generated data saved @ /content/drive/MyDrive/MRP Idiom Translation/data/translations.csv

# %%
# Properly structure output file
data_translated = pd.read_csv(path+"translations.csv")

data_output = pd.DataFrame({"Idiom": data['idiom'],"Input": idiom_sents['Input'], "Translated": data_translated["Generated Text"]})
# Out:
#                                 Idiom  \
# 0                     head over heels
# 1               a sight for sore eyes
# 2                       in a nutshell
# 3            beyond a shadow of doubt
# 4       kill two birds with one stone
# 5               think outside the box
# 6                   go the extra mile
# 7                     bite the bullet
# 8                           take care
# 9                       pig in a poke
# 10                   the ball rolling
# 11             pull yourself together
# 12                    head over heels
# 13                    head over heels
# 14              a sight for sore eyes
# 15              a sight for sore eyes
# 16                      in a nutshell
# 17                      in a nutshell
# 18                      in a nutshell
# 19                      in a nutshell
# 20                      in a nutshell
# 21                      in a nutshell
# 22                      in a nutshell
# 23                      in a nutshell
# 24                      in a nutshell
# 25                      in a nutshell
# 26                      in a nutshell
# 27                      in a nutshell
# 28                      in a nutshell
# 29                      in a nutshell
# 30                      in a nutshell
# 31                      in a nutshell
# 32                      in a nutshell
# 33                      in a nutshell
# 34                      in a nutshell
# 35                      in a nutshell
# 36                      in a nutshell
# 37                      in a nutshell
# 38                      in a nutshell
# 39                      in a nutshell
# 40                      in a nutshell
# 41                      in a nutshell
# 42                      in a nutshell
# 43                      in a nutshell
# 44                      in a nutshell
# 45                      in a nutshell
# 46                      in a nutshell
# 47                      in a nutshell
# 48                      in a nutshell
# 49                      in a nutshell
# 50                      in a nutshell
# 51                      in a nutshell
# 52                      in a nutshell
# 53                      in a nutshell
# 54                      in a nutshell
# 55                      in a nutshell
# 56                      in a nutshell
# 57                      in a nutshell
# 58                      in a nutshell
# 59                      in a nutshell
# 60                      in a nutshell
# 61                      in a nutshell
# 62                      in a nutshell
# 63                      in a nutshell
# 64                      in a nutshell
# 65                      in a nutshell
# 66                      in a nutshell
# 67                      in a nutshell
# 68                      in a nutshell
# 69                      in a nutshell
# 70                      in a nutshell
# 71                      in a nutshell
# 72                      in a nutshell
# 73                      in a nutshell
# 74                      in a nutshell
# 75                      in a nutshell
# 76                      in a nutshell
# 77                      in a nutshell
# 78                      in a nutshell
# 79                      in a nutshell
# 80                      in a nutshell
# 81         beyond a shadow of a doubt
# 82         beyond a shadow of a doubt
# 83   to kill two birds with one stone
# 84   to kill two birds with one stone
# 85           to think outside the box
# 86               to go the extra mile
# 87               to go the extra mile
# 88               to go the extra mile
# 89               to go the extra mile
# 90               to go the extra mile
# 91                 to bite the bullet
# 92                        take care !
# 93                        take care !
# 94                        take care !
# 95                        take care !
# 96                        take care !
# 97                        take care !
# 98                        take care !
# 99                        take care !
# 100                       take care !
# 101                       take care !
# 102                       take care !
# 103                       take care !
# 104                       take care !
# 105                       take care !
# 106                       take care !
# 107                       take care !
# 108            to buy a pig in a poke
# 109            to buy a pig in a poke
# 110            to buy a pig in a poke
# 111            to buy a pig in a poke
# 112            to buy a pig in a poke
# 113           to get the ball rolling
# 114           to get the ball rolling
# 115                  to pull together
# 116                  to pull together
# 117                  to pull together
# 118                  to pull together
# 119                  to pull together
# 120                  to pull together
# 121                  to pull together
#
#                                                  Input  \
# 0    Tom and Mary are head over heels in love with ...
# 1    I can't believe that I haven't seen you in a y...
# 2    In a nutshell , all the new mayor was saying i...
# 3    The government has clarified beyond a shadow o...
# 4    I have to go to the bank , and on the way back...
# 5    The team always thinks outside the box to come...
# 6    When it comes to weaker students , the teacher...
# 7    When the time comes , I'll bite the bullet and...
# 8    Take care not to cut yourself on that rusty pi...
# 9    If you buy a used car without examining it tho...
# 10   The ball was rolling when he struck that first...
# 11   I know its difficult to get over your loss , b...
# 12   Sook seems to be head over heels in love with ...
# 13   He first encountered the tin whistle as a yout...
# 14   In most Dalmatian towns the market is a sight ...
# 15   The Glorious DJ furniture line is a sight for ...
# 16   In a nutshell , we are working towards a recog...
# 17   Let us see , in a nutshell , the most importan...
# 18                 The Czech Republic in a nutshell .
# 19   As regards future objectives , in a nutshell ,...
# 20   In a nutshell : there were programmes being ru...
# 21   In a nutshell , our mission is to provide our ...
# 22   In a nutshell , this means strict adherence to...
# 23   Indeed , that , in a nutshell , is the story o...
# 24   In a nutshell , patients should be allowed to ...
# 25   In a nutshell it is the understanding that whi...
# 26   In a nutshell , Commissioner , you can count o...
# 27   This , to put it in a nutshell , is the busine...
# 28   In a nutshell , this is the ECB ’ s situation ...
# 29   In a nutshell , the child must learn how to le...
# 30   In a nutshell : the implosion of the brave new...
# 31   There you see the European crisis in a nutshel...
# 32   In a nutshell , the cost of our work to improv...
# 33   In a nutshell , I would say that maritime acti...
# 34   In a nutshell , I can say that , in spite of t...
# 35   In a nutshell , our regulatory system to comba...
# 36   In a nutshell , this is the most important par...
# 37   In a nutshell , the ECF ’ s conclusion is that...
# 38   In a nutshell , this report is a fine example ...
# 39   In a nutshell , Commissioner , Europe 's futur...
# 40   In a nutshell , H.264 is suited to any platfor...
# 41   I get the impression that no one is questionin...
# 42   These are , in a nutshell , the motives underl...
# 43   In a nutshell , I would like to reiterate the ...
# 44   Holders are also granted priority parking at s...
# 45   In a nutshell , I am pleased that the Commissi...
# 46   In a nutshell , our joint efforts have resulte...
# 47   This , in a nutshell , provided the main impet...
# 48   In a nutshell , Web-to-print is the dynamic ge...
# 49   In a nutshell , Keynes struggled against the n...
# 50         Discover our pages Belgium in a nutshell !
# 51   In a nutshell , guaranteeing EU citizens ' sec...
# 52   At our bank , it denotes experienced and ackno...
# 53   In a nutshell , they must enshrine all the val...
# 54   In a nutshell , the single currency can only l...
# 55   In a nutshell – a professional drill that coul...
# 56   That , in a nutshell , is what the Fed and the...
# 57   In a nutshell , HAL allows to set the exact sa...
# 58   Entrust yourself to our masseur . In a nutshel...
# 59   In a nutshell : everyone ’ s taste will be sat...
# 60   So , that ’ s in a nutshell how this model of ...
# 61   In a nutshell : it does have its advantages , ...
# 62   But it is more than justified . To put it in a...
# 63   Important financial figures of Q-Cells in a nu...
# 64   This will perhaps allow us to fight together s...
# 65   In a nutshell , we need to invest less in asph...
# 66   In a nutshell , you are always welcome from 07...
# 67   In a nutshell , Commissioner , the objective o...
# 68   In a nutshell , this is an attack on our world...
# 69       That is the social situation in a nutshell .
# 70   This is the Roma issue with all its intricacie...
# 71   In a nutshell , it is a retrograde , ill-thoug...
# 72   In a nutshell , we believe that those who view...
# 73   In a nutshell , public health and consumer pro...
# 74   In a nutshell , you are always welcome from 07...
# 75   In a nutshell , the legislative proposal under...
# 76   In a nutshell , this depends on a strong Europ...
# 77                That is the problem in a nutshell .
# 78   To put it in a nutshell , Europe has worked ag...
# 79   To put it in a nutshell , we are beginning to ...
# 80   In a nutshell , the report fails really to tac...
# 81   The annual campaigns since 1995 have brought n...
# 82   I think it has emerged beyond a shadow of a do...
# 83   This morning , the European Parliament sought ...
# 84   Have you decided to kill two birds with one st...
# 85               We needed to think outside the box .
# 86   However , I should also like to see the Counci...
# 87   However , ladies and gentlemen , it is importa...
# 88   You are self-motivated and willing to go the e...
# 89   I would like to urge the European Union govern...
# 90   Their outstanding traits are their high level ...
# 91   Member States must bite the bullet and be prep...
# 92          We take special care of the little ones !
# 93   It is a good practice to pre-load the output b...
# 94   Take care , all data on your pc will be delete...
# 95   While you ’ ll relax we will take care of all ...
# 96   For orders above € 100,00 we will take care of...
# 97   All Inclusive offers you and your family excel...
# 98   Either you choose for a Low budget- or a custo...
# 99   Enjoy your stay - we ’ ll take care of the res...
# 100  The families affected by new variant Creutzfel...
# 101  A wedding with a difference  let us take care...
# 102      We will take care for your perfect holiday !
# 103  In our five Austrian lounges ( two Business Lo...
# 104  Your company : Talk to us and we take care of ...
# 105  Let our professional team take care of everyth...
# 106  You simply cash the product from your site , s...
# 107  This is the custom . It is perhaps not justifi...
# 108             Nobody wants to buy a pig in a poke .
# 109     The Council wants us to buy a pig in a poke .
# 110  The electorate , I am convinced , will not be ...
# 111  And then I will also have to tell my constitue...
# 112  We are effectively being asked to buy the bovi...
# 113  It didn 't take long to get the ball rolling w...
# 114  These are all good suggestions to get the ball...
# 115  I should like Parliament to pull itself togeth...
# 116  National strategies alone will not produce cut...
# 117  Through this vote , we are calling on the Lith...
# 118  Now I am asking the Commission and the Council...
# 119  Mr Herman called on us to pull ourselves toget...
# 120  Now it is time , however , to pull ourselves t...
# 121  Fortunately , today we know that children who ...
#
#                                             Translated
# 0    Tom und Mary verlieben sich einander in den Ko...
# 1    Ich kann nicht glauben, dass ich Sie in einem ...
# 2    Kurz gesagt, der neue Bürgermeister sagte: Der...
# 3    Die Regierung hat unbestreitbar klargestellt, ...
# 4    Ich muss an die Bank gehen und auf dem Rückweg...
# 5    Das Team denkt immer außerhalb der Box, um ein...
# 6    Wenn es um schwächere Studenten geht, macht de...
# 7    Wenn die Zeit kommt, werde ich die Kugel beiße...
# 8    Stellen Sie sicher, dass Sie sich nicht auf di...
# 9    Wenn man ein gebrauchtes Auto kauft, ohne es z...
# 10   Die Kugel war rollend, als er diese erste Gesp...
# 11   Ich weiß, dass es schwierig ist, Ihren Verlust...
# 12   Sook hat sich mit ihrem Freund in der Liebe ve...
# 13   Als er sich als junger Mensch befand, sah er s...
# 14   In den meisten dalmatinischen Städten ist der ...
# 15   Die Glorious DJ-Möbellinie ist ein Sehenswürdi...
# 16   Kurzum, wir arbeiten auf eine erkennbare und a...
# 17   Kurz gesagt, die wichtigsten Faktoren, die das...
# 18              Die Tschechische Republik kurz gesagt.
# 19   Was die künftigen Ziele anbelangt, so sind zwe...
# 20   Kurz gesagt: Es gab Programme, für die unzurei...
# 21   Kurz gesagt, unsere Aufgabe ist es, unseren Ku...
# 22   Kurz gesagt bedeutet dies eine strenge Einhalt...
# 23   In der Tat ist dies, kurz gesagt, die Geschich...
# 24   Kurzum, Patienten sollten die Kontrolle über i...
# 25   Kurz gesagt ist es das Verständnis, dass die F...
# 26   Zusammenfassend, Herr Kommissar, können Sie au...
# 27   Das ist, um es kurz zu sagen, die Geschäftsphi...
# 28   Kurz gesagt, das ist die Situation der EZB heute.
# 29   Kurz gesagt, das Kind muss lernen, wie zu lernen.
# 30   Kurz gesagt: Die Implosion der tapferen neuen ...
# 31   Hier sieht man die europäische Krise kurz gesa...
# 32   Kurz gesagt, die Kosten für unsere Arbeit zur ...
# 33   Kurzum, ich würde sagen, dass die maritime Tät...
# 34   Kurzum, ich kann sagen, dass der neue Stabilit...
# 35   Kurz gesagt, unser Regulierungssystem zur Terr...
# 36   Kurz gesagt, dies ist der wichtigste Teil der ...
# 37   Kurzum, die Schlussfolgerung des ECF lautet, d...
# 38   Kurzum, dieser Bericht ist ein gutes Beispiel ...
# 39   Kurzum, Herr Kommissar, die Zukunft Europas wi...
# 40   Die H.264-Anwendungen sind sowohl für den Hand...
# 41   Ich habe den Eindruck, daß niemand die Wirksam...
# 42   Das sind - kurz gesagt - die Motive, die der S...
# 43   Kurz gesagt möchte ich die Schlussfolgerung de...
# 44   Inhaber erhalten außerdem Prioritätenparkplätz...
# 45   Kurz gesagt, ich freue mich, dass der Kommissa...
# 46   Kurz gesagt, unsere gemeinsamen Anstrengungen ...
# 47   Zusammenfassend hat dies den wichtigsten Impul...
# 48   Zusammenfassend ist Web-to-Print die dynamisch...
# 49   Keynes gründete eine Universität in New York, ...
# 50      Entdecken Sie unsere Seiten Belgien ganz kurz!
# 51   Kurz gesagt, die Gewährleistung der Sicherheit...
# 52   Bei unserer Bank bezeichnet sie erfahrene und ...
# 53   Kurz gesagt, sie müssen alle Werte und Prinzip...
# 54   Kurzum, die einheitliche Währung kann nur zu e...
# 55   Kurz gesagt – eine professionelle Bohrung, die...
# 56   Das ist es, kurz gesagt, was die Fed und die E...
# 57   Kurz gesagt erlaubt HAL die genauen Eigenschaf...
# 58   Vertrauen Sie sich unserem Masseur, kurz: Geni...
# 59   Kurz gesagt: Jeder Geschmack wird durch die re...
# 60   So funktioniert dieses Modell der wirtschaftli...
# 61   Kurz gesagt: Sie hat ihre Vorteile, und das Ri...
# 62   Aber es ist mehr als gerechtfertigt: Die OLED-...
# 63   Wichtige Finanzzahlen von Q-Cells zusammenfass...
# 64   Dies wird uns vielleicht erlauben, noch effekt...
# 65   Kurz gesagt, wir müssen weniger in Asphalt, Be...
# 66   Kurz gesagt, Sie sind immer willkommen von 07:...
# 67   Kurz gesagt, Herr Kommissar, das Ziel dieses T...
# 68   Kurz gesagt, dies ist ein Angriff auf unsere W...
# 69          Das ist die soziale Situation kurz gesagt.
# 70   Das ist das Roma-Problem mit all seinen Besond...
# 71   Kurz gesagt, es handelt sich um einen rückschr...
# 72   Kurz gesagt, wir glauben, dass diejenigen, die...
# 73   Kurz gesagt, die öffentliche Gesundheit und de...
# 74   Kurz gesagt, Sie sind immer willkommen von 07:...
# 75   Kurz gesagt, der vorliegende Legislativvorschl...
# 76   Kurz gesagt, dies hängt von einem starken Euro...
# 77                      Das ist ganz kurz das Problem.
# 78   Kurz gesagt, Europa hat gegen sich selbst gear...
# 79   Um es kurz zu sagen, beginnen wir das Haus von...
# 80   Kurzum, der Bericht hat dieses Problem nicht w...
# 81   Die Kampagnen seit 1995 haben weder Residenzen...
# 82   Ich denke, es ist unbestreitbar geworden, dass...
# 83   Heute morgen versuchte das Europäische Parlame...
# 84   Haben Sie sich entschieden, zwei Vögel mit ein...
# 85               Wir mussten außerhalb der Box denken.
# 86   Ich möchte jedoch auch, daß der Rat sich mit k...
# 87   Aber es ist wichtig, meine Damen und Herren, d...
# 88   Sie sind selbstmotiviert und bereit, sich als ...
# 89   Ich möchte die Regierungen der Europäischen Un...
# 90   Ihre herausragenden Merkmale sind ihre hohe Qu...
# 91   Die Mitgliedstaaten müssen die Kugel in den Gr...
# 92           Wir kümmern uns besonders um die Kleinen!
# 93   Es ist eine gute Praxis, den Ausgabepuffer vor...
# 94   Bitte beachten Sie, alle Daten auf Ihrem PC we...
# 95   Während Sie sich entspannen, kümmern wir uns u...
# 96   Für Bestellungen über € 100,00 kümmern wir uns...
# 97   All Inclusive bietet Ihnen und Ihrer Familie e...
# 98   Entweder wählen Sie für einen niedrigen Budget...
# 99   Genießen Sie Ihren Aufenthalt - wir kümmern un...
# 100  Die von der neuen Creutzfeld-Jacob-Krankheit b...
# 101  Eine Hochzeit mit einem Unterschied  wir kümme...
# 102         Wir kümmern uns um Ihren perfekten Urlaub!
# 103  In unseren fünf österreichischen Lounges ( zwe...
# 104  Ihr Unternehmen : Sprechen Sie mit uns und wir...
# 105  Wir organisieren Ihre Veranstaltung von Anfang...
# 106  Sie koennen das Produkt einfach von Ihrer Webs...
# 107  Das ist die Gewohnheit, vielleicht nicht gerec...
# 108   Niemand will ein Schwein in einem Pissen kaufen.
# 109  Der Rat will, dass wir ein Schwein in einem Pi...
# 110  Ich bin überzeugt, dass die Wähler nicht gezwu...
# 111  Und dann muß ich auch meinen Wählern sagen, da...
# 112  Wir werden in der Tat gebeten, das Rinderäquiv...
# 113  Es dauerte nicht lange, bis der Ball mit dem V...
# 114  Das alles sind gute Vorschläge, um den Ball zu...
# 115  Ich möchte, daß sich das Parlament zusammenzie...
# 116  Die nationalen Strategien allein werden keine ...
# 117  Mit dieser Abstimmung fordern wir die Vertrete...
# 118  Ich fordere nun die Kommission und den Rat auf...
# 119  Herr Herman hat uns aufgefordert, sich zusamme...
# 120  Jetzt ist es jedoch an der Zeit, uns zusammenz...
# 121  Glücklicherweise wissen wir heute, dass Kinder...

# %%
# Save results
data_output.to_csv(path+"translations_comparison_baseline.csv")

# %% [markdown]
# ## Evaluation using COMET
#
# Using reference-free COMET metric, we evaluate how well the german translations are for translating the idiomatic sentence directly and for using the pipeline.
#
# Can't seem to load model with the limited RAM of Colab
#
# (Also, unlikely to work, since COMET probably doesn't understand idioms)

# %%
# !pip install unbabel-comet -q

from comet import download_model, load_from_checkpoint
# Out:
# Downloading wmt21-comet-qe-da.tar.gz
# wmt21-comet-qe-da.tar.gz: 1.72GB [00:49, 34.9MB/s]
# Extracting /root/.cache/torch/unbabel_comet/wmt21-comet-qe-da.tar.gz
# Extracted /root/.cache/torch/unbabel_comet/wmt21-comet-qe-da.tar.gz

# %%
model_path = download_model("wmt21-comet-qe-da")

model = load_from_checkpoint(model_path)
# Out:
# wmt21-comet-qe-mqm is already in cache.

# %%
# Prepare data
comet_id_input = {"src": en_id_data['input'], "mt": translations_id['Generated Text']}
comet_lit_input = {"src": en_id_data['input'], "mt": translations_lit['Generated Text']}

# %%
model = load_from_checkpoint(model_path)

seg_scores_id, sys_score_id = model.predict(comet_id_input, batch_size=4, gpus=1)
seg_scores_lit, sys_score_lit = model.predict(comet_lit_input, batch_size=4, gpus=1)

# %%
#model = load_from_checkpoint(model_path)

data = [
    {
        "src": "Dem Feuer konnte Einhalt geboten werden",
        "mt": "The fire could be stopped",
    },
    {
        "src": "Schulen und Kindergärten wurden eröffnet.",
        "mt": "Schools and kindergartens were open",
    }
]

seg_scores, sys_score = model.predict(data, batch_size=8)
# Out:
# ---------------------------------------------------------------------------
# MisconfigurationException                 Traceback (most recent call last)
# <ipython-input-26-49dbe5128ae5> in <module>()
#      12 ]
#      13
# ---> 14 seg_scores, sys_score = model.predict(data, batch_size=8)
#
# /usr/local/lib/python3.7/dist-packages/comet/models/base.py in predict(self, samples, batch_size, gpus, mc_dropout, progress_bar, accelerator, num_workers, length_batching)
#     531                 callbacks=[PredictProgressBar()],
#     532                 accelerator=accelerator,
# --> 533                 max_epochs=-1
#     534             )
#     535         else:
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/argparse.py in insert_env_defaults(self, *args, **kwargs)
#     337
#     338         # all args were already moved to kwargs
# --> 339         return fn(self, **kwargs)
#     340
#     341     return cast(_T, insert_env_defaults)
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py in __init__(self, logger, checkpoint_callback, enable_checkpointing, callbacks, default_root_dir, gradient_clip_val, gradient_clip_algorithm, process_position, num_nodes, num_processes, devices, gpus, auto_select_gpus, tpu_cores, ipus, log_gpu_memory, progress_bar_refresh_rate, enable_progress_bar, overfit_batches, track_grad_norm, check_val_every_n_epoch, fast_dev_run, accumulate_grad_batches, max_epochs, min_epochs, max_steps, min_steps, max_time, limit_train_batches, limit_val_batches, limit_test_batches, limit_predict_batches, val_check_interval, flush_logs_every_n_steps, log_every_n_steps, accelerator, strategy, sync_batchnorm, precision, enable_model_summary, weights_summary, weights_save_path, num_sanity_val_steps, resume_from_checkpoint, profiler, benchmark, deterministic, reload_dataloaders_every_n_epochs, auto_lr_find, replace_sampler_ddp, detect_anomaly, auto_scale_batch_size, prepare_data_per_node, plugins, amp_backend, amp_level, move_metrics_to_cpu, multiple_trainloader_mode, stochastic_weight_avg, terminate_on_nan)
#     500             amp_type=amp_backend,
#     501             amp_level=amp_level,
# --> 502             plugins=plugins,
#     503         )
#     504         self._logger_connector = LoggerConnector(self, log_gpu_memory)
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py in __init__(self, devices, num_nodes, accelerator, strategy, plugins, precision, amp_type, amp_level, sync_batchnorm, benchmark, replace_sampler_ddp, deterministic, auto_select_gpus, num_processes, tpu_cores, ipus, gpus)
#     199         if self._accelerator_flag == "auto" or self._accelerator_flag is None:
#     200             self._accelerator_flag = self._choose_accelerator()
# --> 201         self._set_parallel_devices_and_init_accelerator()
#     202
#     203         # 3. Instantiate ClusterEnvironment
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py in _set_parallel_devices_and_init_accelerator(self)
#     518             ]
#     519             raise MisconfigurationException(
# --> 520                 f"{self.accelerator.__class__.__qualname__} can not run on your system"
#     521                 " since the accelerator is not available. The following accelerator(s)"
#     522                 " is available and can be passed into `accelerator` argument of"
#
# MisconfigurationException: GPUAccelerator can not run on your system since the accelerator is not available. The following accelerator(s) is available and can be passed into `accelerator` argument of `Trainer`: ['cpu'].
