# %% [markdown]
# <a href="https://colab.research.google.com/github/lukassanting/Idiom-Translation/blob/main/End_To_End/End_To_End_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training T5 - Prefix+Idiom

# %% [markdown]
# #0. Installs, Imports, Setup

# %% [markdown]
# ##0.1 Import Libraries & Packages

# %%
# !pip install sentencepiece -q
# !pip install transformers -q
# !pip install torch -q
# !pip install rich[jupyter] -q
# Out:
#      |████████████████████████████████| 1.2 MB 14.2 MB/s
#      |████████████████████████████████| 4.2 MB 14.8 MB/s
#      |████████████████████████████████| 6.6 MB 50.6 MB/s
#      |████████████████████████████████| 596 kB 65.5 MB/s
#      |████████████████████████████████| 86 kB 5.9 MB/s
#      |████████████████████████████████| 232 kB 8.4 MB/s
#      |████████████████████████████████| 51 kB 7.2 MB/s

# %%
# Drive
from google.colab import drive

# Plots
import IPython
import IPython.display
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))

# Util
import os
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split

pd.set_option('display.max_rows', None)

# ML
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler

# Importing the T5 modules from huggingface/transformers
from transformers import T5Tokenizer, T5ForConditionalGeneration

# rich: for a better display on terminal
from rich.table import Column, Table
from rich.text import Text
from rich import box
from rich.console import Console

# define a rich console logger
console = Console(record=True)

# Setting up the device for GPU usage
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'

# %% [markdown]
# ##0.2. Import Data

# %% [markdown]
# Either upload the data to the shared Google Drive and use this to download, or upload it directly yourself (whatever is easier)

# %%
folder_name = 'repo'
# !git clone https://github.com/lukassanting/Idiom-Translation/ 'repo'
# Out:
# Cloning into 'repo'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 203 (delta 88), reused 141 (delta 37), pack-reused 0
# Receiving objects: 100% (203/203), 4.26 MiB | 1.77 MiB/s, done.
# Resolving deltas: 100% (88/88), done.

# %% [markdown]
# ##0.3 Setup functions & classes

# %% [markdown]
# ###0.3.1 FUNC: display_df

# %%
# to display dataframe in ASCII format
def display_df(df):
    """display dataframe in ASCII format"""

    console = Console()
    table = Table(
        Column("source_text", justify="center"),
        Column("target_text", justify="center"),
        title="Sample Data",
        pad_edge=False,
        box=box.ASCII,
    )

    for i, row in enumerate(df.values.tolist()):
        table.add_row(row[0], row[1])

    console.print(table)

# %% [markdown]
# ###0.3.2 CLASS: DataSet

# %% [markdown]
# A Dataset class for reading and loading the dataset into the dataloader, and then feed it into the neural network for fine-tuning the model.

# %%
class DataSet(Dataset):
    """
    Creating a dataset class for reading the dataset and
    loading it into the dataloader, to pass it to the
    neural network for finetuning the model

    """

    def __init__(
        self, dataframe, tokenizer, source_len, target_len, source_text, target_text
    ):
        """
        Initializes a Dataset class

        Args:
            dataframe (pandas.DataFrame): Input dataframe
            tokenizer (transformers.tokenizer): Transformers tokenizer
            source_len (int): Max length of source text
            target_len (int): Max length of target text
            source_text (str): column name of source text
            target_text (str): column name of target text
        """
        self.tokenizer = tokenizer
        self.data = dataframe
        self.source_len = source_len
        self.summ_len = target_len
        self.target_text = self.data[target_text]
        self.source_text = self.data[source_text]

    def __len__(self):
        """returns the length of dataframe"""

        return len(self.target_text)

    def __getitem__(self, index):
        """return the input ids, attention masks and target ids"""

        source_text = str(self.source_text[index])
        target_text = str(self.target_text[index])

        # cleaning data so as to ensure data is in string type
        source_text = " ".join(source_text.split())
        target_text = " ".join(target_text.split())

        source = self.tokenizer.batch_encode_plus(
            [source_text],
            max_length=self.source_len,
            pad_to_max_length=True,
            truncation=True,
            padding="max_length",
            return_tensors="pt",
        )
        target = self.tokenizer.batch_encode_plus(
            [target_text],
            max_length=self.summ_len,
            pad_to_max_length=True,
            truncation=True,
            padding="max_length",
            return_tensors="pt",
        )

        source_ids = source["input_ids"].squeeze()
        source_mask = source["attention_mask"].squeeze()
        target_ids = target["input_ids"].squeeze()
        target_mask = target["attention_mask"].squeeze()

        return {
            "source_ids": source_ids.to(dtype=torch.long),
            "source_mask": source_mask.to(dtype=torch.long),
            "target_ids": target_ids.to(dtype=torch.long),
            "target_ids_y": target_ids.to(dtype=torch.long),
        }

# %% [markdown]
# ###0.3.3 FUNC: train

# %% [markdown]
# Train function, which will the put model on training mode, generate outputs and calculate loss

# %%
def train(epoch, tokenizer, model, device, loader, optimizer, train_batch_size):

    """
    Function to be called for training with the parameters passed from main function

    Takes 6 arguments as input:
    
        epoch: epoch
        tokenizer: T5 tokenizer
        model: T5 model
        loader: Train Dataloader
        optimizer: Optimizer
        train_batch_size: batch size for the training data


    """

    model.train()
    train_loss = 0
    train_batches = 0
    for _, data in enumerate(loader, 0):
        y = data["target_ids"].to(device, dtype=torch.long)
        y_ids = y[:, :-1].contiguous()
        lm_labels = y[:, 1:].clone().detach()
        lm_labels[y[:, 1:] == tokenizer.pad_token_id] = -100
        ids = data["source_ids"].to(device, dtype=torch.long)
        mask = data["source_mask"].to(device, dtype=torch.long)

        outputs = model(
            input_ids=ids,
            attention_mask=mask,
            decoder_input_ids=y_ids,
            labels=lm_labels,
        )
        loss = outputs[0]
        train_loss += loss.item()
        train_batches += 1

        # Print training loss every 100 batches
        if _ % 100 == 0:
            #training_logger.add_row(str(epoch), str(_), str(loss.item()))
            console.print("Epoch: ", str(epoch), "Batch: ", str(_), "Loss: ", str(loss.item()))

        optimizer.zero_grad()
        loss.backward() 
        optimizer.step()

    # Print average training loss over the epoch
    train_loss = train_loss/train_batches
    training_logger.add_row(str(epoch), str(train_loss))

# %% [markdown]
# ###0.3.4 FUNC: validate

# %% [markdown]
# Validate function is same as the Train function, but for the validation data

# %%
def validate(epoch, tokenizer, model, device, loader, generate_outputs=True):

  """
  Function to evaluate model for predictions

  """
  model.eval()
  predictions = []
  actuals = []
  val_loss = 0
  batches = 0
  with torch.no_grad():
      for _, data in enumerate(loader, 0):
          y = data['target_ids'].to(device, dtype = torch.long)
          ids = data['source_ids'].to(device, dtype = torch.long)
          mask = data['source_mask'].to(device, dtype = torch.long)

          # Find validation loss
          y_ids = y[:, :-1].contiguous()
          lm_labels = y[:, 1:].clone().detach()
          lm_labels[y[:, 1:] == tokenizer.pad_token_id] = -100

          outputs = model(
              input_ids=ids,
              attention_mask=mask,
              decoder_input_ids=y_ids,
              labels=lm_labels
              )
          loss = outputs[0]
          val_loss += loss.item()
          batches += 1

          # Generate outputs
          if generate_outputs:
            generated_ids = model.generate(
                input_ids = ids,
                attention_mask = mask, 
                max_length=150, 
                num_beams=2,
                repetition_penalty=2.5, 
                length_penalty=1.0, 
                early_stopping=True
                )
            preds = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True) for g in generated_ids]
            target = [tokenizer.decode(t, skip_special_tokens=True, clean_up_tokenization_spaces=True)for t in y]

            predictions.extend(preds)
            actuals.extend(target)

  # Save average loss over epoch
  val_loss = val_loss/batches
  if not generate_outputs:
    validation_logger.add_row(str(epoch), str(val_loss))

  return predictions, actuals

# %% [markdown]
# ###0.3.5 FUNC: T5Trainer

# %% [markdown]
# T5Trainer is our main function. It accepts input data, model type, model paramters to fine-tune the model. Under the hood, it utilizes, our Dataset class for data handling, train function to fine tune the model, validate to evaluate the model.

# %%
def T5Trainer(
    train_data, val_data, source_text, target_text, model_params, output_dir="./outputs/"
):

    """
    T5 trainer has 6 arguments:

      train_data: Input dataframe of training data
      val_data: Input dataframe of validation data
      source_text: Column name of the input text i.e. idiomatic sentence
      target_text: Column name of the target text i.e. literal sentence
      model_params: T5 model parameters
      output_dir: Output directory to save fine tuned T5 model.

    """

    # Set random seeds and deterministic pytorch for reproducibility
    torch.manual_seed(model_params["SEED"])  # pytorch random seed
    np.random.seed(model_params["SEED"])  # numpy random seed
    torch.backends.cudnn.deterministic = True

    # logging
    console.log(f"""[Model]: Loading {model_params["MODEL"]}...\n""")

    # tokenizer for encoding the text
    tokenizer = T5Tokenizer.from_pretrained(model_params["MODEL"])

    # Defining the model. The model is then sent to device (GPU/TPU)
    model = T5ForConditionalGeneration.from_pretrained(model_params["MODEL"])
    model = model.to(device)

    # logging
    console.log(f"[Data]: Reading data...\n")

    # Importing the raw dataset
    train_data = train_data[[source_text, target_text]]
    train_data = train_data.reset_index(drop=True)
    val_data = val_data[[source_text, target_text]]
    val_data = val_data.reset_index(drop=True)

    display_df(train_data.head(2))

    # Creation of Dataset and Dataloader
    console.print(f"TRAIN Dataset: {train_data.shape}")
    console.print(f"VALIDATION Dataset: {val_data.shape}\n")

    # Creating the Training and Validation dataset for further creation of Dataloader
    training_set = DataSet(
        train_data,
        tokenizer,
        model_params["MAX_SOURCE_TEXT_LENGTH"],
        model_params["MAX_TARGET_TEXT_LENGTH"],
        source_text,
        target_text,
    )
    val_set = DataSet(
        val_data,
        tokenizer,
        model_params["MAX_SOURCE_TEXT_LENGTH"],
        model_params["MAX_TARGET_TEXT_LENGTH"],
        source_text,
        target_text,
    )

    # Defining the parameters for creation of dataloaders
    train_params = {
        "batch_size": model_params["TRAIN_BATCH_SIZE"],
        "shuffle": True,
        "num_workers": 0,
    }

    val_params = {
        "batch_size": model_params["VALID_BATCH_SIZE"],
        "shuffle": False,
        "num_workers": 0,
    }

    # Creation of Dataloaders for training and validation.
    training_loader = DataLoader(training_set, **train_params)
    val_loader = DataLoader(val_set, **val_params)

    # Defining the optimizer that will be used to tune the weights of the network in the training session.
    optimizer = torch.optim.Adam(
        params=model.parameters(), lr=model_params["LEARNING_RATE"]
    )

    # Training loop
    console.log(f"[Initiating Fine Tuning]...\n")

    train_batch_size = model_params["TRAIN_BATCH_SIZE"]
    for epoch in range(model_params["TRAIN_EPOCHS"]):
        train(epoch, tokenizer, model, device, training_loader, optimizer, train_batch_size)
        validate(epoch, tokenizer, model, device, val_loader, generate_outputs=False)

    console.print("\n")
    console.print(training_logger)
    console.print("\n")
    console.print(validation_logger)

    console.log(f"[Saving Model]...\n")
    # Saving the model after training
    path = os.path.join(output_dir, "model_files")
    model.save_pretrained(path)
    tokenizer.save_pretrained(path)

    # generating output for validation dataset
    console.log(f"[Generating Validation Outputs]...\n")
    predictions, actuals = validate(epoch, tokenizer, model, device, val_loader)
    final_df = pd.DataFrame({"Input": val_data[source_text], "Generated Text": predictions, "Actual Text": actuals})
    final_df.to_csv(os.path.join(output_dir, "predictions.csv"))

    console.save_text(os.path.join(output_dir, "logs.txt"))

    console.log(f"[Validation Outputs Generated.]\n")
    console.print(
        f"""[Model] Model saved @ {os.path.join(output_dir, "model_files")}\n"""
    )
    console.print(
        f"""[Validation] Generation on Validation data saved @ {os.path.join(output_dir,'predictions.csv')}\n"""
    )
    console.print(f"""[Logs] Logs saved @ {os.path.join(output_dir,'logs.txt')}\n""")

# %% [markdown]
# # 1. Processing Data

# %%
def clean_dataset(data):
  data_clean = data.copy(deep=True)
  for i in range(len(data_clean.columns)):
    data_clean.iloc[:,i] = data_clean.iloc[:,i].apply(lambda x: re.sub('&apos;', '\'', x))
    data_clean.iloc[:,i] = data_clean.iloc[:,i].apply(lambda x: re.sub('&quot;', '\"', x))
    data_clean.iloc[:,i] = data_clean.iloc[:,i].apply(lambda x: re.sub('&#124;', '|', x))
    data_clean.iloc[:,i] = data_clean.iloc[:,i].apply(lambda x: re.sub('&#93;', ']', x))
    data_clean.iloc[:,i] = data_clean.iloc[:,i].apply(lambda x: re.sub('&#91;', '[', x))
    data_clean.iloc[:,i] = data_clean.iloc[:,i].apply(lambda x: re.sub('&gt;', '>', x))
    data_clean.iloc[:,i] = data_clean.iloc[:,i].apply(lambda x: re.sub('&lt;', '<', x))

  return data_clean

# %%
remove_wrong = True
clean = True
idiom_suffix = False

# %%
base_path="data/End-To-End/Dataset/en-de/"
pd.read_csv(base_path+'train_compare_cleaned.csv', header=0)
# Out:
#       Unnamed: 0                                                 en  \
# 0              0  Could you please pass this request on to the P...
# 1              1  You may be forbidden to pass it on , and you a...
# 2              2  I should like to thank everyone who has helped...
# 3              3  I will pass on your appreciation to my colleag...
# 4              4  That is why our group is calling for the Confe...
# 5              5  « Golden Pass » panorama railway section ; fro...
# 6              6  In front of this imposing background it was Be...
# 7              7  This is a commitment from Commissioner McCreev...
# 8              8  Once we have gained experience of them for our...
# 9              9  At this point , I would like to pass on immedi...
# 10            10  From the poetic swing of the reminiscing “ You...
# 11            11  It is great to wake up on a morning , pick up ...
# 12            12  We will not pass on your email address to a th...
# 13            13  Therefore , if mercury is earmarked as a prior...
# 14            14  It is important to be able to hold broad debat...
# 15            15  Furthermore , if appeals to reason are not eno...
# 16            16  – Mr President-in-Office of the Council , Mr P...
# 17            17  With a thin majority in the lower house and a ...
# 18            18  We heard in the Commissioner &apos;s speech th...
# 19            19  We have set up a new crisis management unit to...
# 20            20  This medicine , in combination with safer sex ...
# 21            21  One way or the other we should be able to clea...
# 22            22  After influencing Zek to pass even more extrem...
# 23            23  Last month , at the EU-China summit in Beijing...
# 24            24  I trust that his colleague will pass my questi...
# 25            25  On issues such as these , we need to go the ex...
# 26            26  Take care that you do not find yourselves land...
# 27            27  They used to pass on their musical knowledge t...
# 28            28  Firms are likely to pass the increase in energ...
# 29            29  The geography of Europe is not such that each ...
# 30            30  Almost all the issues were put on hold and are...
# 31            31  All I can say is , hands off the concreting of...
# 32            32  It is sufficient to know , in this case , that...
# 33            33  We want you to go out there and sell the packa...
# 34            34  He can be examined from the sea , having made ...
# 35            35  This fight was very important for Vitali . Fir...
# 36            36  Los Cancajos is one of the best places to go ,...
# 37            37  The Great Wall stretches from Shanhai Pass on ...
# 38            38  These are costs which we cannot pass on to con...
# 39            39  This gas is planned to be utilized by a gas po...
# 40            40  Everywhere you go , there are lovely places to...
# 41            41  In our case , we naturally fell head over heel...
# 42            42  They will continue to develop it , they will r...
# 43            43   I therefore say ‘ Long live the Constitution ’ !
# 44            44  They strongly urged the EU to help Lebanon , a...
# 45            45          That is the message I wanted to pass on .
# 46            46                Come in and make yourself at home !
# 47            47  I am certain that in this day and age and in t...
# 48            48  Without a shadow of a doubt , ladies and gentl...
# 49            49  GetYourGuide reserves the right to pass on inf...
# 50            50  Madam President , Commissioner , Madam Preside...
# 51            51                The floor is yours , Mr President .
# 52            52  Patients tend to be tall , with long legs , an...
# 53            53  Set your Date of Birth and Gender to limit the...
# 54            54                                  The die is cast .
# 55            55  Madam President , the report by the special co...
# 56            56  In this day and age that is totally intolerable .
# 57            57  A lot has been said about Sweden &apos;s attit...
# 58            58  Vice-President of the Commission . - Madam Pre...
# 59            59  With a bike , you can go to places otherwise a...
# 60            60  Therefore , on that score , I suppose I should...
# 61            61  That is excellent , now I know and will be abl...
# 62            62  Moreover , our staff will be happy to tell you...
# 63            63  It would have been easy for you to take at lea...
# 64            64  In a nutshell , the Commission should be congr...
# 65            65  Loaded with sights to see , places to go and t...
# 66            66  Location next to Piazzale Roma can &apos;t be ...
# 67            67  We therefore believe that it is as well to bit...
# 68            68  The customer shall not be entitled to pass on ...
# 69            69  That makes it more cost-effective for us and w...
# 70            70  As long as the country is in a constitutional ...
# 71            71  Mrkva and Zeljo ( which has 4 different locati...
# 72            72  Should you have any question , please contact ...
# 73            73  Boats , planes , barges and submarines , some ...
# 74            74  We have the sad task of having to pass on our ...
# 75            75      I have to say that I do not agree with them !
# 76            76  Consequently , 100,000 watt FM stations can re...
# 77            77  But Jochen Hahn braked abruptly , too , and di...
# 78            78  We will be happy to take the opportunity to pa...
# 79            79  If these innovative engineers are having to fa...
# 80            80  This way anybody can get a clear concept on ho...
# 81            81  Europe will face two options : be prepared to ...
# 82            82  Madam President , before I speak on this subje...
# 83            83  It &apos;s important to get the best choice of...
# 84            84  The current tradeoff is that the client may no...
# 85            85  I can confirm that , so far as global loans ar...
# 86            86  He said that it is time for Europe to raise th...
# 87            87  We would be very pleased if you would take a m...
# 88            88  Thus , the hunting lodge of Augustus the Stron...
# 89            89  In this connection , I believe that perhaps we...
# 90            90  But I wanted to know how to configure RAID1 in...
# 91            91  This is in a nutshell what was laid down in th...
# 92            92       I am happy to say it is the very last time !
# 93            93  If this approach does not work , and if the ex...
# 94            94  The European Union must come to the fore as so...
# 95            95  ( CS ) Pull yourselves together , ladies and g...
# 96            96  I say early , I mean of course in logical sequ...
# 97            97  And now everything is being turned back to fro...
# 98            98  Touching the ground and going out of bounds gi...
# 99            99  Alternatively you can fly to Hannover airport ...
# 100          100  You can rely on us to pass these demands on to...
# 101          101       Mr President , I hope you will hear me out .
# 102          102  You can spend hours travelling up and down the...
# 103          103  It is therefore important to call on the Lithu...
# 104          104  It &apos;s easy to grip and can be carried 3 d...
# 105          105  Unfortunately , in this day and age , illegal ...
# 106          106  And we will be glad to pass your comments on t...
# 107          107  Mr President , it is of course a great tragedy...
# 108          108  He even had to pass on the management of his s...
# 109          109                Of course , it takes two to tango .
# 110          110        On the other hand , it takes two to tango .
# 111          111  By combining their forces they would be able t...
# 112          112  We do not pass on your address or any further ...
# 113          113  If Ukraine does not want to be dependent on Ru...
# 114          114  You have set a high standard for the future , ...
# 115          115  Already the worldwide choice and purchasing of...
# 116          116  But since he has not yet become filthy rich , ...
# 117          117  I should also like to pass on our thanks to th...
# 118          118  I find it very hard in this modern day and age...
# 119          119  These dated from the beginning of the electrif...
# 120          120  Very well located , easy to go to most of the ...
# 121          121  Now it ’ s time to pass on the diary of this s...
# 122          122  The only fly in the ointment is the decision b...
# 123          123  There is another approach , however , which co...
# 124          124  Our earnings expectations take into account th...
# 125          125  In a nutshell : no one will be bored on and ar...
# 126          126  They will check your request and pass on the r...
# 127          127  So I see we have to go to Rábapatoma where the...
# 128          128  Nonetheless , in spite of a populist governmen...
# 129          129  If you have something you &apos;re dying to kn...
# 130          130  We will not pass your data on to third parties...
# 131          131  This may well be a piece of advice that the Co...
# 132          132  On many of them it is possible to pass not onl...
# 133          133  In this day and age , when there is so much EU...
# 134          134  Find wheelchair accessible places to go to and...
# 135          135  We shall pass them on to the Bureau , as I sug...
# 136          136    To close the door in their faces is not right .
# 137          137  Responsibility for this must be borne by all t...
# 138          138  I agree with you , but I should have liked to ...
# 139          139  Though the Bistro Steinhalle can be reached by...
# 140          140  On the one hand , it allows huge numbers of mi...
# 141          141  This is Wales in a nutshell , an impressive fe...
# 142          142  Neck and shoulders are covered by a thick mane...
# 143          143  What we do know is that it is particularly in ...
# 144          144  If you put it like that , the decision we have...
# 145          145  Secondly , I realise that the best way for you...
# 146          146  Mr President , I would just like to ask whethe...
# 147          147               Sweet live in a band i have to say !
# 148          148  39 And it came to pass when they heard him , n...
# 149          149  In this day and age , the age of public awaren...
# 150          150  ur company can go back to 40 years of experien...
# 151          151  Overall its a decent hotel though , nice and q...
# 152          152  Thank you very much , and please pass on my re...
# 153          153  It is important for us to preserve and pass on...
# 154          154  As we also know , the background to these atta...
# 155          155  For this reason , every time your application ...
# 156          156  As we know , a new General Assembly is going t...
# 157          157  I would ask the President to pass on our suppo...
# 158          158  Consequently , the Union for a Europe of Natio...
# 159          159  It would be appreciated therefore if you could...
# 160          160  This does not of course make this any less of ...
# 161          161  The risk is — it so happens that at the same t...
# 162          162  We strongly believe that a majority of MEPs in...
# 163          163  I would ask all Member States to approve every...
# 164          164  The European Union &apos;s motto clearly sums ...
# 165          165  On fisheries - whether that can be part of it ...
# 166          166  I think we should make it clear that the Easte...
# 167          167  To have you as a happy customer and pass on a ...
# 168          168  Whichever tool we choose , Mr Barroso , I expe...
# 169          169  Nor is it sufficient to beat the drum for caus...
# 170          170  Suddenly the rivalries between the various Eur...
# 171          171  I think we all feel a reserved satisfaction ; ...
# 172          172  This is why the company offers an efficient pr...
# 173          173  Therefore , I ask you , Mrs Malmström , to pas...
# 174          174  I hope that the Irish presidency will incorpor...
# 175          175  We also agreed that it would be best to hold t...
# 176          176  All I can say about that is that it is an emba...
# 177          177  I shall , of course , pass on your comments to...
# 178          178  Allow me to pass on some information about Bol...
# 179          179     I will pass on your remarks to the President .
# 180          180  I think the House will know that I have tried ...
# 181          181  Therefore please fill in the contact e-mail co...
# 182          182  Commissioner , I am delighted to hear you are ...
# 183          183  “ I am compelled to interpret , not record the...
# 184          184  Mr President , my colleagues have already made...
# 185          185  It was just a question of time that Marchisio ...
# 186          186  Last weekend , a large demonstration in Hong K...
# 187          187  Irrespective of whether the goal is to build u...
# 188          188  Our another responsibility is to raise the bar...
# 189          189  NI-DAQmx makes it fast and easy to configure y...
# 190          190  We do not pass on to third parties your person...
# 191          191  We have already said it and we repeat : the Eu...
# 192          192  The only way forward for any just society in t...
# 193          193  However , these imply a level of cost which we...
# 194          194  If you wish to find an accomodation around the...
# 195          195  It can probably seat about two hundred people ...
# 196          196  My room was starting to show it &apos;s age , ...
# 197          197  Pushing for clear labelling is the only way to...
# 198          198  If you should discover within it a compelling ...
# 199          199  Large groups will easily be able to pass the i...
# 200          200  If you choose to change the amount of the stan...
# 201          201  It gives a clear signal to our citizens that ,...
# 202          202  Since it is an important question and the lack...
# 203          203  Whenever we go to a West African country , we ...
# 204          204  You know &apos; close the door &apos; to evil ...
# 205          205  Special requests : We can pass on any special ...
# 206          206  For the most part the construction elements bu...
# 207          207  The ECB ’ s latest program of bond purchases w...
# 208          208  14 And it came to pass that the Lamanites had ...
# 209          209  Cheap and Cheerful style hotel ; good value an...
# 210          210  The Hotel Lido Giovanna is between the little ...
# 211          211  Once there , we embark on a trek of two days w...
# 212          212  In those days , military factors were given pr...
# 213          213  If required we might pass your personal inform...
# 214          214  We are giving all the signals we can to organi...
# 215          215  Only in this way will NGOs representing differ...
# 216          216  It seems to me that , in Europe , we have a wo...
# 217          217  The Spring Council tomorrow needs to bite the ...
# 218          218  As you know , the allocation of frequencies is...
# 219          219  This is Europe ’ s headscarf debate in a nutsh...
# 220          220  When , having left behind Angarsk pass , you a...
# 221          221  That , in a nutshell , is the fundamental euro...
# 222          222  With these keys , they can open the door to an...
# 223          223  In short , we are in a right mess , that is al...
# 224          224  In a nutshell , what is the reasoning behind t...
# 225          225  The Commissioner is well aware that each job o...
# 226          226  I believe that this is a key issue that I want...
# 227          227  Here some exits of blue clay , and in general ...
# 228          228  Before we proceed to the vote on the report by...
# 229          229  If you arrive by air via Orlando International...
# 230          230  I will also pass the message about the Free Un...
# 231          231  Additionally a curve over Museum Island is pos...
# 232          232  It is true that there is information here and ...
# 233          233  I am simply saying that you have to pull all t...
# 234          234  It &apos;s fun and easy to learn , so beginner...
# 235          235  Carlyle &apos;s words &quot; A mystic bond of ...
# 236          236  - Natura Card pass with free entry to entertai...
# 237          237  After this debate we should be able to say : w...
# 238          238  We will treat your details confidentially and ...
# 239          239  The Hindus go on pilgrimage to the Ganges and ...
# 240          240  The picture of the crisis in a few months is g...
# 241          241  Europe has a particular responsibility , throu...
# 242          242  We need to pass on the message to the various ...
# 243          243  And then people look at me if I say &quot; Ger...
# 244          244  His 2-reel westerns immediately distinguish th...
# 245          245  Music , places to go out , nature walks , exhi...
# 246          246  Their photo portraits will show their faces an...
# 247          247  This is why , together with the other Members ...
# 248          248  When you are trying to pull together a negotia...
# 249          249  One of the aims of the EWC is to pass on infor...
# 250          250  Nonetheless , current interest rates were desc...
# 251          251  Several waiting queues have to pass the incomi...
# 252          252  Knowing your way around will make it easy for ...
# 253          253  If a company wants to be innovative today and ...
# 254          254   Adam Allen : &quot; I just have to say WOW ! ! !
# 255          255  We cannot ask our NGOs to go to places where t...
# 256          256  Switzerland ’ s largest alp is a political ano...
# 257          257  The Union still has a long way to go in develo...
# 258          258  Citistep.com offers to his ( its ) advertisers...
# 259          259  In this day and age we really should not be ex...
# 260          260  Mr President , quite frankly , I believe it is...
# 261          261  The personal details you give us here will be ...
# 262          262  Amendment No 4 specifies the obligation upon s...
# 263          263  Now I hear you trying to sound as if you have ...
# 264          264  Since 1970th years of thousand or even ten tho...
# 265          265  This is what I wanted to emphasise in this deb...
# 266          266  We will never pass on your e-mail address to a...
# 267          267  You have to take care of your neck around here...
# 268          268  The basic aim of all these reforms was , and i...
# 269          269  In our restaurant , the harmony of Retz wines ...
# 270          270  We bind ourselves to our principles , no matte...
# 271          271  The nitrogen gas is thus separated and fed int...
# 272          272  I know that she will be reporting in detail to...
# 273          273  When it comes to scaremongering politics about...
# 274          274  Andreas Tille suggested that all new packages ...
# 275          275  The philosopy of the winery is to pass on its ...
# 276          276  According to the proposals adopted , Member St...
# 277          277  We hope that the Cuban leadership will be far-...
# 278          278  Are you ready for a vacation , but don ’ t wan...
# 279          279  If anyone is thinking of staying at the Alkist...
# 280          280  I am in favour of the ban on brominated fire r...
# 281          281  It &apos;s best to try to dive as early as pos...
# 282          282  Post fashion circus` , it will be held twice a...
# 283          283  All they have to do is vote for the creation o...
# 284          284  Every year , 350 000 flying hours are wasted b...
# 285          285  For the high end boutiques , go to the west en...
# 286          286  I took note of the other detailed questions an...
# 287          287  That is why I still have a certain scepticism ...
# 288          288  We shall pass these comments on to the Commiss...
# 289          289  I welcome the fact that other issues have come...
# 290          290  The hotel is located in an ideal place to go o...
# 291          291  I do not know when the Commission will be able...
# 292          292  &quot; What shall i say ... FIRST CLASS ! I ca...
# 293          293  The number of restaurants in Japan is stupendo...
# 294          294  We will pass that on to the relevant body with...
# 295          295  We talk about micro-costs which we want the ma...
# 296          296  &quot; Women are ( I nearly want to say : natu...
# 297          297  Second , public consultation , in order to kno...
# 298          298            We take care of all paperwork for you !
# 299          299  On January 23 and 24 , 2010 , Epicentro Art wi...
# 300          300  I do not understand why the European Union sho...
# 301          301  As you may know , she was due to be executed b...
# 302          302  I must not pass over the passage in the minist...
# 303          303  I ask you to pass on this invitation to Commis...
# 304          304  Mr President , I would like you to hear this p...
# 305          305  We will gladly send you a DVD on request and h...
# 306          306  To put it in a nutshell : visibility is fine ,...
# 307          307  We gladly pass on our know-how to you to empow...
# 308          308  Yet we must adhere to international law withou...
# 309          309  I would request you to pass this complaint on ...
# 310          310  We have made a great effort to work out whethe...
# 311          311  If they do not pass on any data , they have di...
# 312          312  As you know , there are going to be primary el...
# 313          313  We must make a clear diagnosis and look for a ...
# 314          314  I pass on my praise to the French , Italian , ...
# 315          315  And succeed , I think we can say , we certainl...
# 316          316  How can we explain that , although prices are ...
# 317          317  Find wheelchair accessible places to go to and...
# 318          318  On Wednesday Dec.2nd the County Government ann...
# 319          319  It is the characteristic mental make-up of his...
# 320          320  astraia will not pass on confidential data to ...
# 321          321  Come and visit , and we will take care of your...
# 322          322  There are very many approaches , and they are ...
# 323          323  We may never know the number of victims in Ira...
# 324          324  I would just say that we cannot stick our head...
# 325          325  Coming as I do from a language region of 22 mi...
# 326          326  On the Grimsel mule track route from Meiringen...
# 327          327  As you know , the suspected cases in Greece pr...
# 328          328     But there , I have to say , I have my doubts !
# 329          329  Special live entertainment for all the family ...
# 330          330  The European Union has to get the ball rolling...
# 331          331  From the Otopeni Airport you may reach our hos...
# 332          332  If you have , this is your chance to explore t...
# 333          333  These alarm units already recognize the fire i...
# 334          334  It is up to you to choose between a whole day ...
# 335          335  Master users need to pass on the group ID and ...
# 336          336  I say no - it proves that it is working proper...
# 337          337  Two dates come to the fore to finally force th...
# 338          338  Without previous written consent Klimmer is ne...
# 339          339  I would like to hear what you have to say abou...
# 340          340  Mrs Raschhofer , I shall gladly pass your comm...
# 341          341  We would like to know whether the Commission w...
# 342          342  The day following your application you can tel...
# 343          343  However , there is a third issue that has now ...
# 344          344  Some are happy with the Council &apos;s strict...
# 345          345  It is not for the Commission to pass comment o...
# 346          346  2 hours the refuge &quot; Santner Pass &quot; ...
# 347          347  A successful business enterprise needs to go t...
# 348          348  lines 4 or 5 ( only one station to go ) your s...
# 349          349  President-in-Office of the Council . - ( CS ) ...
# 350          350  31 And it came to pass on the morrow he entere...
# 351          351  Mr President , Commissioner , I am sorry that ...
# 352          352  Furthermore , the dryness of the ground in sum...
# 353          353  I will pass on what you have said to the Presi...
# 354          354  This is where the expertise of DIMENSION-POLYA...
# 355          355  The best way to travel conveniently and inexpe...
# 356          356  The other important point , on which I voted d...
# 357          357  Although this is a recommendation adopted outs...
# 358          358  Commissioner , I should firstly like to make a...
# 359          359  Mr President there is reason to be worried bec...
# 360          360  Klimmer assures strict confidentiality and dur...
# 361          361  For example , we have been asked to pass judge...
# 362          362  To put it in a nutshell , we need innovative p...
# 363          363  The attractiveness of the marina is due to the...
# 364          364                 Have a nice time and take care ! !
# 365          365  6 And it came to pass that he came unto me , a...
# 366          366  28 And it came to pass , that on the other han...
# 367          367  Since the hind legs were much longer they are ...
# 368          368  Don &apos;t take your time , because experienc...
# 369          369  However , the outermost regions could not supp...
# 370          370  Select the pictures and attributes to be expor...
# 371          371  First of all you must reach agreement with the...
# 372          372  Moreover , in her description of our evolution...
# 373          373  Everywhere you go , there are lovely places to...
# 374          374  We know , though , that our external borders c...
# 375          375  First , a European liaison office could be cre...
# 376          376  You won ’ t be put on hold or have to wait for...
# 377          377  The country to hold the Presidency , Spain , i...
# 378          378  After you have seen it , you can also pass on ...
# 379          379  These rules are not written in stone , they ar...
# 380          380  If you want to be the first to know about upco...
# 381          381  Madam President , I should just like to ask yo...
# 382          382  With the help of the caretaker who has all the...
# 383          383  I am categorically against resolution P7 _ TA-...
# 384          384  This issue has come to the fore because the me...
# 385          385  it is easy to take the train from the Cologne ...
# 386          386  There is only limited opportunity – or justifi...
# 387          387  If there is a good example of that firmness it...
# 388          388  This sort of reminder would not in any way clo...
# 389          389  In terms of social policy , everyone must pull...
# 390          390  These elements must be included if we are to h...
# 391          391  Trying to pool these traditions may look like ...
# 392          392  The greatest difference as far as the European...
# 393          393  . The most constructive way forward would be f...
# 394          394  It is amazing to me that , in this modern day ...
# 395          395  have the automatic child seat recognition chec...
# 396          396  Teachers too must be moulded into real Europea...
# 397          397  I heard them clearly . In any case , I underta...
# 398          398  It would make more sense to pass this kind of ...
# 399          399  We take note of your comment and your suggesti...
# 400          400  Firstly , we need to clear the way for plannin...
# 401          401  The point is that they will have to face them ...
# 402          402  Appear in all places where you go , there &apo...
# 403          403  I will nevertheless pass them on to Mrs Bjerre...
# 404          404  The single-sided micro etching allows colours ...
# 405          405  As you are due to go there , we call on you to...
# 406          406  The Contractor undertakes not to pass on econo...
# 407          407  The Council will be delighted to know in advan...
# 408          408  Even if we ask the county councils or national...
# 409          409  A methanol flame is almost colorless . Care sh...
# 410          410  He is unable to be here today and I am to pass...
# 411          411  You know &apos; close the door &apos; to evil ...
# 412          412  There is one point on which I would like to gi...
# 413          413  Gyeong-ju kills the woman in the heat of the m...
# 414          414  European energy champions would squeeze out ev...
# 415          415  ( DE ) Madam President , for us , it is relati...
# 416          416  Dont Need I say , tell all the screen , Negati...
# 417          417  If you have any questions on how to play Onlin...
# 418          418  17 And it came to pass that on the morrow they...
# 419          419       ... And then do not say I did not warn you !
# 420          420  It is not easy for today &apos;s consumers to ...
# 421          421  in writing . - ( ET ) Ladies and gentlemen , w...
# 422          422    I did not hear anyone refer to you personally .
# 423          423  With regard to the specific question on transp...
# 424          424  Mr President , as this vote concerns me direct...
# 425          425  We shall pass on the request to Sir Leon that ...
# 426          426  Café Liégeois is therefore making a strong ges...
# 427          427  A special packet for who wants to pass the gre...
# 428          428  It is no longer possible for this dossier to b...
# 429          429  We like to think that creative minds hold no b...
# 430          430  Your personal information is save with us and ...
# 431          431  Room 25 was way too small for two tall adults ...
# 432          432  We will take care of your request as soon as p...
# 433          433  By air you fly to Hammerfest with the small ai...
# 434          434  We are fifteen Member States with different tr...
# 435          435  Our view is that if excessive compensation is ...
# 436          436  Mr President , the Commission had intended to ...
# 437          437  Once again , President Santer has given us a d...
# 438          438  Latex , leather , floggers , handcuffs , slapp...
# 439          439  Please , have a look around and never hesitate...
# 440          440  It will also be necessary to cooperate with lo...
# 441          441  They provide detailed practical information fo...
# 442          442  I would therefore state that only a strong , v...
# 443          443  It is within this context that I wish to pass ...
# 444          444  Although a regulation came into force on 15 Ma...
# 445          445  I have put a little bit of modest money away s...
# 446          446  Sit back and relax whilst in the slow lane , t...
# 447          447  The price , it was cheap and cheerful , perfec...
# 448          448  And Thomas had already provided the second , i...
# 449          449  I hope the Commission will pass that message o...
# 450          450  The arrangements introduced will clear the way...
# 451          451  In a nutshell , we believe it is right to be c...
# 452          452  Perhaps , Commissioner , you could pass that m...
# 453          453  The Presidency will , of course , pass on your...
# 454          454  &quot; A new series of books which is impressi...
# 455          455  Lastly , we must constantly and insistently ma...
# 456          456  On long-haul buses , if your ticket allocates ...
# 457          457  Therefore , we invite you to pass your next ho...
# 458          458  After a temporary committee of enquiry , which...
# 459          459  Frankly , Mr President , the Council needs to ...
# 460          460  Now , in answer to the desperate shortage of f...
# 461          461  Nonetheless , I am glad that Parliament has sh...
# 462          462  Will we , the four states , be forced to estab...
# 463          463              I have to say that , in all honesty !
# 464          464  During his residence in Thrace he joined the e...
# 465          465  Furthermore , KERN may pass on your informatio...
# 466          466  As I felt the familiar warmth in my heart that...
# 467          467  Despite all this , I fear that what is propose...
# 468          468  Mr President , I should like to pass on the Eu...
# 469          469  In a nutshell , the proposal is not perfect , ...
# 470          470  I will certainly pass that message on to the P...
# 471          471  The humpback whale produces a louder sound tha...
# 472          472  Coordinating a monetary policy with an economi...
# 473          473  First of all , as I said , it is the Belgian a...
# 474          474  &quot; To pass on this message that the Compañ...
# 475          475  In a nutshell , the &quot; other &quot; Majorc...
# 476          476  I will pass it on to the Bureau after this sit...
# 477          477  Ultimately , we now have the agreement to pass...
# 478          478  We know the proper steps to take in order to e...
# 479          479  Exhibitors pass on guest tickets to their busi...
# 480          480  Now , as you will hear , I am sure those hopef...
# 481          481  I hope in that case that Dimas will be able to...
# 482          482  This Area , which has come to the fore in line...
# 483          483  I would also like to ask you to pass on my tha...
# 484          484  Kids are home from school and I can &apos;t ev...
# 485          485  This crisis is clear evidence that the Europea...
# 486          486  Find wheelchair accessible places to go to and...
# 487          487  If carried out in this way , it should be clea...
# 488          488  I think it is really disgraceful that in this ...
# 489          489  Even the Nordic governments have supported a c...
# 490          490  @ : Vonny Nuyten : I &apos;m glad to hear that...
# 491          491  Moreover , I think the Member who has just spo...
# 492          492  We have here a unique cultural heritage of inc...
# 493          493  We know that , if the situation in Iran were t...
# 494          494  I am sure it is what you hear in your constitu...
# 495          495  We have been informed today , by Commissioner ...
# 496          496  Since Flanders ( and Belgium ) is not big , it...
# 497          497  Words cannot , of course , express the atrocit...
# 498          498  Loquendo Speaker Verification technology uses ...
# 499          499  This is about keeping the present state of our...
# 500          500  It was impossible to close the bathroom door b...
# 501          501  Although it is certainly to soon to pass judgm...
# 502          502  Many accommodation facilities are available in...
# 503          503  It is not yet altogether straightforward to pa...
# 504          504  Intel sponsors top clans and events to help ra...
# 505          505  So this is your chance to save some money . On...
# 506          506                 – Mr President , the die is cast .
# 507          507  In connection with this kind of work we have o...
# 508          508  The die is sometimes cast differently from how...
# 509          509  One of my best friends from childhood married ...
# 510          510  When will we be able to hold a debate on this ...
# 511          511     We do not pass on your data to third parties .
# 512          512  I would like to know whether you consider that...
# 513          513  Secondly , I am a little surprised to hear you...
# 514          514  It is true that a small elite would continue t...
# 515          515  Both were head over heels in love and flew and...
# 516          516  Discover our pages Discover Belgium , The Even...
# 517          517  We will not pass on these informations to anyo...
# 518          518  We offer day trips as well as multi night pack...
# 519          519  The EU needs the United States if things get o...
# 520          520  I will pass this on to the House &apos;s servi...
# 521          521  These typical features of resorts along the Sp...
# 522          522  We are very pleased to be able to hold an exch...
# 523          523  So today we want to go up to the high places ,...
# 524          524  In this day and age , with the arrival of hars...
# 525          525  So I wonder whether the time has not come to s...
# 526          526      The only way out is to set clear priorities .
# 527          527  If you &apos;re ready to raise the bar , apply...
# 528          528  Secondly , in its proposals , the Commission i...
# 529          529  Without any shadow of a doubt , this is a cris...
# 530          530  We don ’ t pass on your personal data to third...
# 531          531  28 And it came to pass that Ammon and Lamoni p...
# 532          532  We pay attention to Beat Wabel ´ s report to v...
# 533          533  y your things , don ’ t forget to have a thick...
# 534          534  In a nutshell , the development of some is the...
# 535          535  But that unfeeling organ is strong , made of s...
# 536          536  Like I always did , I will continue also in fu...
# 537          537  Mr Blokland , I had a quick look at the list y...
# 538          538  Apart from that I do not see why I should have...
# 539          539  The political guidelines continue to move in d...
# 540          540  Why should we in the West go to such lengths t...
# 541          541  If we have that confidence we can pass that me...
# 542          542  To pass judgment on redistributive outcomes , ...
# 543          543  Where to go , places you should not miss , the...
# 544          544  I can only pass your words on to President Bar...
# 545          545  This newly structured website aims to pass on ...
# 546          546  One problem in assessing the tiger-mothering a...
# 547          547  Mint tea is available for about 6DH all over t...
# 548          548  As you know , I consider energy efficiency in ...
# 549          549  Most PowerPoint users know that a closed shape...
# 550          550  I will keep this House informed as to progress...
# 551          551  But if , God forbid , things get out of hand t...
# 552          552  I am sure Commissioner Kinnock will pass on th...
# 553          553  Secondly , Morocco and other countries face re...
# 554          554             Please pass this on to all concerned .
# 555          555  In this day and age , we are using electricity...
# 556          556  That is , without doubt , too short , too swee...
# 557          557  Where a delivery period of more than 4 months ...
# 558          558  World of Warcraft MMORPG players will find it ...
# 559          559  Here in the House , however , we have a situat...
# 560          560  Along with nourishing the skin , the high temp...
# 561          561  Hotel owners help you for rental services as w...
# 562          562  Moreover , an existing pipeline network implie...
# 563          563  Those who go to such places don &apos;t discov...
# 564          564  We can only welcome the effective role played ...
# 565          565  The Dutch Public Prosecutor is involved in thi...
# 566          566  Place your cursor on the marks to display the ...
# 567          567  There will not be much time for discussion but...
# 568          568  Then order the new Carnival DVD to have alread...
# 569          569  As Leila Shahid , the General Delegate for the...
# 570          570  Bronze membership entitles you to one personal...
# 571          571  Our main aim is to be able to pass on our pass...
# 572          572  For example , in agriculture and fishing , it ...
# 573          573  To place odds on your pass line bet , you must...
# 574          574  I shall pass on the honourable member &apos;s ...
# 575          575                               The floor is yours .
# 576          576  I am grateful for the praise which has kindly ...
# 577          577  However , you have to go to many places to rea...
# 578          578  We apologise for any inconvenience this may ca...
# 579          579  With this website we want to pass on informati...
# 580          580  I know beyond a shadow of a doubt that in the ...
# 581          581  That is why I am asking them to cooperate with...
# 582          582  The increase was perhaps exaggerated in the he...
# 583          583  The existence of such links is often decisive ...
# 584          584  Thus I agree on the need to go the extra mile ...
# 585          585  It would finance the purchases by issuing Euro...
# 586          586  The European Parliament has already embarked o...
# 587          587  I would like to ask you , Mr President , not o...
# 588          588        I will say one thing - my advice to you ( !
# 589          589  I think that the old saying , ‘ It takes two t...
# 590          590  Instead of making abusive or derogative remark...
# 591          591  They are designed to fly aerodynamic ally when...
# 592          592  Please pass on my comments to Eduardo a credit...
# 593          593  In a nutshell : the European Union is of the f...
# 594          594  Our hotel is the most exclusive place on Ischi...
# 595          595  These companies learn about your pattern of ne...
# 596          596  Does the DeskShare GmbH pass on information to...
# 597          597  Let us then give some thought to what judgment...
# 598          598  It is a sad little story but I knew you would ...
# 599          599  Another event that most likely will be of cons...
# 600          600  The courses are marked by buoys that you have ...
# 601          601  Hearing , reading , typing errors or abbreviat...
# 602          602  Here too , I say &apos; yes &apos; , an emphat...
# 603          603  Or maybe you just want to go for a walk or enj...
# 604          604  We will not pass your information on to other ...
# 605          605  Success requires people who want to go to plac...
# 606          606  Should it not be a priority for the fifteen go...
# 607          607  &quot; Fat Man &quot; and &quot; Little Boy &q...
# 608          608  By Plane : You will fly to the international a...
# 609          609  So take care that pussycat doesn � t get an ex...
# 610          610  ( NL ) Mr President , in a nutshell , the foll...
# 611          611  Mr Marset Campos , regardless of how we may se...
# 612          612  Secondly , however , until guilt can be proven...
# 613          613  I could prove without a shadow of a doubt , ho...
# 614          614  Admittedly , it is not the real avian influenz...
# 615          615  Do they then pass the money on to the passenge...
# 616          616  A federal agency had that information and fail...
# 617          617  In this day and age , they do it in the name o...
# 618          618  Well , a user of ubuntu has his girlfriend and...
# 619          619  My colleagues and I would be delighted to hear...
# 620          620  To put it in a nutshell , the information syst...
# 621          621  What he later wrote about the experience of th...
# 622          622  The first drama was such a great success that ...
# 623          623  We can certainly not pass on the problem to th...
# 624          624  Previous work includes : Man and Boy : DADA ( ...
# 625          625  The new Slovak Government is ready to go the e...
# 626          626  I would also ask your opinion of the Court of ...
# 627          627  In any case , I am certainly taking note of th...
# 628          628  FLOWERPOT HOLDERS are used to hold flo ® werpo...
# 629          629  For example I find no hint of the fact that we...
# 630          630  They face difficult choices but we must persev...
# 631          631  A man and boy emerge from the streets near the...
# 632          632            I say and I repeat : that is not true !
# 633          633  For peacetime transit , in particular for the ...
# 634          634  That is why I would be interested to know whet...
# 635          635  It is absolutely clear that the next phase of ...
# 636          636  Mr Rothley has persuaded me personally but I k...
# 637          637  It gives me particular pleasure to be able to ...
# 638          638  Using WICU tubes helps processors to actively ...
# 639          639  The &apos; ginger &apos; gene is recessive , w...
# 640          640  I have chosen some quotes which I would like t...
# 641          641  Member of the Commission . - Madam President ,...
# 642          642  In order for the Commission to be able to obta...
# 643          643  You &apos;ll have to beat rival racers to the ...
# 644          644  Mr Farage , you and your colleagues will be pl...
# 645          645  You have mentioned that , even before this con...
# 646          646  This is the message that I will pass on to Pre...
# 647          647  We will never pass on your details to any thir...
# 648          648  It will be difficult , we will have to pull to...
# 649          649  We also know that new elements need to be inco...
# 650          650  As a result , it is advisable to have special ...
# 651          651  Fossilized on the concept of &quot; fundraisin...
# 652          652  Polar-Mohr Maschinenvertriebsgesell-schaft is ...
# 653          653  We are more than happy to pass on this experie...
# 654          654  Last year it took only 6 ½ days for the festiv...
# 655          655  After the event is over we need a full report ...
# 656          656  I call on the European Union , therefore , to ...
# 657          657  Implenia &apos;s trained and committed profess...
# 658          658  In a nutshell , it has been much easier for th...
# 659          659  You can print a list of all downloads in a sel...
# 660          660  Since their customers are putty in their hands...
# 661          661  You &apos;re a driver , so you &apos;ve likely...
# 662          662  We feel great solidarity with this Sakharov Pr...
# 663          663  Please retain your online boarding pass or air...
# 664          664  Nor do we know whether it will be acceptable t...
# 665          665  35 The Commission accepts that the Law on publ...
# 666          666  I also enjoyed the all day breakfast in the ad...
# 667          667  I especially welcome the fact that the United ...
# 668          668  In failing to pass judgement on this , we are ...
# 669          669  The partnership is here to stay and the way is...
# 670          670  Our friendly secretaries Frau Becker and Frau ...
# 671          671  Between the pass the mountains climb up to ca....
# 672          672  In an age in which the nations of this world g...
# 673          673  Project leader William Dobbs is delighted with...
# 674          674  However , this can only be brought to pass if ...
# ...
# 2052  Der Kunde unterlässt es insbesondere auch , di...   NaN
# 2053                Herr Präsident Sie haben das Wort .   NaN
# 2054  Denn das läuft automatisch ab , und wenn wir i...   NaN
# 2055  Deshalb kann auch ein Teil der jährlichen öffe...   NaN
# 2056  Meiner Meinung nach erweisen wir Europa gerade...   NaN
# 2057  Sie werden eng mit unseren Designern und unser...   NaN
# 2058  Wir haben ein geistiges Klima geschaffen , in ...   NaN
# 2059  Die Gesundheit ist eine der Fragen , die den B...   NaN
# 2060  Wie ich in meiner ersten Anmerkung gesagt habe...   NaN
# 2061  Kulturell und strategisch von den Jesuiten des...   NaN
# 2062  Zweitens möchten wir wissen , was unternommen ...   NaN
# 2063  Von der Kommissarin und der Europäischen Kommi...   NaN
# 2064  Neben dem Parkhaus « Place de l ’ Europe » , s...     x
# 2065  Das Parlament wird erfreut sein zu erfahren , ...   NaN
# 2066  Herr Wurtz , hätten Sie Freundlichkeit , Ihre ...   NaN
# 2067  Wir melden Sie automatisch bei der Kurverwaltu...   NaN
# 2068  In solchen Momenten des Niedergangs treten in ...   NaN
# 2069  Darüber hinaus hat Island schon seit dem Vorja...     x
# 2070  Entsprechend können wir Insights liefern , die...     x
# 2071  Ich werde diese Idee gerne aufgreifen und weit...   NaN
# 2072  Nun ist es an der Zeit , das Reisetagebuch an ...   NaN
# 2073  Vielmehr teilt die Kommission die von den Dame...   NaN
# 2074  Wir räumen Ihnen den Weg für Ihre reibungslose...   NaN
# 2075  Zusätzlic müssen sie sie weiterleiten , nicht ...   NaN
# 2076  Deshalb möchte ich abschließend fragen , ob wi...   NaN
# 2077  Nach einem schwierigen 1. Geschäftsjahresquart...   NaN
# 2078  Aber besser in diesem Bereich ein Ende mit Sch...     x
# 2079  Wenn Sie immer Schritt mit der Zeit halten wol...   NaN
# 2080  Ich werde es Herrn Präsident Hänsch weitergebe...   NaN
# 2081  Herr Hatzidakis , ich werde Frau de Palacio Ih...   NaN
# 2082  Wir sollten das nicht als Wahlpropaganda hier ...   NaN
# 2083  Es wurde ausgesetzt , weil wir auf die Umsetzu...   NaN
# 2084  Basierend auf bekannten und in der Praxis seit...   NaN
# 2085  Herr Präsident , ich bin lediglich hier , um z...   NaN
# 2086  Aufzug war sehr klein ( ist aber nicht wirklic...     x
# 2087  Ganz so easy wie der Urlaub geplant war , verl...     x
# 2088  Die Versorgung des Raketentriebwerks wurde dar...     x
# 2089  Die Weitergabe der Erfahrung an Jüngere ist he...   NaN
# 2090  Erreichbar sind viele Wandertouren in der Nied...   NaN
# 2091  Frau Beer bat mich , ihren Dank an die einzeln...   NaN
# 2092  Ich möchte wissen , ob Sie die Erwähnung in de...   NaN
# 2093  Dann warten Sie geduldig und denken Sie dar � ...     x
# 2094  Wenn Sie nun mit dem Eurostar durch den Tunnel...   NaN
# 2095  Es ist positiv , dass Mitgliedstaaten Gelegenh...   NaN
# 2096  Wir organisieren den schönsten Tag Ihres Lebes...   NaN
# 2097  Gemeinsam mit Partnern , z.B. Banken oder der ...   NaN
# 2098  Wir kennen den Kommissar als einen guten Demok...   NaN
# 2099  Es überrascht mich zu hören , dass Sie eine au...   NaN
# 2100  Frau Fraga Estévez , ich teile Ihre Einschätzu...   NaN
# 2101  Im Nebel sah er in der Nähe des Ufers eine Ges...   NaN
# 2102  Ich würde eine Erklärung Ihrerseits zu diesem ...   NaN
# 2103  Denn das ist der schrecklichste Grund , weshal...   NaN
# 2104  ( EL ) Unabhängig davon , dass das Europäische...   NaN
# 2105  Wir werden dann nicht zum Global Player , wenn...   NaN
# 2106  Das russische Gericht Khamovinicheskii sollte ...   NaN
# 2107  Also entschied ich mich ... ich sage euch : So...   NaN
# 2108  Meiner Auffassung nach darf die potenzielle Ex...   NaN
# 2109  Wie wir jedoch alle wissen , verfügt der Finan...   NaN
# 2110  Ich will Ihnen gerne die Zusage geben , daß ic...   NaN
# 2111  Ziel des unterbreiteten Vorschlags ist es , Kr...   NaN
# 2112  Das Fest an dem Jung und Alt in Mallorca singe...     x
# 2113  ( Da die Vollversion nur für Sie selbst lizens...   NaN
# 2114  Wie Ihr bald selbst sehen werdet , steckt er v...   NaN
# 2115  Eine Weitergabe an Dritte , abgesehen von den ...   NaN
# 2116  Für den Fall der Rückgabe oder Nichteinlösung ...   NaN
# 2117  Ich hoffe nicht , daß die Leitlinie der Europä...   NaN
# 2118  Einmal den Ring in der Hand , wird man diese T...   NaN
# 2119  Im Übrigen findet keine Weitergabe Ihrer perso...   NaN
# 2120  Videocassetten etc. - ohne Vergütungsansprüche...     x
# 2121  Eine weitere Betrugsmasche ist , wenn eine Per...   NaN
# 2122  Es ist ja wunderbar einfach , sich für die Kün...   NaN
# 2123  The girls just made notes on their pads and th...     x
# 2124  Im Rahmen der Troika schlage ich Ihnen vor , d...   NaN
# 2125  Pferdeschlittenfahrten - Unüberbietbar schön u...   NaN
# 2126  Ecophon steht für ein angenehmes Arbeitsumfeld...     x
# 2127  Diese Informationen erhalten Sie dann an Ihre ...   NaN
# 2128  Dann wüssten Sie , dass wir auch morgen im Ple...   NaN
# 2129  Eine Kommt Nicht Wette ist mit einer Nicht Pas...   NaN
# 2130  Mechanische Eichhörnchen sind auch sehr nette ...   NaN
# 2131  Die Münzen verkaufen , sehr schnell als Invest...   NaN
# 2132  Weiter nördlich fahren wir besonders dicht an ...   NaN
# 2133  - Herr Präsident , könnten Sie diese Botschaft...   NaN
# 2134  Zusammenfassend läßt sich sagen : Zur Sicherun...   NaN
# 2135  Wir müssen uns wieder fangen und das europäisc...   NaN
# 2136  Wir sollten jetzt die große Chance , eine grun...   NaN
# 2137  Fahren Sie die erste Straße im Kreisverkehr re...     x
# 2138  In dieser Hinsicht möchte ich gern an die Komm...   NaN
# 2139  Es ist Zeit geworden , den Keller zu leeren un...   NaN
# 2140  Beim Verlassen eines Raumes und Betreten eines...   NaN
# 2141  Ich bin der Überzeugung , dass sehr laut und d...   NaN
# 2142  Herr Prodi , da Herr Bolkestein noch immer nic...   NaN
# 2143  Um für die Aufnahmen Ihrer Digitalkamera ICC P...   NaN
# 2144  Herr Präsident , ich sage Bravo zum Berichters...   NaN
# 2145  Freunde , die man selten sieht , Mutter und To...     x
# 2146  Wir werden das aber auch an unsere Dienste wei...   NaN
# 2147  Ich hätte es spannend gefunden , Sie dies hier...   NaN
# 2148  Ich möchte Sie darüber informieren , dass der ...   NaN
# 2149  Sobald mir die entsprechenden Angaben vorliege...   NaN
# 2150  Zudem geben wir unseren Kunden die besten Prei...   NaN
# 2151         Es ist ein Privileg , Wissen zu erwerben .   NaN
# 2152  Erzeuger von besonders hochwertigen regionalen...   NaN
# 2153  Sie sind auch aktiv - zumindest die deutsch-fr...   NaN
# 2154  Sartre hat die mörderische Konsequenz des Fano...   NaN
# 2155  Am 13. Mai 2008 hat die Netzeinspeisung von Bi...     x
# 2156  Daraus entstehen Preisvorteile und Synergieeff...   NaN
# 2157  Ich leite die Frage aber an das zuständige Mit...   NaN
# 2158  Wir garantieren somit die Performance kritisch...   NaN
# 2159  Die EU - das wissen wir alle - ist wirtschafts...   NaN
# 2160  Frau Präsidentin ! Frau van Bladel hat in eine...   NaN
# 2161  der Beschreibung in dem jeweiligen Handbuch – ...   NaN
# 2162  Ob man es mit einem Wort sagt oder mit hundert...   NaN
# 2163  Das Treffen in London ist die Gelegenheit , Ge...   NaN
# 2164  Es bietet die elegante Wohnkultur der K + K Ho...     x
# 2165  Unser Verein lässt Norbika am 8.1.03 mit dem D...   NaN
# 2166  Nachdem wir erschöpft von dieser Tour zurückge...   NaN
# 2167  Wie wir alle wissen , werden sich die führende...   NaN
# 2168  Vor allem heutzutage ist uns die Entscheidung ...   NaN
# 2169  Zunächst einmal bleibt festzustellen , daß in ...   NaN
# 2170  Wir haben das so sehr vergessen , dass wir auf...   NaN
# 2171  Bleibt man jedoch dabei UND erleidet einen Bad...   NaN
# 2172  1.500 Fahrzeugen und zahlreichen Lizenznehmern...     x
# 2173  Unnötig zu sagen , ich weine , wenn ich es sehe !   NaN
# 2174  Lassen Sie mich die Gelegenheit nutzen , um Ih...   NaN
# 2175  Der &quot; Bilstein B8 Sprint &quot; Dämpfer i...   NaN
# 2176  Die Stadt ist römisch-katholischer Bischofssit...     x
# 2177  Und wenn Sie mich nach meiner persönlichen Mei...   NaN
# 2178  Die Existenz dieser Richtlinie wird außerdem d...   NaN
# 2179  Ich bedanke mich für die Komplimente und werde...   NaN
# 2180  Falls Ihnen all die Musik , die Unterhaltung ,...   NaN
# 2181                     Das Wort hat Herr Castagnède .   NaN
# 2182  ( PL ) Herr Präsident ! Die Debatte über genet...   NaN
# 2183  Das Hotel Green Peace liegt 139 km vom Flughaf...     x
# 2184  Die Logis von Belgien : Hotelgewerbe mit mensc...     x
# 2185  Wenn ich eine persönliche Bemerkungen hinzufüg...   NaN
# 2186  Ich bitte Sie ferner , es dem niederländischen...   NaN
# 2187  Dieser Fonds muß außerdem , und ich bitte Sie ...   NaN
# 2188  Es wurde auch gesagt , die baskische Regierung...   NaN
# 2189  Ihr macht es uns echt nicht leicht und es wird...   NaN
# 2190  Der Junge hat sich ein sehr klares und origine...   NaN
# 2191  Herr Präsident , ich habe alle Bemerkungen der...   NaN
# 2192  Das ist schlicht gesagt , Caroline , the probl...   NaN
# 2193  Ich bin überzeugt , dass sich mit der Zeit der...   NaN
# 2194  Natürlich reichen die Bemühungen der Regierung...   NaN
# 2195  … und „ Patron Renato “ wird Sie mit seiner st...     x
# 2196  Das wirkliche Problem besteht zweifellos in ei...   NaN
# 2197  Ich nehme Ihren Hinweis auf jeden Fall zur Ken...   NaN
# 2198  Wenn Sie häufig online buchen , können Sie Ihr...     x
# 2199  Wir wollen Leute hören , die uns sagen : „ Hie...   NaN
# 2200  Erst wird ein Tagesordnungspunkt abgehandelt ,...   NaN
# 2201  Das Hotel entspricht allen Anspruechen der Gae...   NaN
# 2202  Unsere Disponenten werden sich umgehend mit Ih...   NaN
# 2203  Speichern Sie diese nicht auf Ihrem PC , und g...   NaN
# 2204  Dies kann nur dadurch erreicht werden , dass s...   NaN
# 2205  In wenigen Klicks über Internet zur neuen Sais...   NaN
# 2206  Ich würde gerne eine klare , detaillierte Antw...   NaN
# 2207  Diese Woche werden die letzten Teile eingefügt...   NaN
# 2208  Ich sage Herrn Bush : Das können Sie Ihrer Gro...   NaN
# 2209  Herr Präsident ! Ich wäre Ihnen dankbar , wenn...   NaN
# 2210  Noch hat das französische Volk Zeit , sich zus...   NaN
# 2211  Aber auf keinen Fall wollte die Liberale Frakt...   NaN
# 2212  Wenn ich heute den Karlspreis für den Euro ent...   NaN
# 2213  Sie liegt vielmehr darin , dass die Struktur d...   NaN
# 2214  Grundlage der Wissensvermittlung muss das Umse...   NaN
# 2215  Es überrascht , daß Personen mit solch immense...   NaN
# 2216  4.4 Bei Vertragsabschluss mit Offenlegung der ...     x
# 2217      Ich bin kein Held , ( es muß wirklich sagen !   NaN
# 2218  Ich werde diese Information ganz gewiss weiter...   NaN
# 2219  Nach einem Wasch-und Pinsel auf die billige un...   NaN
# 2220                 aber sie sagen , I gotta get fat !   NaN
# 2221  Unser Mandat verpflichtet uns zu lernen , wie ...   NaN
# 2222  Es ist an der Zeit , dieses destruktive Experi...   NaN
# 2223  Daher wäre es interessant zu wissen , ob auch ...   NaN
# 2224  Das Präsidium wird diese Angelegenheit an die ...   NaN
# 2225  Es ist leicht für uns , zu reden , aber sehr s...   NaN
# 2226  Es gibt Bedenken , dass die Mitgliedstaaten üb...   NaN
# 2227  Der Kollegin Swinburne bitte ich auszurichten ...   NaN
# 2228  Sie wissen stets , ob ein dritter Partner an T...   NaN
# 2229  Halten Sie Ihre Hündin sicher an der Leine und...   NaN
# 2230  Außerdem muss der Übersetzer ein Experte in Sa...   NaN
# 2231  Persönlichkeit ist zweifellos wichtig , und un...   NaN
# 2232  14 Sprich : « Ich fürchte die Strafe eines fur...     x
# 2233  Das Problem entsteht dann , wenn nicht allgeme...   NaN
# 2234  Herr Präsident , Frau Außenministerin , Herr K...   NaN
# 2235  Ich glaube , es wird eine gute Sache sein , di...   NaN
# 2236  Ich kann es nur weiterleiten mit der ausdrückl...   NaN
# 2237  Es ist Zeit , die Landwirtschaft ein für allem...   NaN
# 2238  Unsere Partner im Norden kennen die EU als kom...   NaN
# 2239  Ich möchte nun die zentrale Botschaft dieser G...   NaN
# 2240  Ich werde aber diese Botschaft dennoch an mein...   NaN
# 2241  Wir haben im Fall von Uganda gesehen , dass da...   NaN
# 2242  ... überprüft ansonsten nur die Lastenfreiheit...   NaN
# 2243  Die Lehre aus den Vorgängen in der Ukraine ist...   NaN
# 2244  Ich habe die Äußerungen der verschiedenen Abge...   NaN
# 2245  Ein hochkarätiges Rahmenprogramm und zahlreich...   NaN
# 2246  Ich werde Ihre Anregung dem Präsidium übermitt...   NaN
# 2247  Tatsächlich wurde bereits gegen dieses Verbot ...   NaN
# 2248  Machen Sie sich keine Gedanken , Sie brauchen ...   NaN
# 2249  Alle Appartements sind in neu rekonstruierten ...     x
# 2250  Also , für diejenigen , die davon mehr von der...   NaN
# 2251  Derzeit wisse er nicht , ob das neue Partman f...   NaN
# 2252  Herr Präsident , unser einziges Problem ist , ...   NaN
# 2253  20 Und es begab sich : Sie entfernten sich und...   NaN
# 2254  Es sei darauf hingewiesen , daß es möglich sei...   NaN
# 2255  Wir freuen uns über Ihr Interesse an Schloss B...   NaN
# 2256  Damit verfügen die Feuerwehren und Rettungsdie...   NaN
# 2257  Sie haben jetzt Gelegenheit , uns mitzuteilen ...   NaN
# 2258  Wir fordern keine personenbezogenen Daten von ...   NaN
# 2259  So lautet , auf den Punkt gebracht , die Ansic...   NaN
# 2260  In dieser Fraktion ist es möglich , vom Tal au...   NaN
# 2261  Erst kürzlich wurde der erste Download-Inhalt ...     x
# 2262  So lautet kurz gefasst unser Standpunkt zur Ei...   NaN
# 2263  Die Lage zwischen Dom und Palazzo Veccio ist e...     x
# 2264  Um den Stein ins Rollen zu bringen , sollte di...   NaN
# 2265  Selbstverständlich , Frau Napoletano , werde i...   NaN
# 2266  Inside Line ist die Berichterstattung der Hond...     x
# 2267  Für alle Tierkreiszeichen empfehlen die Sterne...   NaN
# 2268  &quot; Der Präsident von Fenerbahce stellt im ...     x
# 2269  Ich habe Ihre Hinweise zur Kenntnis genommen ,...   NaN
# 2270  Das wollte ich hier ganz klar und offen auf de...   NaN
# 2271  Wir haben den Bedarf für sichere und zuverläss...   NaN
# 2272  17 Und es begab sich : Am nächsten Tag versamm...   NaN
# 2273  Abschließend möchte ich anmerken , dass die Mi...   NaN
# 2274  Kurz gesagt werden sowohl die Probleme , mit d...   NaN
# 2275  Wir sind der Ansicht , daß das zu detailliert ...   NaN
# 2276  Ich möchte den Kommissionspräsidenten , Herrn ...   NaN
# 2277  Meine Zucht erhebt sich über einen Land in der...     x
# 2278  How you doin ? ? ? I &apos; m an easygoing 26 ...     x
# 2279  Rapid Trogmischer sind aus den besten verfügba...     x
# 2280  Teilen Sie uns einfach mit , was Sie vermissen...   NaN
# 2281  Die Übernachtung ist nur im Norden auf dem Zel...   NaN
# 2282  Klar formuliert , ohne in den Überschwang oder...   NaN
# 2283  Dieses Anliegen bitte ich Sie , Herr Kommissar...   NaN
# 2284  Am Alhambra Casino nach links abbiegen und nac...   NaN
# 2285  Eine Komfortautomatik haben die vorderen Siche...   NaN
# 2286  Wir sollten nicht zögern , die durch Stau , Lu...   NaN
# 2287  Am 24. &amp; # 160 ; März &amp; # 160 ; 2010 w...   NaN
# 2288  Ich kann Ihnen die Genugtuung der Kommission z...   NaN
# 2289  Zusätzlich gibt es zwei weitere Geldautomaten ...     x
# 2290  Ich bitte Sie dringendst , werte Kolleginnen u...   NaN
# 2291  Dennoch halte ich es für wichtig , dass wir un...   NaN
# 2292  Heutzutage ist es vollkommen unannehmbar , das...   NaN
# 2293  Ich leite Ihre Anfrage an meine Kollegen , Her...   NaN
# 2294  Diese Kosten an die Verbraucher weiterzugeben ...   NaN
# 2295  Und es muß unbedingt bekannt sein , welche Wün...   NaN
# 2296  Unsere Erfahrungen und unser Wissen geben wir ...   NaN
# 2297  Anfangs war ich diesem Album gegenüber etwas s...     x
# 2298  Die heutige Debatte ist daher insofern sehr be...   NaN
# 2299  Sie versammelten sich Ende April 2010 am Klaus...   NaN
# 2300  In unseren Konferenzräumen finden bis zu 80 Pe...   NaN
# 2301  Keiner von uns will heute noch mit der Pferdek...   NaN

# %%
import importlib
clean_dataset = importlib.import_module(folder_name + '.End-To-End.cleaning').clean_dataset

# %%
base_path="repo/End-To-End/Dataset/en-de/"
train_data = pd.read_csv(base_path+'train_compare_cleaned.csv', header=0, index_col=0)
test_data = pd.read_csv(base_path+'test_compare_cleaned.csv', header=0, index_col=0)

train_info = pd.read_csv(base_path+'idiom_trainplus.info',sep='\t',header=None,names=["spread", "en_idiom", "de_idiom",'frequency'])
test_info = pd.read_csv(base_path+'idiom_test.info',sep='\t',header=None,names=["spread", "en_idiom", "de_idiom",'frequency'])

train_data = pd.concat((train_data, train_info['en_idiom']), axis=1)
test_data = pd.concat((test_data, test_info['en_idiom']), axis=1)

train_data = train_data[train_data['Wrong']!='x']
test_data = test_data[test_data['Wrong']!='x']

train_data = train_data.drop(columns=['trans', 'Wrong'])
test_data = test_data.drop(columns=['trans', 'Wrong'])

train_data[['en', 'de']] = clean_dataset(train_data[['en', 'de']])
test_data[['en', 'de']] = clean_dataset(test_data[['en', 'de']])

train_data['input'] = 'translate English to German: '+ train_data['en']
test_data['input'] = 'translate English to German: '+ test_data['en']

train_data = train_data.drop(columns=['en'])
test_data = test_data.drop(columns=['en'])

train_data = train_data.rename(columns={'de': 'target'})
test_data = test_data.rename(columns={'de': 'target'})

train_data['frequency'] = train_data['en_idiom'].map(train_data['en_idiom'].value_counts())

train_data['single'] = train_data['frequency'] == 1

if train_data['single'].sum() == 1:
  sample = train_data.loc[train_data['single']==True]
  train_data = train_data.loc[train_data['single']==False]
  train_data, val_data=train_test_split(train_data, test_size=0.15, stratify=train_data['en_idiom'], random_state=42)
  val_data = pd.concat((val_data, sample))

elif train_data['single'].sum() == 0:
  train_data, val_data=train_test_split(train_data, test_size=0.15, stratify=train_data['en_idiom'], random_state=42)
  
else:
  raise Exception('More than one single')

train_data = train_data.drop(columns=['en_idiom', 'frequency', 'single'])
val_data = val_data.drop(columns=['en_idiom', 'frequency', 'single'])

# %%
# Check max length
lengths_train_in = train_data["input"].str.split(" ")
lengths_test_in = test_data["input"].str.split(" ")
lengths_val_in = val_data["input"].str.split(" ")

print("Max number of tokens input = ", max(lengths_train_in.str.len().max(),lengths_test_in.str.len().max()))

lengths_train_tar = train_data["target"].str.split(" ")
lengths_test_tar = test_data["target"].str.split(" ")
lengths_val_tar = val_data["target"].str.split(" ")

print("Max number of tokens target = ", max(lengths_train_tar.str.len().max(),lengths_test_tar.str.len().max()))
# Out:
# Max number of tokens input =  153
# Max number of tokens target =  144

# %% [markdown]
# #2. Training Model

# %%
# let's define model parameters specific to T5
model_params = {
    "MODEL": "t5-small",  # model_type: t5-base/t5-small/t5-large
    "TRAIN_BATCH_SIZE": 4,  # training batch size
    "VALID_BATCH_SIZE": 4,  # validation batch size
    "TRAIN_EPOCHS": 50,  # number of training epochs
    "VAL_EPOCHS": 1,  # number of validation epochs
    "LEARNING_RATE": 1e-4,  # learning rate
    "MAX_SOURCE_TEXT_LENGTH": 180,  # max length of source text
    "MAX_TARGET_TEXT_LENGTH": 150,  # max length of target text
    "SEED": 42,  # set seed for reproducibility
}

# %%
# Initialize training and validation loggers to keep track of model loss

# training logger to log training loss over the epochs and batches
training_logger = Table(
    Column("Epoch", justify="center"),
    # Column("Batch", justify="center"),
    Column("Loss", justify="center"),
    title="Training Loss",
    pad_edge=False,
    box=box.ASCII,
)

# validation logger to log validation loss over the epochs
validation_logger = Table(
    Column("Epoch", justify="center"),
    Column("Loss", justify="center"),
    title="Validation Loss",
    pad_edge=False,
    box=box.ASCII,
)

# %%
# %mkdir outputs

# %%
# Train model
T5Trainer(train_data=train_data, val_data= val_data, source_text="input", target_text="target", model_params=model_params, output_dir="outputs")
# Out:
# [13:00:04] [Model]: Loading t5-small...                     <ipython-input-8-31ece74cb2e6>:23
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:169: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-small automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,
# [13:00:08] [Data]: Reading data...                          <ipython-input-8-31ece74cb2e6>:33
#                                          Sample Data
# +-------------------------------------------------------------------------------------------+
# |                source_text                  |                 target_text                 |
# |---------------------------------------------+---------------------------------------------|
# |translate English to German: You will always | Sie wissen stets , ob ein dritter Partner an|
# | know whether a third party is involved in   |    Transaktionen beteiligt ist und ob wir   |
# |    transactions and whether we pass on      |   Informationen über die Transaktionen mit  |
# | information about the transactions to this  | diesem dritten Partner an diesen weitergeben|
# |                 partner .                   |                   können .                  |
# | translate English to German: What test can  |   Welcher Test kann durchgeführt werden um  |
# |    be done in order to know if the low      |     festzustellen , ob der Grund für die    |
# | performance is due to the electric pump or  | niedrige Leistung bei der Pumpe oder bei der|
# |             the installation ?              |               Montage liegt ?               |
# +-------------------------------------------------------------------------------------------+
# TRAIN Dataset: (1730, 2)
# VALIDATION Dataset: (307, 2)
#            [Initiating Fine Tuning]...                      <ipython-input-8-31ece74cb2e6>:88
# Epoch:  0 Batch:  0 Loss:  2.4924094676971436
# Epoch:  0 Batch:  100 Loss:  1.2873202562332153
# Epoch:  0 Batch:  200 Loss:  1.9143338203430176
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-141-075643cc0c44> in <module>()
#       1 # Train model
# ----> 2 T5Trainer(train_data=train_data, val_data= val_data, source_text="input", target_text="target", model_params=model_params, output_dir="outputs")
#
# <ipython-input-8-31ece74cb2e6> in T5Trainer(train_data, val_data, source_text, target_text, model_params, output_dir)
#      90     train_batch_size = model_params["TRAIN_BATCH_SIZE"]
#      91     for epoch in range(model_params["TRAIN_EPOCHS"]):
# ---> 92         train(epoch, tokenizer, model, device, training_loader, optimizer, train_batch_size)
#      93         validate(epoch, tokenizer, model, device, val_loader, generate_outputs=False)
#      94
#
# <ipython-input-6-327987059964> in train(epoch, tokenizer, model, device, loader, optimizer, train_batch_size)
#      43
#      44         optimizer.zero_grad()
# ---> 45         loss.backward()
#      46         optimizer.step()
#      47
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     361                 create_graph=create_graph,
#     362                 inputs=inputs)
# --> 363         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     364
#     365     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#     176
#     177 def grad(
#
# KeyboardInterrupt:

# %%
# Save the training loss to csv
table_data = {x.header: [Text.from_markup(y).plain for y in x.cells] for x in training_logger.columns}
training_logger_df = pd.DataFrame(table_data)
training_logger_df.to_csv("outputs/"+"train_loss.csv", sep="=")

# Save the validation loss to csv
table_data = {x.header: [Text.from_markup(y).plain for y in x.cells] for x in validation_logger.columns}
validation_logger_df = pd.DataFrame(table_data)
validation_logger_df.to_csv("outputs/"+"val_loss.csv", sep="=")

# %%
# Plot the loss
train_loss = pd.read_csv("outputs/"+"train_loss.csv", sep="=")
train_loss.plot(0,2)
val_loss = pd.read_csv("outputs/"+"val_loss.csv", sep="=")
val_loss.plot(0,2)

# %%
# !zip -r outputs.zip outputs
# Out:
#   adding: outputs/ (stored 0%)
#   adding: outputs/logs.txt (deflated 72%)
#   adding: outputs/val_loss.csv (deflated 23%)
#   adding: outputs/train_loss.csv (deflated 20%)
#   adding: outputs/model_files/ (stored 0%)
#   adding: outputs/model_files/config.json (deflated 63%)
#   adding: outputs/model_files/spiece.model (deflated 48%)
#   adding: outputs/model_files/tokenizer_config.json (deflated 80%)
#   adding: outputs/model_files/pytorch_model.bin (deflated 8%)
#   adding: outputs/model_files/special_tokens_map.json (deflated 83%)
#   adding: outputs/predictions.csv (deflated 64%)
